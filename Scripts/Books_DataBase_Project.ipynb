# %% [markdown]
# # 📘 Books Database Project
# This project builds a structured books database using a CSV file containing book records with categories, prices, availability, ratings, and more. The database is created using Python, pandas, and MySQBenchwork.

# %% [markdown]
# ## Imports

# %%
import mysql.connector
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## 1. Load the CSV File

# %%
df = pd.read_csv("books.csv")
df
# Out:
#      Category                                              Title  \
# 0      Travel                            It's Only the Himalayas
# 1      Travel  Full Moon over Noah’s Ark: An Odyssey to Mount...
# 2      Travel  See America: A Celebration of Our National Par...
# 3      Travel  Vagabonding: An Uncommon Guide to the Art of L...
# 4      Travel                               Under the Tuscan Sun
# ..        ...                                                ...
# 995  Politics  Why the Right Went Wrong: Conservatism--From G...
# 996  Politics  Equal Is Unfair: America's Misguided Fight Aga...
# 997  Cultural                                     Amid the Chaos
# 998   Erotica                                         Dark Notes
# 999     Crime  The Long Shadow of Small Ghosts: Murder and Me...
#
#                                                    URL   Price Availability  \
# 0    http://books.toscrape.com/catalogue/its-only-t...  £45.17     In stock
# 1    http://books.toscrape.com/catalogue/full-moon-...  £49.43     In stock
# 2    http://books.toscrape.com/catalogue/see-americ...  £48.87     In stock
# 3    http://books.toscrape.com/catalogue/vagabondin...  £36.94     In stock
# 4    http://books.toscrape.com/catalogue/under-the-...  £37.33     In stock
# ..                                                 ...     ...          ...
# 995  http://books.toscrape.com/catalogue/why-the-ri...  £52.65     In stock
# 996  http://books.toscrape.com/catalogue/equal-is-u...  £56.86     In stock
# 997  http://books.toscrape.com/catalogue/amid-the-c...  £36.58     In stock
# 998  http://books.toscrape.com/catalogue/dark-notes...  £19.19     In stock
# 999  http://books.toscrape.com/catalogue/the-long-s...  £10.97     In stock
#
#     Rating
# 0      Two
# 1     Four
# 2    Three
# 3      Two
# 4    Three
# ..     ...
# 995   Four
# 996    One
# 997    One
# 998   Five
# 999    One
#
# [1000 rows x 6 columns]

# %%
# Clean data
rating_map = {"One" : 1 , "Two" : 2 , "Three" : 3 , "Four" : 4 , "Five" : 5}
df['rating'] = df['Rating'].map(rating_map)
df['price'] = df['Price'].str.replace("£", "").astype(float)
df
# Out:
#      Category                                              Title  \
# 0      Travel                            It's Only the Himalayas
# 1      Travel  Full Moon over Noah’s Ark: An Odyssey to Mount...
# 2      Travel  See America: A Celebration of Our National Par...
# 3      Travel  Vagabonding: An Uncommon Guide to the Art of L...
# 4      Travel                               Under the Tuscan Sun
# ..        ...                                                ...
# 995  Politics  Why the Right Went Wrong: Conservatism--From G...
# 996  Politics  Equal Is Unfair: America's Misguided Fight Aga...
# 997  Cultural                                     Amid the Chaos
# 998   Erotica                                         Dark Notes
# 999     Crime  The Long Shadow of Small Ghosts: Murder and Me...
#
#                                                    URL   Price Availability  \
# 0    http://books.toscrape.com/catalogue/its-only-t...  £45.17     In stock
# 1    http://books.toscrape.com/catalogue/full-moon-...  £49.43     In stock
# 2    http://books.toscrape.com/catalogue/see-americ...  £48.87     In stock
# 3    http://books.toscrape.com/catalogue/vagabondin...  £36.94     In stock
# 4    http://books.toscrape.com/catalogue/under-the-...  £37.33     In stock
# ..                                                 ...     ...          ...
# 995  http://books.toscrape.com/catalogue/why-the-ri...  £52.65     In stock
# 996  http://books.toscrape.com/catalogue/equal-is-u...  £56.86     In stock
# 997  http://books.toscrape.com/catalogue/amid-the-c...  £36.58     In stock
# 998  http://books.toscrape.com/catalogue/dark-notes...  £19.19     In stock
# 999  http://books.toscrape.com/catalogue/the-long-s...  £10.97     In stock
#
#     Rating  rating  price
# 0      Two       2  45.17
# 1     Four       4  49.43
# 2    Three       3  48.87
# 3      Two       2  36.94
# 4    Three       3  37.33
# ..     ...     ...    ...
# 995   Four       4  52.65
# 996    One       1  56.86
# 997    One       1  36.58
# 998   Five       5  19.19
# 999    One       1  10.97
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## 2. Connect to MySQL

# %%
con = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'admin',
)

cur = con.cursor()

# %% [markdown]
# ## 3. Create the books Database

# %%
qry = '''
CREATE DATABASE IF NOT EXISTS books
'''

cur.execute(qry)

# %%
qry = '''
USE books
'''
cur.execute(qry)

# %% [markdown]
# ## 4. Create Tables in books Database

# %%
# Create categories table
qry = '''
CREATE TABLE IF NOT EXISTS categories (
    category_id INT AUTO_INCREMENT PRIMARY KEY,
    category_name VARCHAR(100) UNIQUE
)
'''
cur.execute(qry)

# %%
# Create books_catalog table
qry = '''
CREATE TABLE IF NOT EXISTS books_catalog (
    book_id INT AUTO_INCREMENT PRIMARY KEY,
    title VARCHAR(255),
    url TEXT,
    price DECIMAL(6,2),
    availability VARCHAR(50),
    rating INT,
    category_id INT,
    FOREIGN KEY (category_id) REFERENCES categories(category_id)
)
'''
cur.execute(qry)
con.commit()

# %% [markdown]
# ##  5. Insert Categories into categories Table

# %%
for cat in df["Category"].unique():
    cur.execute("INSERT IGNORE INTO categories (category_name) VALUES (%s)", (cat,))
con.commit()

# %%
#  Create mapping: category_name → category_id
cur.execute("SELECT category_id, category_name FROM categories")
category_map = {name: cid for cid, name in cur.fetchall()}
category_map
# Out:
# {'Academic': 39,
#  'Add a comment': 17,
#  'Adult Fiction': 28,
#  'Art': 24,
#  'Autobiography': 26,
#  'Biography': 35,
#  'Business': 34,
#  'Childrens': 10,
#  'Christian': 42,
#  'Christian Fiction': 33,
#  'Classics': 5,
#  'Contemporary': 37,
#  'Crime': 50,
#  'Cultural': 48,
#  'Default': 14,
#  'Erotica': 49,
#  'Fantasy': 18,
#  'Fiction': 9,
#  'Food and Drink': 32,
#  'Health': 46,
#  'Historical': 41,
#  'Historical Fiction': 3,
#  'History': 31,
#  'Horror': 30,
#  'Humor': 29,
#  'Music': 13,
#  'Mystery': 2,
#  'New Adult': 19,
#  'Nonfiction': 12,
#  'Novels': 45,
#  'Paranormal': 23,
#  'Parenting': 27,
#  'Philosophy': 6,
#  'Poetry': 22,
#  'Politics': 47,
#  'Psychology': 25,
#  'Religion': 11,
#  'Romance': 7,
#  'Science': 21,
#  'Science Fiction': 15,
#  'Self Help': 40,
#  'Sequential Art': 4,
#  'Short Stories': 44,
#  'Spirituality': 38,
#  'Sports and Games': 16,
#  'Suspense': 43,
#  'Thriller': 36,
#  'Travel': 1,
#  'Womens Fiction': 8,
#  'Young Adult': 20}

# %% [markdown]
# ## 6. Insert Books into books_catalog Table

# %%
con = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'admin',
    database = 'books'
)

cur = con.cursor()

# %%
qry = '''
INSERT INTO books_catalog (title, url, price, availability, rating, category_id)
        VALUES (%s, %s, %s, %s, %s, %s)
'''
for _,row in df.iterrows():
    cur.execute(qry ,
        (row["Title"],
        row["URL"],
        row["price"],
        row["Availability"],
        row["rating"],
        category_map[row["Category"]]))

con.commit()

# %% [markdown]
# ### Done!Test a Query

# %%
qry = '''
SELECT title, price FROM books_catalog;
'''
cur.execute(qry)

for title, price in cur.fetchall():
    print(f"{title} - £{price}\n")
# Out:
# It's Only the Himalayas - £45.17
#
# Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond - £49.43
#
# See America: A Celebration of Our National Parks & Treasured Sites - £48.87
#
# Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel - £36.94
#
# Under the Tuscan Sun - £37.33
#
# A Summer In Europe - £44.34
#
# The Great Railway Bazaar - £30.54
#
# A Year in Provence (Provence #1) - £56.88
#
# The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2) - £23.21
#
# Neither Here nor There: Travels in Europe - £38.95
#
# 1,000 Places to See Before You Die - £26.08
#
# Sharp Objects - £47.82
#
# In a Dark, Dark Wood - £19.63
#
# The Past Never Ends - £56.50
#
# A Murder in Time - £16.64
#
# The Murder of Roger Ackroyd (Hercule Poirot #4) - £44.10
#
# The Last Mile (Amos Decker #2) - £54.21
#
# That Darkness (Gardiner and Renner #1) - £13.92
#
# Tastes Like Fear (DI Marnie Rome #3) - £10.69
#
# A Time of Torment (Charlie Parker #14) - £48.35
#
# A Study in Scarlet (Sherlock Holmes #1) - £16.73
#
# Poisonous (Max Revere Novels #3) - £26.80
#
# Murder at the 42nd Street Library (Raymond Ambler #1) - £54.36
#
# Most Wanted - £35.28
#
# Hide Away (Eve Duncan #20) - £11.84
#
# Boar Island (Anna Pigeon #19) - £59.48
#
# The Widow - £27.26
#
# Playing with Fire - £13.71
#
# What Happened on Beale Street (Secrets of the South Mysteries #2) - £25.37
#
# The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1) - £52.30
#
# Delivering the Truth (Quaker Midwife Mystery #1) - £20.89
#
# The Mysterious Affair at Styles (Hercule Poirot #1) - £24.80
#
# In the Woods (Dublin Murder Squad #1) - £38.38
#
# The Silkworm (Cormoran Strike #2) - £23.05
#
# The Exiled - £43.45
#
# The Cuckoo's Calling (Cormoran Strike #1) - £19.21
#
# Extreme Prey (Lucas Davenport #26) - £25.40
#
# Career of Evil (Cormoran Strike #3) - £24.72
#
# The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1) - £57.70
#
# The Girl You Lost - £12.29
#
# The Girl In The Ice (DCI Erika Foster #1) - £15.85
#
# Blood Defense (Samantha Brinkman #1) - £20.30
#
# 1st to Die (Women's Murder Club #1) - £53.98
#
# Tipping the Velvet - £53.74
#
# Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton - £29.69
#
# A Flight of Arrows (The Pathfinders #2) - £55.53
#
# The House by the Lake - £36.95
#
# Mrs. Houdini - £30.25
#
# The Marriage of Opposites - £28.08
#
# Glory over Everything: Beyond The Kitchen House - £45.84
#
# Love, Lies and Spies - £20.55
#
# A Paris Apartment - £39.01
#
# Lilac Girls - £17.28
#
# The Constant Princess (The Tudor Court #1) - £16.62
#
# The Invention of Wings - £37.34
#
# World Without End (The Pillars of the Earth #2) - £32.97
#
# The Passion of Dolssa - £28.32
#
# Girl With a Pearl Earring - £26.77
#
# Voyager (Outlander #3) - £21.07
#
# The Red Tent - £35.66
#
# The Last Painting of Sara de Vos - £55.55
#
# The Guernsey Literary and Potato Peel Pie Society - £49.53
#
# Girl in the Blue Coat - £46.83
#
# Between Shades of Gray - £20.79
#
# While You Were Mine - £41.32
#
# The Secret Healer - £34.56
#
# Starlark - £25.83
#
# Lost Among the Living - £27.70
#
# A Spy's Devotion (The Regency Spies of London #1) - £16.97
#
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1) - £52.29
#
# Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2) - £16.28
#
# This One Summer - £19.49
#
# The Nameless City (The Nameless City #1) - £38.16
#
# Saga, Volume 5 (Saga (Collected Editions) #5) - £51.04
#
# Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15) - £50.40
#
# Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1) - £13.61
#
# Pop Gun War, Volume 1: Gift - £18.97
#
# Patience - £10.16
#
# Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1) - £15.44
#
# orange: The Complete Collection 1 (orange: The Complete Collection #1) - £48.41
#
# Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8) - £46.91
#
# Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4) - £45.61
#
# Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12) - £19.92
#
# I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5) - £29.17
#
# I am a Hero Omnibus Volume 1 - £54.63
#
# Giant Days, Vol. 2 (Giant Days #5-8) - £22.11
#
# Danganronpa Volume 1 - £51.99
#
# Codename Baboushka, Volume 1: The Conclave of Death - £36.72
#
# Camp Midnight - £17.08
#
# Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions)) - £37.92
#
# The Shadow Hero (The Shadow Hero) - £33.14
#
# Fables, Vol. 1: Legends in Exile (Fables #1) - £41.62
#
# Batman: The Long Halloween (Batman) - £36.50
#
# Batman: The Dark Knight Returns (Batman) - £15.38
#
# Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1) - £37.34
#
# We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1) - £53.90
#
# Through the Woods - £25.38
#
# Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1) - £11.89
#
# So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6) - £35.43
#
# Robin War - £47.82
#
# Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1) - £25.48
#
# Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14) - £38.39
#
# Lowriders to the Center of the Earth (Lowriders in Space #2) - £51.51
#
# El Deafo - £57.62
#
# Batman: Europa - £32.01
#
# Art Ops Vol. 1 - £48.80
#
# Adulthood Is a Myth: A "Sarah's Scribbles" Collection - £10.90
#
# Fruits Basket, Vol. 9 (Fruits Basket #9) - £33.95
#
# Roller Girl - £14.10
#
# Fruits Basket, Vol. 7 (Fruits Basket #7) - £19.57
#
# Fruits Basket, Vol. 6 (Fruits Basket #6) - £20.96
#
# Death Note, Vol. 6: Give-and-Take (Death Note #6) - £36.39
#
# Fruits Basket, Vol. 5 (Fruits Basket #5) - £16.33
#
# Death Note, Vol. 5: Whiteout (Death Note #5) - £52.41
#
# The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of Momochi House #4) - £27.88
#
# Fruits Basket, Vol. 4 (Fruits Basket #4) - £50.44
#
# The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine) - £14.41
#
# The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3) - £55.55
#
# Saga, Volume 3 (Saga (Collected Editions) #3) - £21.57
#
# Prodigy: The Graphic Novel (Legend: The Graphic Novel #2) - £43.63
#
# Persepolis: The Story of a Childhood (Persepolis #1-2) - £39.13
#
# Original Fake - £31.45
#
# Grayson, Vol 3: Nemesis (Grayson #3) - £42.72
#
# Fruits Basket, Vol. 3 (Fruits Basket #3) - £45.17
#
# Black Butler, Vol. 1 (Black Butler #1) - £49.31
#
# Awkward - £38.02
#
# The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2) - £54.81
#
# Saga, Volume 2 (Saga (Collected Editions) #2) - £11.75
#
# Fruits Basket, Vol. 2 (Fruits Basket #2) - £11.64
#
# Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1) - £18.51
#
# The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine) - £36.52
#
# The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1) - £54.12
#
# The Complete Maus (Maus #1-2) - £10.64
#
# Skip Beat!, Vol. 01 (Skip Beat! #1) - £42.12
#
# Saga, Volume 1 (Saga (Collected Editions) #1) - £28.48
#
# Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5) - £46.96
#
# Paper Girls, Vol. 1 (Paper Girls #1-5) - £21.71
#
# Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1) - £29.87
#
# Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1) - £39.39
#
# Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1) - £45.24
#
# Giant Days, Vol. 1 (Giant Days #1-4) - £56.76
#
# Fruits Basket, Vol. 1 (Fruits Basket #1) - £40.28
#
# Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1) - £34.65
#
# Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1) - £57.06
#
# The Secret Garden - £15.08
#
# The Metamorphosis - £28.58
#
# The Pilgrim's Progress - £50.26
#
# The Hound of the Baskervilles (Sherlock Holmes #5) - £14.82
#
# Little Women (Little Women #1) - £28.07
#
# Gone with the Wind - £32.49
#
# Candide - £58.63
#
# Animal Farm - £57.22
#
# Wuthering Heights - £17.73
#
# The Picture of Dorian Gray - £29.70
#
# The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition]) - £26.78
#
# Beowulf - £38.35
#
# And Then There Were None - £35.01
#
# The Story of Hong Gildong - £43.19
#
# The Little Prince - £45.42
#
# Sense and Sensibility - £37.46
#
# Of Mice and Men - £47.11
#
# Emma - £32.93
#
# Alice in Wonderland (Alice's Adventures in Wonderland #1) - £55.53
#
# Sophie's World - £15.94
#
# The Death of Humanity: and the Case for Life - £58.11
#
# The Stranger - £17.44
#
# Proofs of God: Classical Arguments from Tertullian to Barth - £54.21
#
# Kierkegaard: A Christian Missionary to Christians - £47.13
#
# At The Existentialist Café: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others - £29.93
#
# Critique of Pure Reason - £20.75
#
# Run, Spot, Run: The Ethics of Keeping Pets - £20.02
#
# The Nicomachean Ethics - £36.34
#
# Meditations - £25.89
#
# Beyond Good and Evil - £43.38
#
# Chase Me (Paris Nights #2) - £25.27
#
# Black Dust - £34.53
#
# Her Backup Boyfriend (The Sorensen Family #1) - £33.97
#
# First and First (Five Boroughs #3) - £15.97
#
# Fifty Shades Darker (Fifty Shades #2) - £21.96
#
# The Wedding Dress - £24.12
#
# Suddenly in Love (Lake Haven #1) - £55.99
#
# Something More Than This - £16.24
#
# Doing It Over (Most Likely To #1) - £35.61
#
# The Wedding Pact (The O'Malleys #2) - £32.61
#
# Hold Your Breath (Search and Rescue #1) - £28.82
#
# Dirty (Dive Bar #1) - £40.83
#
# Take Me Home Tonight (Rock Star Romance #3) - £53.98
#
# Off the Hook (Fishing for Trouble #1) - £47.67
#
# A Gentleman's Position (Society of Gentlemen #3) - £14.75
#
# Sit, Stay, Love - £20.90
#
# A Girl's Guide to Moving On (New Beginnings #2) - £31.30
#
# The Perfect Play (Play by Play #1) - £59.99
#
# Dark Lover (Black Dagger Brotherhood #1) - £12.87
#
# Changing the Game (Play by Play #2) - £13.38
#
# A Walk to Remember - £56.43
#
# The Purest Hook (Second Circle Tattoos #3) - £12.25
#
# The Obsession - £45.43
#
# Reservations for Two - £11.10
#
# Best of My Love (Fool's Gold #20) - £27.41
#
# Where Lightning Strikes (Bleeding Stars #3) - £39.77
#
# This One Moment (Pushing Limits #1) - £48.71
#
# Rhythm, Chord & Malykhin - £28.34
#
# My Perfect Mistake (Over the Top #1) - £38.92
#
# Listen to Me (Fusion #1) - £58.99
#
# Imperfect Harmony - £34.74
#
# Fighting Fate (Fighting #6) - £39.24
#
# Deep Under (Walker Security #1) - £47.09
#
# Charity's Cross (Charles Towne Belles #4) - £41.24
#
# Bounty (Colorado Mountain #7) - £37.26
#
# I Had a Nice Time And Other Lies...: How to find love & sh*t like that - £57.36
#
# Will You Won't You Want Me? - £13.86
#
# Keep Me Posted - £20.46
#
# Grey (Fifty Shades #4) - £48.49
#
# Meternity - £43.58
#
# Some Women - £13.73
#
# Shopaholic Ties the Knot (Shopaholic #3) - £48.39
#
# Can You Keep a Secret? - £21.94
#
# Twenties Girl - £42.80
#
# The Undomestic Goddess - £45.75
#
# The Nanny Diaries (Nanny #1) - £52.53
#
# The Devil Wears Prada (The Devil Wears Prada #1) - £44.29
#
# Something Borrowed (Darcy & Rachel #1) - £48.96
#
# Something Blue (Darcy & Rachel #2) - £54.62
#
# I've Got Your Number - £19.69
#
# The Edge of Reason (Bridget Jones #2) - £19.18
#
# Bridget Jones's Diary (Bridget Jones #1) - £29.82
#
# Soumission - £50.10
#
# Private Paris (Private #10) - £47.61
#
# We Love You, Charlie Freeman - £50.27
#
# Thirst - £17.27
#
# The Murder That Never Was (Forensic Instincts #5) - £54.11
#
# Tuesday Nights in 1980 - £21.04
#
# The Vacationers - £42.15
#
# The Regional Office Is Under Attack! - £51.36
#
# Finders Keepers (Bill Hodges Trilogy #2) - £53.53
#
# The Time Keeper - £27.88
#
# The Testament of Mary - £52.67
#
# The First Hostage (J.B. Collins #2) - £25.85
#
# Take Me with You - £45.21
#
# Still Life with Bread Crumbs - £26.41
#
# Shtum - £55.84
#
# My Name Is Lucy Barton - £41.56
#
# My Mrs. Brown - £24.48
#
# Mr. Mercedes (Bill Hodges Trilogy #1) - £28.90
#
# I Am Pilgrim (Pilgrim #1) - £10.60
#
# Eligible (The Austen Project #4) - £27.09
#
# Eight Hundred Grapes - £14.39
#
# Dear Mr. Knightley - £11.21
#
# Cometh the Hour (The Clifton Chronicles #6) - £25.01
#
# Balloon Animals - £17.03
#
# A Man Called Ove - £39.72
#
# The Silent Sister (Riley MacPherson #1) - £46.29
#
# The Dinner Party - £56.54
#
# The Improbability of Love - £59.45
#
# Mothering Sunday - £13.34
#
# Lies and Other Acts of Love - £45.14
#
# Daredevils - £16.34
#
# 11/22/63 - £48.48
#
# The Shack - £28.03
#
# The High Mountains of Portugal - £51.15
#
# Miller's Valley - £58.54
#
# Hystopia: A Novel - £21.96
#
# The Bourne Identity (Jason Bourne #1) - £42.78
#
# Sister Dear - £40.20
#
# Memoirs of a Geisha - £49.67
#
# Me Before You (Me Before You #1) - £19.02
#
# Deception Point - £40.32
#
# The Little Paris Bookshop - £24.73
#
# The Firm - £45.56
#
# The Expatriates - £44.58
#
# Siddhartha - £34.22
#
# Last One Home (New Beginnings #1) - £59.98
#
# Digital Fortress - £58.00
#
# Atlas Shrugged - £26.58
#
# Three-Martini Lunch - £23.21
#
# The Nightingale - £26.26
#
# The Infinities - £27.41
#
# The Husband's Secret - £52.51
#
# The Da Vinci Code (Robert Langdon #2) - £22.96
#
# The Art of Fielding - £22.10
#
# Lila (Gilead #3) - £12.47
#
# Jurassic Park (Jurassic Park #1) - £44.97
#
# Inferno (Robert Langdon #4) - £41.00
#
# Crazy Rich Asians (Crazy Rich Asians #1) - £49.13
#
# Big Little Lies - £22.11
#
# The Course of Love - £16.78
#
# When I'm Gone - £51.96
#
# The Silent Wife - £12.34
#
# The Bette Davis Club - £30.66
#
# Kitchens of the Great Midwest - £57.20
#
# Bright Lines - £39.07
#
# Birdsong: A Story in Pictures - £54.64
#
# The Bear and the Piano - £36.89
#
# The Secret of Dreadwillow Carse - £56.13
#
# The White Cat and the Monk: A Retelling of the Poem “Pangur Bán” - £58.08
#
# Little Red - £13.47
#
# Walt Disney's Alice in Wonderland - £12.96
#
# Twenty Yawns - £22.08
#
# Rain Fish - £23.57
#
# Once Was a Time - £18.28
#
# Luis Paints the World - £53.95
#
# Nap-a-Roo - £25.08
#
# The Whale - £35.96
#
# Shrunken Treasures: Literary Classics, Short, Sweet, and Silly - £52.87
#
# Raymie Nightingale - £34.41
#
# Playing from the Heart - £32.38
#
# Maybe Something Beautiful: How Art Transformed a Neighborhood - £22.54
#
# The Wild Robot - £56.07
#
# The Thing About Jellyfish - £48.77
#
# The Lonely Ones - £43.59
#
# The Day the Crayons Came Home (Crayons) - £26.33
#
# The Cat in the Hat (Beginner Books B-1) - £16.26
#
# Red: The True Story of Red Riding Hood - £28.54
#
# Horrible Bear! - £37.52
#
# Green Eggs and Ham (Beginner Books B-16) - £10.79
#
# Counting Thyme - £10.62
#
# Are We There Yet? - £10.66
#
# Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book) - £52.88
#
# Matilda - £28.34
#
# Charlie and the Chocolate Factory (Charlie Bucket #1) - £22.85
#
# Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master - £37.97
#
# You Are What You Love: The Spiritual Power of Habit - £21.87
#
# God: The Most Unpleasant Character in All Fiction - £30.03
#
# The Book of Mormon - £24.57
#
# A History of God: The 4,000-Year Quest of Judaism, Christianity, and Islam - £27.62
#
# The Bhagavad Gita - £57.49
#
# Choosing Our Religion: The Spiritual Lives of America's Nones - £28.42
#
# Worlds Elsewhere: Journeys Around Shakespeare’s Globe - £40.30
#
# The Five Love Languages: How to Express Heartfelt Commitment to Your Mate - £31.05
#
# Reasons to Stay Alive - £26.41
#
# #HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe. - £23.11
#
# Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness - £44.18
#
# Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity - £31.12
#
# The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing - £16.77
#
# The Gutsy Girl: Escapades for Your Life of Epic Adventure - £37.13
#
# The Electric Pencil: Drawings from Inside State Hospital No. 3 - £56.06
#
# Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up - £41.83
#
# Reskilling America: Learning to Labor in the Twenty-First Century - £19.83
#
# In the Country We Love: My Family Divided - £22.00
#
# Everydata: The Misinformation Hidden in the Little Data You Consume Every Day - £54.35
#
# Call the Nurse: True Stories of a Country Nurse on a Scottish Isle - £29.14
#
# Algorithms to Live By: The Computer Science of Human Decisions - £30.81
#
# The Power of Now: A Guide to Spiritual Enlightenment - £43.54
#
# The Omnivore's Dilemma: A Natural History of Four Meals - £38.21
#
# The Genius of Birds - £17.24
#
# The Artist's Way: A Spiritual Path to Higher Creativity - £38.49
#
# So You've Been Publicly Shamed - £12.23
#
# Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead - £19.43
#
# Big Magic: Creative Living Beyond Fear - £30.80
#
# Becoming Wise: An Inquiry into the Mystery and Art of Living - £27.43
#
# Agnostic: A Spirited Manifesto - £12.51
#
# Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity - £38.20
#
# What's It Like in Space?: Stories from Astronauts Who've Been There - £19.60
#
# The Year of Magical Thinking - £43.04
#
# The Literature Book (Big Ideas Simply Explained) - £17.43
#
# The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World’s Most Precious Manuscripts - £15.77
#
# Swell: A Year of Waves - £45.58
#
# No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon - £21.95
#
# Looking for Lovely: Collecting the Moments that Matter - £29.14
#
# Let It Out: A Journey Through Journaling - £26.79
#
# Hamilton: The Revolution - £58.79
#
# Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years - £15.06
#
# Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life - £51.75
#
# Buying In: The Secret Dialogue Between What We Buy and Who We Are - £37.80
#
# Brain on Fire: My Month of Madness - £49.32
#
# Abstract City - £56.37
#
# 13 Hours: The Inside Account of What Really Happened In Benghazi - £27.06
#
# The Lonely City: Adventures in the Art of Being Alone - £33.26
#
# The Diary of a Young Girl - £59.90
#
# Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas - £21.21
#
# Furiously Happy: A Funny Book About Horrible Things - £41.46
#
# The Sleep Revolution: Transforming Your Life, One Night at a Time - £11.68
#
# Mother, Can You Not? - £16.89
#
# A Mother's Reckoning: Living in the Aftermath of Tragedy - £19.53
#
# 10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works - £24.57
#
# Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster - £35.92
#
# Zero to One: Notes on Startups, or How to Build the Future - £34.06
#
# Why Not Me? - £17.76
#
# When Breath Becomes Air - £39.36
#
# The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer - £28.45
#
# Smarter Faster Better: The Secrets of Being Productive in Life and Business - £38.89
#
# Rising Strong - £21.82
#
# Man's Search for Meaning - £29.48
#
# Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations - £25.06
#
# Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want - £12.55
#
# I Will Find You - £44.21
#
# Brazen: The Courage to Find the You That's Been Hiding - £19.22
#
# Between the World and Me - £56.91
#
# Being Mortal: Medicine and What Matters in the End - £55.06
#
# A Murder Over a Girl: Justice, Gender, Junior High - £13.20
#
# For the Love: Fighting for Grace in a World of Impossible Standards - £45.13
#
# Finding God in the Ruins: How God Redeems Pain - £46.64
#
# The Man Who Mistook His Wife for a Hat and Other Clinical Tales - £59.45
#
# In Cold Blood - £49.98
#
# Girl, Interrupted - £42.14
#
# Why Save the Bankers?: And Other Essays on Our Economic and Political Crisis - £48.67
#
# Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut - £25.15
#
# My Mother Was Nuts - £31.63
#
# Data, A Love Story: How I Gamed Online Dating to Meet My Match - £32.35
#
# The Jazz of Physics: The Secret Link Between Music and the Structure of the Universe - £38.71
#
# The Gunning of America: Business and the Making of American Gun Culture - £16.81
#
# The Geography of Bliss: One Grump's Search for the Happiest Places in the World - £28.23
#
# God Is Not Great: How Religion Poisons Everything - £27.80
#
# We the People: The Modern-Day Figures Who Have Reshaped and Affirmed the Founding Fathers' Vision of America - £31.95
#
# Very Good Lives: The Fringe Benefits of Failure and the Importance of Imagination - £50.66
#
# Unstuffed: Decluttering Your Home, Mind, and Soul - £58.09
#
# Under the Banner of Heaven: A Story of Violent Faith - £30.00
#
# Trespassing Across America: One Man's Epic, Never-Done-Before (and Sort of Illegal) Hike Across the Heartland - £53.51
#
# The Name of God is Mercy - £37.25
#
# Stiff: The Curious Lives of Human Cadavers - £36.74
#
# Spilled Milk: Based on a True Story - £49.51
#
# Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars - £41.67
#
# Outliers: The Story of Success - £14.16
#
# Notes from a Small Island (Notes From a Small Island #1) - £40.17
#
# Night (The Night Trilogy #1) - £13.51
#
# Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing - £57.83
#
# Letter to a Christian Nation - £22.20
#
# Let's Pretend This Never Happened: A Mostly True Memoir - £45.11
#
# It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond - £42.38
#
# Into the Wild - £56.70
#
# In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin - £28.85
#
# I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban - £28.88
#
# Gratitude - £26.66
#
# Disrupted: My Misadventure in the Start-Up Bubble - £15.28
#
# Brave Enough - £51.32
#
# Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen - £27.35
#
# Blink: The Power of Thinking Without Thinking - £21.74
#
# Black Flags: The Rise of ISIS - £40.87
#
# Are We Smart Enough to Know How Smart Animals Are? - £56.58
#
# A Walk in the Woods: Rediscovering America on the Appalachian Trail - £30.48
#
# The Suffragettes (Little Black Classics, #96) - £11.89
#
# Kindle Paperwhite User's Guide - £34.00
#
# H is for Hawk - £57.42
#
# Travels with Charley: In Search of America - £57.82
#
# The Tumor - £41.56
#
# The End of the Jesus Era (An Investigation #1) - £14.40
#
# Eat, Pray, Love - £51.32
#
# Rip it Up and Start Again - £35.02
#
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991 - £57.25
#
# How Music Works - £37.32
#
# Love Is a Mix Tape (Music #1) - £18.03
#
# Please Kill Me: The Uncensored Oral History of Punk - £31.19
#
# Kill 'Em and Leave: Searching for James Brown and the American Soul - £45.05
#
# Chronicles, Vol. 1 - £52.60
#
# This Is Your Brain on Music: The Science of a Human Obsession - £38.40
#
# Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors - £12.36
#
# No One Here Gets Out Alive - £20.02
#
# Life - £31.58
#
# Old Records Never Die: One Man's Quest for His Vinyl and His Past - £55.66
#
# Forever Rockers (The Rocker #12) - £28.80
#
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull - £17.93
#
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics - £22.60
#
# Starving Hearts (Triangular Trade Trilogy, #1) - £13.99
#
# America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana - £22.50
#
# Aladdin and His Wonderful Lamp - £53.13
#
# Penny Maybe - £33.29
#
# Maude (1883-1993):She Grew Up with the country - £18.02
#
# The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer - £20.59
#
# Soul Reader - £39.58
#
# Bossypants - £49.46
#
# A World of Flavor: Your Gluten Free Passport - £42.95
#
# A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations - £56.76
#
# Tracing Numbers on a Train - £41.60
#
# Thirteen Reasons Why - £52.72
#
# The Secret (The Secret #1) - £27.37
#
# The Psychopath Test: A Journey Through the Madness Industry - £36.00
#
# The Kite Runner - £41.82
#
# The Girl on the Train - £55.02
#
# The Emerald Mystery - £23.15
#
# The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs. - £32.00
#
# The Art of War - £33.34
#
# Secrets and Lace (Fatal Hearts #1) - £20.27
#
# Romero and Juliet: A Tragic Tale of Love and Zombies - £36.94
#
# Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form - £41.06
#
# Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1) - £10.76
#
# Large Print Heart of the Pride - £19.15
#
# Grumbles - £22.16
#
# First Steps for New Christians (Print Edition) - £29.00
#
# Eureka Trivia 6.0 - £54.59
#
# Drive: The Surprising Truth About What Motivates Us - £34.95
#
# Done Rubbed Out (Reightman & Bailey #1) - £37.72
#
# Beauty Restored (Riley Family Legacy Novellas #3) - £11.11
#
# Ayumi's Violin - £15.48
#
# Anonymous - £46.82
#
# Amy Meets the Saints and Sages - £18.46
#
# Amatus - £50.54
#
# V for Vendetta (V for Vendetta Complete) - £37.10
#
# Unbroken: A World War II Story of Survival, Resilience, and Redemption - £45.95
#
# The Wright Brothers - £56.80
#
# The Songs of the Gods - £44.48
#
# The Rosie Project (Don Tillman #1) - £54.04
#
# The Power of Habit: Why We Do What We Do in Life and Business - £16.88
#
# Steve Jobs - £39.50
#
# Luckiest Girl Alive - £49.83
#
# Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments - £46.91
#
# Lady Midnight (The Dark Artifices #1) - £16.28
#
# Hush, Hush (Hush, Hush #1) - £47.02
#
# Greek Mythic History - £10.23
#
# Every Last Word - £46.47
#
# Daily Fantasy Sports - £36.58
#
# Clockwork Angel (The Infernal Devices #1) - £44.14
#
# City of Fallen Angels (The Mortal Instruments #4) - £11.23
#
# City of Bones (The Mortal Instruments #1) - £43.28
#
# City of Ashes (The Mortal Instruments #2) - £47.27
#
# Carry On, Warrior: Thoughts on Life Unarmed - £31.85
#
# Carrie - £46.23
#
# Angels & Demons (Robert Langdon #1) - £51.48
#
# The Three Searches, Meaning, and the Story - £13.33
#
# Raspberry Pi Electronics Projects for the Evil Genius - £49.67
#
# How to Speak Golf: An Illustrated Guide to Links Lingo - £58.32
#
# Eleanor & Park - £56.51
#
# Troublemaker: Surviving Hollywood and Scientology - £48.39
#
# Adultery - £20.88
#
# Unlimited Intuition Now - £58.87
#
# Underlying Notes - £11.82
#
# The New Brand You: Your New Image Makes the Sale for You - £44.05
#
# The Flowers Lied - £16.68
#
# NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond - £10.41
#
# Modern Day Fables - £47.44
#
# The Unlikely Pilgrimage of Harold Fry (Harold Fry #1) - £43.62
#
# The Martian (The Martian #1) - £41.39
#
# Left Behind (Left Behind #1) - £40.72
#
# John Vassos: Industrial Design for Modern Life - £20.22
#
# I'll Give You the Sun - £56.48
#
# Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back - £52.86
#
# Ender's Game (The Ender Quintet #1) - £43.64
#
# Death by Leisure: A Cautionary Tale - £37.51
#
# Wildlife of New York: A Five-Borough Coloring Book - £22.14
#
# The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible - £34.72
#
# The Great Gatsby - £36.05
#
# The Good Girl - £49.03
#
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change - £33.17
#
# Steal Like an Artist: 10 Things Nobody Told You About Being Creative - £20.90
#
# Life of Pi - £13.22
#
# The Sound Of Love - £57.84
#
# The Perks of Being a Wallflower - £55.02
#
# The Makings of a Fatherless Child - £31.58
#
# The Hobbit (Middle-Earth Universe) - £17.80
#
# The Fellowship of the Ring (The Lord of the Rings #1) - £10.27
#
# Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman - £30.60
#
# Musicophilia: Tales of Music and the Brain - £46.58
#
# What If?: Serious Scientific Answers to Absurd Hypothetical Questions - £53.68
#
# The Fault in Our Stars - £47.22
#
# The Dream Thieves (The Raven Cycle #2) - £34.50
#
# The 5th Wave (The 5th Wave #1) - £11.83
#
# Shiver (The Wolves of Mercy Falls #1) - £16.23
#
# Remember Me? - £11.48
#
# If I Stay (If I Stay #1) - £38.13
#
# I Know Why the Caged Bird Sings (Maya Angelou's Autobiography #1) - £36.55
#
# Harry Potter and the Deathly Hallows (Harry Potter #7) - £23.32
#
# Fool Me Once - £16.96
#
# Drama - £38.70
#
# Blue Lily, Lily Blue (The Raven Cycle #3) - £34.13
#
# Alight (The Generations Trilogy #2) - £58.59
#
# Vogue Colors A to Z: A Fashion Coloring Book - £52.35
#
# The Shining (The Shining #1) - £27.88
#
# The Hunger Games (The Hunger Games #1) - £29.85
#
# Outlander (Outlander #1) - £19.67
#
# Mockingjay (The Hunger Games #3) - £20.44
#
# Harry Potter and the Sorcerer's Stone (Harry Potter #1) - £13.90
#
# Confessions of a Shopaholic (Shopaholic #1) - £48.94
#
# Zero History (Blue Ant #3) - £34.77
#
# World War Z: An Oral History of the Zombie War - £21.80
#
# Wild: From Lost to Found on the Pacific Crest Trail - £46.02
#
# Where'd You Go, Bernadette - £18.13
#
# Twilight (Twilight #1) - £41.93
#
# The Paris Wife - £36.80
#
# The Maze Runner (The Maze Runner #1) - £20.93
#
# The Lover's Dictionary - £58.09
#
# The Goldfinch - £43.58
#
# The Giver (The Giver Quartet #1) - £12.30
#
# The Girl Who Played with Fire (Millennium Trilogy #2) - £22.14
#
# The Demon-Haunted World: Science as a Candle in the Dark - £52.25
#
# The Book Thief - £53.49
#
# The Autobiography of Malcolm X - £23.43
#
# Shopaholic & Baby (Shopaholic #5) - £46.45
#
# Quiet: The Power of Introverts in a World That Can't Stop Talking - £43.55
#
# Packing for Mars: The Curious Science of Life in the Void - £56.68
#
# Orange Is the New Black - £24.61
#
# One for the Money (Stephanie Plum #1) - £32.87
#
# Morning Star (Red Rising #3) - £29.40
#
# Life After Life - £26.13
#
# Lean In: Women, Work, and the Will to Lead - £25.02
#
# Is Everyone Hanging Out Without Me? (And Other Concerns) - £20.11
#
# Gone Girl - £37.60
#
# Fellside - £38.62
#
# Eclipse (Twilight #3) - £18.74
#
# Dracula - £52.62
#
# Dead Wake: The Last Crossing of the Lusitania - £39.24
#
# David and Goliath: Underdogs, Misfits, and the Art of Battling Giants - £17.81
#
# Dark Places - £23.90
#
# Breaking Dawn (Twilight #4) - £35.28
#
# Beautiful Creatures (Caster Chronicles #1) - £21.55
#
# A Visit from the Goon Squad - £14.08
#
# The Zombie Room - £19.69
#
# The Name of the Wind (The Kingkiller Chronicle #1) - £50.59
#
# Taking Shots (Assassins #1) - £18.88
#
# Shatter Me (Shatter Me #1) - £42.40
#
# Paradise Lost (Paradise #1) - £24.96
#
# On the Road (Duluoz Legend) - £32.36
#
# Jane Eyre - £38.43
#
# Frankenstein - £38.00
#
# Mesaerion: The Best Science Fiction Stories 1800-1849 - £37.59
#
# Join - £35.67
#
# William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4) - £43.30
#
# The Project - £10.65
#
# Soft Apocalypse - £26.12
#
# Sleeping Giants (Themis Files #1) - £48.74
#
# Arena - £21.36
#
# Foundation (Foundation (Publication Order) #1) - £32.42
#
# The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2) - £10.92
#
# Ready Player One - £19.07
#
# Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3) - £33.26
#
# Dune (Dune #1) - £54.86
#
# Do Androids Dream of Electric Sheep? (Blade Runner #1) - £51.48
#
# Three Wishes (River of Time: California #1) - £44.18
#
# The Last Girl (The Dominion Trilogy #1) - £36.26
#
# Having the Barbarian's Baby (Ice Planet Barbarians #7.5) - £34.96
#
# The Book of Basketball: The NBA According to The Sports Guy - £44.84
#
# Friday Night Lights: A Town, a Team, and a Dream - £51.22
#
# Sugar Rush (Offensive Line #2) - £24.42
#
# Settling the Score (The Summer Games #1) - £44.91
#
# Icing (Aces Hockey #2) - £40.44
#
# The Torch Is Passed: A Harding Family Story - £19.09
#
# The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy - £23.89
#
# The Art Forger - £40.76
#
# On a Midnight Clear - £14.07
#
# Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners) - £53.90
#
# Shobu Samurai, Project Aryoku (#3) - £29.06
#
# Modern Romance - £28.26
#
# The White Queen (The Cousins' War #1) - £25.91
#
# The Song of Achilles - £37.40
#
# The Immortal Life of Henrietta Lacks - £40.67
#
# The Dovekeepers - £48.78
#
# More Than Music (Chasing the Dream #1) - £37.61
#
# Code Name Verity (Code Name Verity #1) - £22.13
#
# Cell - £20.29
#
# Angels Walking (Angels Walking #1) - £34.20
#
# A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer - £56.48
#
# A People's History of the United States - £40.79
#
# A Brush of Wings (Angels Walking #3) - £55.51
#
# Rook - £37.86
#
# The Midnight Watch: A Novel of the Titanic and the Californian - £26.20
#
# The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore - £59.15
#
# The Children - £11.88
#
# One with You (Crossfire #5) - £15.71
#
# Without Shame - £48.27
#
# Watchmen - £58.05
#
# A Hero's Curse (The Unseen Chronicles #1) - £50.49
#
# 23 Degrees South: A Tropical Tale of Changing Whether... - £35.79
#
# The Glass Castle - £16.24
#
# The Drowning Girls - £35.67
#
# Team of Rivals: The Political Genius of Abraham Lincoln - £20.12
#
# John Adams - £57.43
#
# Good in Bed (Cannie Shapiro #1) - £37.05
#
# The Joy of Cooking - £43.27
#
# The Golden Compass (His Dark Materials #1) - £18.77
#
# The God Delusion - £46.85
#
# Pride and Prejudice - £19.27
#
# Mere Christianity - £48.51
#
# Fun Home: A Family Tragicomic - £56.59
#
# The Raven King (The Raven Cycle #4) - £30.57
#
# Find Her (Detective D.D. Warren #8) - £22.37
#
# Evicted: Poverty and Profit in the American City - £42.27
#
# A Game of Thrones (A Song of Ice and Fire #1) - £46.42
#
# A Clash of Kings (A Song of Ice and Fire #2) - £10.79
#
# The Tipping Point: How Little Things Can Make a Big Difference - £10.02
#
# The Rest Is Noise: Listening to the Twentieth Century - £34.77
#
# The Purpose Driven Life: What on Earth Am I Here for? - £37.19
#
# The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1) - £47.80
#
# The Girl Who Kicked the Hornet's Nest (Millennium Trilogy #3) - £57.48
#
# The End of Faith: Religion, Terror, and the Future of Reason - £22.13
#
# The Complete Poems - £41.32
#
# The Catcher in the Rye - £24.55
#
# The Case for Christ (Cases for Christianity) - £47.84
#
# The Blind Side: Evolution of a Game - £53.71
#
# Seven Days in the Art World - £52.33
#
# Sarah's Key - £46.29
#
# Rogue Lawyer (Rogue Lawyer #1) - £50.11
#
# Manuscript Found in Accra - £34.98
#
# Fire Bound (Sea Haven/Sisters of the Heart #5) - £21.28
#
# Cosmos - £36.17
#
# #GIRLBOSS - £50.96
#
# The Sense of an Ending - £31.38
#
# The Republic - £33.78
#
# The Odyssey - £29.64
#
# The Light of the Fireflies - £54.43
#
# The Iliad - £16.16
#
# The Communist Manifesto - £14.76
#
# Lord of the Flies - £24.89
#
# Unicorn Tracks - £18.78
#
# Saga, Volume 6 (Saga (Collected Editions) #6) - £25.02
#
# Princess Between Worlds (Wide-Awake Princess #5) - £13.34
#
# Masks and Shadows - £56.40
#
# Crown of Midnight (Throne of Glass #2) - £43.29
#
# Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3) - £28.09
#
# A Court of Thorns and Roses (A Court of Thorns and Roses #1) - £52.37
#
# Throne of Glass (Throne of Glass #1) - £35.07
#
# The Glittering Court (The Glittering Court #1) - £44.28
#
# Hollow City (Miss Peregrine’s Peculiar Children #2) - £42.98
#
# The Star-Touched Queen - £46.02
#
# The Hidden Oracle (The Trials of Apollo #1) - £52.26
#
# The Bane Chronicles (The Bane Chronicles #1-11) - £44.73
#
# Island of Dragons (Unwanteds #7) - £29.65
#
# Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3) - £37.51
#
# City of Glass (The Mortal Instruments #3) - £56.02
#
# Searching for Meaning in Gailana - £38.73
#
# The Star-Touched Queen - £32.30
#
# A Shard of Ice (The Black Symphony Saga #1) - £56.63
#
# King's Folly (The Kinsman Chronicles #1) - £39.61
#
# Every Heart a Doorway (Every Heart A Doorway #1) - £12.16
#
# A Gathering of Shadows (Shades of Magic #2) - £44.81
#
# The Raven Boys (The Raven Cycle #1) - £57.74
#
# The False Prince (The Ascendance Trilogy #1) - £56.00
#
# Tell the Wind and Fire - £45.51
#
# A Feast for Crows (A Song of Ice and Fire #4) - £17.21
#
# The Demonists (Demonist #1) - £52.11
#
# The Beast (Black Dagger Brotherhood #14) - £46.08
#
# Paper and Fire (The Great Library #2) - £49.45
#
# Harry Potter and the Order of the Phoenix (Harry Potter #5) - £31.63
#
# Harry Potter and the Half-Blood Prince (Harry Potter #6) - £48.75
#
# Harry Potter and the Chamber of Secrets (Harry Potter #2) - £14.74
#
# The Rose & the Dagger (The Wrath and the Dawn #2) - £58.64
#
# Soldier (Talon #3) - £24.72
#
# Midnight Riot (Peter Grant/ Rivers of London - books #1) - £55.46
#
# Heir to the Sky - £44.07
#
# Eragon (The Inheritance Cycle #1) - £43.87
#
# Darkfever (Fever #1) - £56.02
#
# Ash - £22.06
#
# A Storm of Swords (A Song of Ice and Fire #3) - £31.22
#
# Vampire Girl (Vampire Girl #1) - £53.82
#
# The Silent Twin (Detective Jennifer Knight #3) - £36.25
#
# The Mirror & the Maze (The Wrath and the Dawn #1.5) - £29.38
#
# Sister Sable (The Mad Queen #1) - £13.33
#
# Shadow Rites (Jane Yellowrock #10) - £21.72
#
# Origins (Alphas 0.5) - £28.99
#
# One Second (Seven #7) - £52.94
#
# Myriad (Prentor #1) - £58.75
#
# Without Borders (Wanderlove #1) - £45.07
#
# The Mistake (Off-Campus #2) - £43.29
#
# The Matchmaker's Playbook (Wingmen Inc. #1) - £55.85
#
# The Hook Up (Game On #1) - £36.29
#
# Shameless - £58.35
#
# Off Sides (Off #1) - £39.45
#
# The Requiem Red - £22.65
#
# Set Me Free - £17.46
#
# The Natural History of Us (The Fine Art of Pretending #2) - £45.22
#
# Obsidian (Lux #1) - £14.86
#
# Burning - £28.81
#
# A Fierce and Subtle Poison - £28.13
#
# Scarlett Epstein Hates It Here - £43.55
#
# Nightingale, Sing - £38.28
#
# Library of Souls (Miss Peregrine’s Peculiar Children #3) - £48.56
#
# Frostbite (Vampire Academy #2) - £29.99
#
# Wild Swans - £14.36
#
# Until Friday Night (The Field Party #1) - £46.31
#
# This Is Where It Ends - £27.12
#
# The Darkest Lie - £35.35
#
# My Kind of Crazy - £40.36
#
# Don't Get Caught - £55.35
#
# Catching Jordan (Hundred Oaks) - £50.83
#
# Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1) - £58.14
#
# The Epidemic (The Program 0.6) - £14.44
#
# Stars Above (The Lunar Chronicles #4.5) - £48.05
#
# No Love Allowed (Dodge Cove #1) - £54.65
#
# Exit, Pursued by a Bear - £51.34
#
# The Alien Club - £54.40
#
# Don't Forget Steven - £33.23
#
# South of Sunshine - £28.93
#
# My Life Next Door (My Life Next Door ) - £36.39
#
# Future Shock (Future Shock #1) - £55.65
#
# Nightstruck: A Novel - £50.35
#
# Tell the Wolves I'm Home - £50.96
#
# Will Grayson, Will Grayson (Will Grayson, Will Grayson) - £47.31
#
# Where She Went (If I Stay #2) - £41.73
#
# Two Summers - £14.64
#
# The Darkest Corners - £11.33
#
# Tell Me Three Things - £41.81
#
# Lola and the Boy Next Door (Anna and the French Kiss #2) - £23.63
#
# Kill the Boy Band - £15.52
#
# Isla and the Happily Ever After (Anna and the French Kiss #3) - £48.13
#
# An Abundance of Katherines - £10.00
#
# Harry Potter and the Prisoner of Azkaban (Harry Potter #3) - £24.17
#
# Walk the Edge (Thunder Road #2) - £32.36
#
# Two Boys Kissing - £32.74
#
# The New Guy (and Other Senior Year Distractions) - £44.92
#
# The Land of 10,000 Madonnas - £29.64
#
# Scarlet (The Lunar Chronicles #2) - £14.57
#
# Legend (Legend #1) - £43.69
#
# Lady Renegades (Rebel Belle #3) - £53.04
#
# Golden (Heart of Dread #3) - £42.21
#
# Cinder (The Lunar Chronicles #1) - £26.09
#
# Boy Meets Boy - £21.12
#
# Annie on My Mind - £36.83
#
# New Moon (Twilight #2) - £12.86
#
# Girl Online On Tour (Girl Online #2) - £53.47
#
# The Haters - £27.89
#
# The Art of Not Breathing - £40.83
#
# The Most Perfect Thing: Inside (and Outside) a Bird's Egg - £42.96
#
# Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine - £57.36
#
# Sorting the Beef from the Bull: The Science of Food Fraud Forensics - £44.74
#
# Tipping Point for Planet Earth: How Close Are We to the Edge? - £37.55
#
# The Fabric of the Cosmos: Space, Time, and the Texture of Reality - £55.91
#
# Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World - £28.41
#
# The Origin of Species - £10.01
#
# The Grand Design - £13.76
#
# Peak: Secrets from the New Science of Expertise - £16.28
#
# The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory - £13.03
#
# The Disappearing Spoon: And Other True Tales of Madness, Love, and the History of the World from the Periodic Table of the Elements - £57.35
#
# Surely You're Joking, Mr. Feynman!: Adventures of a Curious Character - £25.83
#
# Seven Brief Lessons on Physics - £30.60
#
# The Selfish Gene - £29.45
#
# A Light in the Attic - £51.77
#
# The Black Maria - £52.15
#
# Shakespeare's Sonnets - £20.66
#
# Olio - £23.88
#
# You can't bury them all: Poems - £33.63
#
# Slow States of Collapse: Poems - £57.31
#
# Untitled Collection: Sabbath Poems 2014 - £14.27
#
# Poems That Make Grown Women Cry - £14.19
#
# Night Sky with Exit Wounds - £41.05
#
# salt. - £46.78
#
# Quarter Life Poetry: Poems for the Young, Broke and Hangry - £50.89
#
# Out of Print: City Lights Spotlight No. 14 - £53.64
#
# Les Fleurs du Mal - £29.04
#
# Howl and Other Poems - £40.45
#
# Leave This Song Behind: Teen Poetry at Its Best - £51.17
#
# The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1) - £15.42
#
# The Crossover - £38.77
#
# Booked - £17.49
#
# Twenty Love Poems and a Song of Despair - £30.95
#
# Vampire Knight, Vol. 1 (Vampire Knight #1) - £15.40
#
# Wall and Piece - £44.18
#
# Feathers: Displays of Brilliant Plumage - £49.05
#
# Art and Fear: Observations on the Perils (and Rewards) of Artmaking - £48.63
#
# The New Drawing on the Right Side of the Brain - £43.02
#
# History of Beauty - £10.29
#
# The Story of Art - £41.14
#
# The Art Book - £32.34
#
# Ways of Seeing - £39.51
#
# The Lucifer Effect: Understanding How Good People Turn Evil - £10.40
#
# The Golden Condom: And Other Essays on Love Lost and Found - £39.43
#
# It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle - £56.27
#
# An Unquiet Mind: A Memoir of Moods and Madness - £21.30
#
# Thinking, Fast and Slow - £21.14
#
# Civilization and Its Discontents - £59.95
#
# 8 Keys to Mental Health Through Exercise - £31.04
#
# The Argonauts - £10.93
#
# M Train - £27.18
#
# Lab Girl - £40.85
#
# Approval Junkie: Adventures in Caring Too Much - £58.81
#
# Running with Scissors - £12.91
#
# Me Talk Pretty One Day - £57.60
#
# Lust & Wonder - £11.87
#
# Life Without a Recipe - £59.04
#
# A Heartbreaking Work of Staggering Genius - £54.29
#
# Catastrophic Happiness: Finding Joy in Childhood's Messy Years - £37.35
#
# Fifty Shades Freed (Fifty Shades #3) - £15.36
#
# The Long Haul (Diary of a Wimpy Kid #9) - £44.07
#
# Old School (Diary of a Wimpy Kid #10) - £11.83
#
# I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction - £25.98
#
# Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened - £14.75
#
# Dress Your Family in Corduroy and Denim - £43.68
#
# Toddlers Are A**holes: It's Not Your Fault - £25.55
#
# When You Are Engulfed in Flames - £30.89
#
# Naked - £31.69
#
# Lamb: The Gospel According to Biff, Christ's Childhood Pal - £55.50
#
# Holidays on Ice - £51.07
#
# Security - £39.25
#
# Follow You Home - £21.36
#
# The Loney - £23.40
#
# Pet Sematary - £10.56
#
# Doctor Sleep (The Shining #2) - £40.12
#
# Psycho: Sanitarium (Psycho #1.5) - £36.97
#
# Can You Keep a Secret? (Fear Street Relaunch #4) - £48.64
#
# Red Dragon (Hannibal Lecter #1) - £23.37
#
# Dracula the Un-Dead - £35.63
#
# Night Shift (Night Shift #1-20) - £12.75
#
# Needful Things - £47.51
#
# Misery - £34.79
#
# It - £25.01
#
# 'Salem's Lot - £49.56
#
# The Stand - £57.86
#
# The Girl with All the Gifts - £49.47
#
# House of Leaves - £54.89
#
# Sapiens: A Brief History of Humankind - £54.23
#
# Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink - £25.52
#
# The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind - £19.73
#
# Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics - £36.28
#
# Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History - £59.64
#
# Zealot: The Life and Times of Jesus of Nazareth - £24.70
#
# A Distant Mirror: The Calamitous 14th Century - £14.58
#
# 1491: New Revelations of the Americas Before Columbus - £21.80
#
# Brilliant Beacons: A History of the American Lighthouse - £11.45
#
# "Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination - £44.48
#
# A Short History of Nearly Everything - £52.40
#
# The Rise and Fall of the Third Reich: A History of Nazi Germany - £39.67
#
# Catherine the Great: Portrait of a Woman - £58.55
#
# The Mathews Men: Seven Brothers and the War Against Hitler's U-boats - £42.91
#
# The Hiding Place - £55.91
#
# America's War for the Greater Middle East: A Military History - £51.22
#
# The Guns of August - £14.54
#
# House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth - £43.70
#
# Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More - £30.52
#
# The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper! - £56.41
#
# My Paris Kitchen: Recipes and Stories - £33.37
#
# Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed - £14.02
#
# Layered: Baking, Building, and Styling Spectacular Cakes - £40.11
#
# The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us - £37.34
#
# The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking - £37.60
#
# The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First - £41.25
#
# Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals - £42.16
#
# The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth - £28.77
#
# It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes - £19.55
#
# Barefoot Contessa Back to Basics - £28.01
#
# Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again - £50.62
#
# My Kitchen Year: 136 Recipes That Saved My Life - £11.53
#
# Everyday Italian: 125 Simple and Delicious Recipes - £20.10
#
# A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More - £38.77
#
# Cravings: Recipes for What You Want to Eat - £20.50
#
# The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York - £12.34
#
# 32 Yolks - £53.63
#
# Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories - £11.38
#
# How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything) - £46.01
#
# How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking - £28.25
#
# The Barefoot Contessa Cookbook - £59.92
#
# Better Homes and Gardens New Cook Book - £39.61
#
# The Power Greens Cookbook: 140 Delicious Superfood Recipes - £11.05
#
# Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens - £24.91
#
# Vegan Vegetarian Omnivore: Dinner for Everyone at the Table - £13.66
#
# The Smitten Kitchen Cookbook - £23.59
#
# The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution - £34.32
#
# Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World - £33.14
#
# Redeeming Love - £20.47
#
# Close to You - £49.46
#
# Shadows of the Past (Logan Point #1) - £39.67
#
# Like Never Before (Walker Family #2) - £28.77
#
# Counted With the Stars (Out from Egypt #1) - £17.97
#
# If I Run (If I Run #1) - £49.97
#
# The Dirty Little Secrets of Getting Your Dream Job - £33.34
#
# The Third Wave: An Entrepreneur’s Vision of the Future - £12.61
#
# The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job - £27.55
#
# Shoe Dog: A Memoir by the Creator of NIKE - £23.99
#
# Made to Stick: Why Some Ideas Survive and Others Die - £38.85
#
# Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two - £43.14
#
# The Art of Startup Fundraising - £21.00
#
# Born for This: How to Find the Work You Were Meant to Do - £21.59
#
# The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It - £36.91
#
# Rich Dad, Poor Dad - £51.74
#
# The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses - £33.92
#
# Rework - £44.88
#
# Louisa: The Extraordinary Life of Mrs. Adams - £16.85
#
# Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena - £21.15
#
# The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist - £39.55
#
# Benjamin Franklin: An American Life - £48.19
#
# The Rise of Theodore Roosevelt (Theodore Roosevelt #1) - £42.57
#
# In Her Wake - £12.84
#
# The Elephant Tree - £23.82
#
# Behind Closed Doors - £52.22
#
# You (You #1) - £43.61
#
# The Guilty (Will Robie #4) - £13.82
#
# The 14th Colony (Cotton Malone #11) - £39.24
#
# Give It Back - £18.32
#
# Killing Floor (Jack Reacher #1) - £31.49
#
# The Bone Hunters (Lexy Vaughan & Steven Macaulay #2) - £59.71
#
# Far From True (Promise Falls Trilogy #2) - £34.93
#
# The Travelers - £15.77
#
# When We Collided - £31.77
#
# Someone Like You (The Harrisons #2) - £52.79
#
# We Are All Completely Beside Ourselves - £24.04
#
# The Four Agreements: A Practical Guide to Personal Freedom - £17.66
#
# The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution - £32.24
#
# Chasing Heaven: What Dying Taught Me About Living - £37.80
#
# If I Gave You God's Phone Number....: Searching for Spirituality in America - £20.91
#
# Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain - £46.33
#
# A New Earth: Awakening to Your Life's Purpose - £55.65
#
# Logan Kade (Fallen Crest High #5.5) - £13.12
#
# Online Marketing for Busy Authors: A Step-By-Step Guide - £46.35
#
# How to Be Miserable: 40 Strategies You Already Use - £46.03
#
# Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress - £52.15
#
# You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life - £12.08
#
# How to Stop Worrying and Start Living - £46.49
#
# All the Light We Cannot See - £29.87
#
# The Girl You Left Behind (The Girl You Left Behind #1) - £15.79
#
# (Un)Qualified: How God Uses Broken People to Do Big Things - £54.00
#
# Crazy Love: Overwhelmed by a Relentless God - £47.72
#
# Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality - £25.77
#
# Silence in the Dark (Logan Point #4) - £58.33
#
# The Grownup - £35.88
#
# Suzie Snowflake: One beautiful flake (a self-esteem story) - £54.81
#
# The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life - £49.05
#
# Eat Fat, Get Thin - £54.07
#
# 10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days! - £49.71
#
# The Art and Science of Low Carbohydrate Living - £52.98
#
# Libertarianism for Beginners - £51.33
#
# Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond - £52.65
#
# Equal Is Unfair: America's Misguided Fight Against Income Inequality - £56.86
#
# Amid the Chaos - £36.58
#
# Dark Notes - £19.19
#
# The Long Shadow of Small Ghosts: Murder and Memory in an American City - £10.97

# %% [markdown]
# ## You Have Some questions To Answer!

# %% [markdown]
# #### 01) Write a sql query to get books that has rate >=3 and has 'Mr' in its name.

# %%
qry = '''
SELECT * FROM books_catalog 
WHERE rating >= 3 AND title LIKE '%Mr%';
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(48,
#   'Mrs. Houdini',
#   'http://books.toscrape.com/catalogue/mrs-houdini_821/index.html',
#   Decimal('30.25'),
#   'In stock',
#   5,
#   3),
#  (243,
#   'My Mrs. Brown',
#   'http://books.toscrape.com/catalogue/my-mrs-brown_719/index.html',
#   Decimal('24.48'),
#   'In stock',
#   3,
#   9),
#  (248,
#   'Dear Mr. Knightley',
#   'http://books.toscrape.com/catalogue/dear-mr-knightley_684/index.html',
#   Decimal('11.21'),
#   'In stock',
#   3,
#   9),
#  (952,
#   'Louisa: The Extraordinary Life of Mrs. Adams',
#   'http://books.toscrape.com/catalogue/louisa-the-extraordinary-life-of-mrs-adams_818/index.html',
#   Decimal('16.85'),
#   'In stock',
#   3,
#   35)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    book_id                                         title  \
# 0       48                                  Mrs. Houdini
# 1      243                                 My Mrs. Brown
# 2      248                            Dear Mr. Knightley
# 3      952  Louisa: The Extraordinary Life of Mrs. Adams
#
#                                                  url  price availability  \
# 0  http://books.toscrape.com/catalogue/mrs-houdin...  30.25     In stock
# 1  http://books.toscrape.com/catalogue/my-mrs-bro...  24.48     In stock
# 2  http://books.toscrape.com/catalogue/dear-mr-kn...  11.21     In stock
# 3  http://books.toscrape.com/catalogue/louisa-the...  16.85     In stock
#
#    rating  category_id
# 0       5            3
# 1       3            9
# 2       3            9
# 3       3           35

# %% [markdown]
# #### 02) Write a sql query to get books that has rate >=3 or price > 20.

# %%
qry = '''
SELECT * FROM books_catalog 
WHERE rating >= 3 OR price > 20;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(1,
#   "It's Only the Himalayas",
#   'http://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html',
#   Decimal('45.17'),
#   'In stock',
#   2,
#   1),
#  (2,
#   'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#   'http://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html',
#   Decimal('49.43'),
#   'In stock',
#   4,
#   1),
#  (3,
#   'See America: A Celebration of Our National Parks & Treasured Sites',
#   'http://books.toscrape.com/catalogue/see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html',
#   Decimal('48.87'),
#   'In stock',
#   3,
#   1),
#  (4,
#   'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   'http://books.toscrape.com/catalogue/vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html',
#   Decimal('36.94'),
#   'In stock',
#   2,
#   1),
#  (5,
#   'Under the Tuscan Sun',
#   'http://books.toscrape.com/catalogue/under-the-tuscan-sun_504/index.html',
#   Decimal('37.33'),
#   'In stock',
#   3,
#   1),
#  (6,
#   'A Summer In Europe',
#   'http://books.toscrape.com/catalogue/a-summer-in-europe_458/index.html',
#   Decimal('44.34'),
#   'In stock',
#   2,
#   1),
#  (7,
#   'The Great Railway Bazaar',
#   'http://books.toscrape.com/catalogue/the-great-railway-bazaar_446/index.html',
#   Decimal('30.54'),
#   'In stock',
#   1,
#   1),
#  (8,
#   'A Year in Provence (Provence #1)',
#   'http://books.toscrape.com/catalogue/a-year-in-provence-provence-1_421/index.html',
#   Decimal('56.88'),
#   'In stock',
#   4,
#   1),
#  (9,
#   'The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#   'http://books.toscrape.com/catalogue/the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html',
#   Decimal('23.21'),
#   'In stock',
#   1,
#   1),
#  (10,
#   'Neither Here nor There: Travels in Europe',
#   'http://books.toscrape.com/catalogue/neither-here-nor-there-travels-in-europe_198/index.html',
#   Decimal('38.95'),
#   'In stock',
#   3,
#   1),
#  (11,
#   '1,000 Places to See Before You Die',
#   'http://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html',
#   Decimal('26.08'),
#   'In stock',
#   5,
#   1),
#  (12,
#   'Sharp Objects',
#   'http://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#   Decimal('47.82'),
#   'In stock',
#   4,
#   2),
#  (13,
#   'In a Dark, Dark Wood',
#   'http://books.toscrape.com/catalogue/in-a-dark-dark-wood_963/index.html',
#   Decimal('19.63'),
#   'In stock',
#   3,
#   2),
#  (14,
#   'The Past Never Ends',
#   'http://books.toscrape.com/catalogue/the-past-never-ends_942/index.html',
#   Decimal('56.50'),
#   'In stock',
#   4,
#   2),
#  (15,
#   'A Murder in Time',
#   'http://books.toscrape.com/catalogue/a-murder-in-time_877/index.html',
#   Decimal('16.64'),
#   'In stock',
#   3,
#   2),
#  (16,
#   'The Murder of Roger Ackroyd (Hercule Poirot #4)',
#   'http://books.toscrape.com/catalogue/the-murder-of-roger-ackroyd-hercule-poirot-4_852/index.html',
#   Decimal('44.10'),
#   'In stock',
#   4,
#   2),
#  (18,
#   'That Darkness (Gardiner and Renner #1)',
#   'http://books.toscrape.com/catalogue/that-darkness-gardiner-and-renner-1_743/index.html',
#   Decimal('13.92'),
#   'In stock',
#   3,
#   2),
#  (19,
#   'Tastes Like Fear (DI Marnie Rome #3)',
#   'http://books.toscrape.com/catalogue/tastes-like-fear-di-marnie-rome-3_742/index.html',
#   Decimal('10.69'),
#   'In stock',
#   3,
#   2),
#  (20,
#   'A Time of Torment (Charlie Parker #14)',
#   'http://books.toscrape.com/catalogue/a-time-of-torment-charlie-parker-14_657/index.html',
#   Decimal('48.35'),
#   'In stock',
#   5,
#   2),
#  (21,
#   'A Study in Scarlet (Sherlock Holmes #1)',
#   'http://books.toscrape.com/catalogue/a-study-in-scarlet-sherlock-holmes-1_656/index.html',
#   Decimal('16.73'),
#   'In stock',
#   3,
#   2),
#  (22,
#   'Poisonous (Max Revere Novels #3)',
#   'http://books.toscrape.com/catalogue/poisonous-max-revere-novels-3_627/index.html',
#   Decimal('26.80'),
#   'In stock',
#   3,
#   2),
#  (23,
#   'Murder at the 42nd Street Library (Raymond Ambler #1)',
#   'http://books.toscrape.com/catalogue/murder-at-the-42nd-street-library-raymond-ambler-1_624/index.html',
#   Decimal('54.36'),
#   'In stock',
#   4,
#   2),
#  (24,
#   'Most Wanted',
#   'http://books.toscrape.com/catalogue/most-wanted_623/index.html',
#   Decimal('35.28'),
#   'In stock',
#   3,
#   2),
#  (25,
#   'Hide Away (Eve Duncan #20)',
#   'http://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html',
#   Decimal('11.84'),
#   'In stock',
#   3,
#   2),
#  (26,
#   'Boar Island (Anna Pigeon #19)',
#   'http://books.toscrape.com/catalogue/boar-island-anna-pigeon-19_613/index.html',
#   Decimal('59.48'),
#   'In stock',
#   3,
#   2),
#  (27,
#   'The Widow',
#   'http://books.toscrape.com/catalogue/the-widow_609/index.html',
#   Decimal('27.26'),
#   'In stock',
#   2,
#   2),
#  (28,
#   'Playing with Fire',
#   'http://books.toscrape.com/catalogue/playing-with-fire_602/index.html',
#   Decimal('13.71'),
#   'In stock',
#   3,
#   2),
#  (29,
#   'What Happened on Beale Street (Secrets of the South Mysteries #2)',
#   'http://books.toscrape.com/catalogue/what-happened-on-beale-street-secrets-of-the-south-mysteries-2_506/index.html',
#   Decimal('25.37'),
#   'In stock',
#   5,
#   2),
#  (30,
#   "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#   'http://books.toscrape.com/catalogue/the-bachelor-girls-guide-to-murder-herringford-and-watts-mysteries-1_491/index.html',
#   Decimal('52.30'),
#   'In stock',
#   5,
#   2),
#  (31,
#   'Delivering the Truth (Quaker Midwife Mystery #1)',
#   'http://books.toscrape.com/catalogue/delivering-the-truth-quaker-midwife-mystery-1_464/index.html',
#   Decimal('20.89'),
#   'In stock',
#   4,
#   2),
#  (32,
#   'The Mysterious Affair at Styles (Hercule Poirot #1)',
#   'http://books.toscrape.com/catalogue/the-mysterious-affair-at-styles-hercule-poirot-1_452/index.html',
#   Decimal('24.80'),
#   'In stock',
#   4,
#   2),
#  (33,
#   'In the Woods (Dublin Murder Squad #1)',
#   'http://books.toscrape.com/catalogue/in-the-woods-dublin-murder-squad-1_433/index.html',
#   Decimal('38.38'),
#   'In stock',
#   2,
#   2),
#  (34,
#   'The Silkworm (Cormoran Strike #2)',
#   'http://books.toscrape.com/catalogue/the-silkworm-cormoran-strike-2_280/index.html',
#   Decimal('23.05'),
#   'In stock',
#   5,
#   2),
#  (35,
#   'The Exiled',
#   'http://books.toscrape.com/catalogue/the-exiled_247/index.html',
#   Decimal('43.45'),
#   'In stock',
#   3,
#   2),
#  (36,
#   "The Cuckoo's Calling (Cormoran Strike #1)",
#   'http://books.toscrape.com/catalogue/the-cuckoos-calling-cormoran-strike-1_239/index.html',
#   Decimal('19.21'),
#   'In stock',
#   3,
#   2),
#  (37,
#   'Extreme Prey (Lucas Davenport #26)',
#   'http://books.toscrape.com/catalogue/extreme-prey-lucas-davenport-26_154/index.html',
#   Decimal('25.40'),
#   'In stock',
#   3,
#   2),
#  (38,
#   'Career of Evil (Cormoran Strike #3)',
#   'http://books.toscrape.com/catalogue/career-of-evil-cormoran-strike-3_137/index.html',
#   Decimal('24.72'),
#   'In stock',
#   2,
#   2),
#  (39,
#   "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#   'http://books.toscrape.com/catalogue/the-no-1-ladies-detective-agency-no-1-ladies-detective-agency-1_76/index.html',
#   Decimal('57.70'),
#   'In stock',
#   4,
#   2),
#  (40,
#   'The Girl You Lost',
#   'http://books.toscrape.com/catalogue/the-girl-you-lost_66/index.html',
#   Decimal('12.29'),
#   'In stock',
#   3,
#   2),
#  (41,
#   'The Girl In The Ice (DCI Erika Foster #1)',
#   'http://books.toscrape.com/catalogue/the-girl-in-the-ice-dci-erika-foster-1_65/index.html',
#   Decimal('15.85'),
#   'In stock',
#   3,
#   2),
#  (42,
#   'Blood Defense (Samantha Brinkman #1)',
#   'http://books.toscrape.com/catalogue/blood-defense-samantha-brinkman-1_8/index.html',
#   Decimal('20.30'),
#   'In stock',
#   3,
#   2),
#  (45,
#   'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#   'http://books.toscrape.com/catalogue/forever-and-forever-the-courtship-of-henry-longfellow-and-fanny-appleton_894/index.html',
#   Decimal('29.69'),
#   'In stock',
#   3,
#   3),
#  (46,
#   'A Flight of Arrows (The Pathfinders #2)',
#   'http://books.toscrape.com/catalogue/a-flight-of-arrows-the-pathfinders-2_876/index.html',
#   Decimal('55.53'),
#   'In stock',
#   5,
#   3),
#  (47,
#   'The House by the Lake',
#   'http://books.toscrape.com/catalogue/the-house-by-the-lake_846/index.html',
#   Decimal('36.95'),
#   'In stock',
#   1,
#   3),
#  (48,
#   'Mrs. Houdini',
#   'http://books.toscrape.com/catalogue/mrs-houdini_821/index.html',
#   Decimal('30.25'),
#   'In stock',
#   5,
#   3),
#  (49,
#   'The Marriage of Opposites',
#   'http://books.toscrape.com/catalogue/the-marriage-of-opposites_759/index.html',
#   Decimal('28.08'),
#   'In stock',
#   4,
#   3),
#  (50,
#   'Glory over Everything: Beyond The Kitchen House',
#   'http://books.toscrape.com/catalogue/glory-over-everything-beyond-the-kitchen-house_696/index.html',
#   Decimal('45.84'),
#   'In stock',
#   3,
#   3),
#  (51,
#   'Love, Lies and Spies',
#   'http://books.toscrape.com/catalogue/love-lies-and-spies_622/index.html',
#   Decimal('20.55'),
#   'In stock',
#   2,
#   3),
#  (52,
#   'A Paris Apartment',
#   'http://books.toscrape.com/catalogue/a-paris-apartment_612/index.html',
#   Decimal('39.01'),
#   'In stock',
#   4,
#   3),
#  (53,
#   'Lilac Girls',
#   'http://books.toscrape.com/catalogue/lilac-girls_597/index.html',
#   Decimal('17.28'),
#   'In stock',
#   3,
#   3),
#  (54,
#   'The Constant Princess (The Tudor Court #1)',
#   'http://books.toscrape.com/catalogue/the-constant-princess-the-tudor-court-1_493/index.html',
#   Decimal('16.62'),
#   'In stock',
#   3,
#   3),
#  (55,
#   'The Invention of Wings',
#   'http://books.toscrape.com/catalogue/the-invention-of-wings_448/index.html',
#   Decimal('37.34'),
#   'In stock',
#   1,
#   3),
#  (56,
#   'World Without End (The Pillars of the Earth #2)',
#   'http://books.toscrape.com/catalogue/world-without-end-the-pillars-of-the-earth-2_420/index.html',
#   Decimal('32.97'),
#   'In stock',
#   4,
#   3),
#  (57,
#   'The Passion of Dolssa',
#   'http://books.toscrape.com/catalogue/the-passion-of-dolssa_351/index.html',
#   Decimal('28.32'),
#   'In stock',
#   5,
#   3),
#  (58,
#   'Girl With a Pearl Earring',
#   'http://books.toscrape.com/catalogue/girl-with-a-pearl-earring_322/index.html',
#   Decimal('26.77'),
#   'In stock',
#   1,
#   3),
#  (59,
#   'Voyager (Outlander #3)',
#   'http://books.toscrape.com/catalogue/voyager-outlander-3_299/index.html',
#   Decimal('21.07'),
#   'In stock',
#   5,
#   3),
#  (60,
#   'The Red Tent',
#   'http://books.toscrape.com/catalogue/the-red-tent_273/index.html',
#   Decimal('35.66'),
#   'In stock',
#   5,
#   3),
#  (62,
#   'The Guernsey Literary and Potato Peel Pie Society',
#   'http://books.toscrape.com/catalogue/the-guernsey-literary-and-potato-peel-pie-society_253/index.html',
#   Decimal('49.53'),
#   'In stock',
#   1,
#   3),
#  (63,
#   'Girl in the Blue Coat',
#   'http://books.toscrape.com/catalogue/girl-in-the-blue-coat_160/index.html',
#   Decimal('46.83'),
#   'In stock',
#   2,
#   3),
#  (64,
#   'Between Shades of Gray',
#   'http://books.toscrape.com/catalogue/between-shades-of-gray_128/index.html',
#   Decimal('20.79'),
#   'In stock',
#   5,
#   3),
#  (65,
#   'While You Were Mine',
#   'http://books.toscrape.com/catalogue/while-you-were-mine_97/index.html',
#   Decimal('41.32'),
#   'In stock',
#   5,
#   3),
#  (66,
#   'The Secret Healer',
#   'http://books.toscrape.com/catalogue/the-secret-healer_80/index.html',
#   Decimal('34.56'),
#   'In stock',
#   3,
#   3),
#  (67,
#   'Starlark',
#   'http://books.toscrape.com/catalogue/starlark_56/index.html',
#   Decimal('25.83'),
#   'In stock',
#   3,
#   3),
#  (68,
#   'Lost Among the Living',
#   'http://books.toscrape.com/catalogue/lost-among-the-living_31/index.html',
#   Decimal('27.70'),
#   'In stock',
#   4,
#   3),
#  (69,
#   "A Spy's Devotion (The Regency Spies of London #1)",
#   'http://books.toscrape.com/catalogue/a-spys-devotion-the-regency-spies-of-london-1_3/index.html',
#   Decimal('16.97'),
#   'In stock',
#   3,
#   3),
#  (70,
#   "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   'http://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html',
#   Decimal('52.29'),
#   'In stock',
#   5,
#   4),
#  (71,
#   'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   'http://books.toscrape.com/catalogue/tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949/index.html',
#   Decimal('16.28'),
#   'In stock',
#   3,
#   4),
#  (72,
#   'This One Summer',
#   'http://books.toscrape.com/catalogue/this-one-summer_947/index.html',
#   Decimal('19.49'),
#   'In stock',
#   3,
#   4),
#  (73,
#   'The Nameless City (The Nameless City #1)',
#   'http://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html',
#   Decimal('38.16'),
#   'In stock',
#   4,
#   4),
#  (75,
#   'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#   'http://books.toscrape.com/catalogue/rat-queens-vol-3-demons-rat-queens-collected-editions-11-15_921/index.html',
#   Decimal('50.40'),
#   'In stock',
#   3,
#   4),
#  (76,
#   'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   'http://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html',
#   Decimal('13.61'),
#   'In stock',
#   3,
#   4),
#  (77,
#   'Pop Gun War, Volume 1: Gift',
#   'http://books.toscrape.com/catalogue/pop-gun-war-volume-1-gift_918/index.html',
#   Decimal('18.97'),
#   'In stock',
#   3,
#   4),
#  (78,
#   'Patience',
#   'http://books.toscrape.com/catalogue/patience_916/index.html',
#   Decimal('10.16'),
#   'In stock',
#   3,
#   4),
#  (79,
#   'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   'http://books.toscrape.com/catalogue/outcast-vol-1-a-darkness-surrounds-him-outcast-1_915/index.html',
#   Decimal('15.44'),
#   'In stock',
#   3,
#   4),
#  (80,
#   'orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   'http://books.toscrape.com/catalogue/orange-the-complete-collection-1-orange-the-complete-collection-1_914/index.html',
#   Decimal('48.41'),
#   'In stock',
#   1,
#   4),
#  (81,
#   'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   'http://books.toscrape.com/catalogue/lumberjanes-vol-2-friendship-to-the-max-lumberjanes-5-8_907/index.html',
#   Decimal('46.91'),
#   'In stock',
#   2,
#   4),
#  (82,
#   'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#   'http://books.toscrape.com/catalogue/lumberjanes-vol-1-beware-the-kitten-holy-lumberjanes-1-4_906/index.html',
#   Decimal('45.61'),
#   'In stock',
#   3,
#   4),
#  (83,
#   'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   'http://books.toscrape.com/catalogue/lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905/index.html',
#   Decimal('19.92'),
#   'In stock',
#   3,
#   4),
#  (84,
#   'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   'http://books.toscrape.com/catalogue/i-hate-fairyland-vol-1-madly-ever-after-i-hate-fairyland-compilations-1-5_899/index.html',
#   Decimal('29.17'),
#   'In stock',
#   2,
#   4),
#  (85,
#   'I am a Hero Omnibus Volume 1',
#   'http://books.toscrape.com/catalogue/i-am-a-hero-omnibus-volume-1_898/index.html',
#   Decimal('54.63'),
#   'In stock',
#   3,
#   4),
#  (86,
#   'Giant Days, Vol. 2 (Giant Days #5-8)',
#   'http://books.toscrape.com/catalogue/giant-days-vol-2-giant-days-5-8_895/index.html',
#   Decimal('22.11'),
#   'In stock',
#   2,
#   4),
#  (87,
#   'Danganronpa Volume 1',
#   'http://books.toscrape.com/catalogue/danganronpa-volume-1_889/index.html',
#   Decimal('51.99'),
#   'In stock',
#   4,
#   4),
#  (88,
#   'Codename Baboushka, Volume 1: The Conclave of Death',
#   'http://books.toscrape.com/catalogue/codename-baboushka-volume-1-the-conclave-of-death_887/index.html',
#   Decimal('36.72'),
#   'In stock',
#   4,
#   4),
#  (89,
#   'Camp Midnight',
#   'http://books.toscrape.com/catalogue/camp-midnight_886/index.html',
#   Decimal('17.08'),
#   'In stock',
#   3,
#   4),
#  (90,
#   'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   'http://books.toscrape.com/catalogue/bitch-planet-vol-1-extraordinary-machine-bitch-planet-collected-editions_882/index.html',
#   Decimal('37.92'),
#   'In stock',
#   2,
#   4),
#  (91,
#   'The Shadow Hero (The Shadow Hero)',
#   'http://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html',
#   Decimal('33.14'),
#   'In stock',
#   1,
#   4),
#  (92,
#   'Fables, Vol. 1: Legends in Exile (Fables #1)',
#   'http://books.toscrape.com/catalogue/fables-vol-1-legends-in-exile-fables-1_806/index.html',
#   Decimal('41.62'),
#   'In stock',
#   4,
#   4),
#  (93,
#   'Batman: The Long Halloween (Batman)',
#   'http://books.toscrape.com/catalogue/batman-the-long-halloween-batman_793/index.html',
#   Decimal('36.50'),
#   'In stock',
#   2,
#   4),
#  (94,
#   'Batman: The Dark Knight Returns (Batman)',
#   'http://books.toscrape.com/catalogue/batman-the-dark-knight-returns-batman_792/index.html',
#   Decimal('15.38'),
#   'In stock',
#   3,
#   4),
#  (95,
#   'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   'http://books.toscrape.com/catalogue/wonder-woman-earth-one-volume-one-wonder-woman-earth-one-1_783/index.html',
#   Decimal('37.34'),
#   'In stock',
#   4,
#   4),
#  (97,
#   'Through the Woods',
#   'http://books.toscrape.com/catalogue/through-the-woods_772/index.html',
#   Decimal('25.38'),
#   'In stock',
#   2,
#   4),
#  (98,
#   'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#   'http://books.toscrape.com/catalogue/superman-vol-1-before-truth-superman-by-gene-luen-yang-1_739/index.html',
#   Decimal('11.89'),
#   'In stock',
#   3,
#   4),
#  (99,
#   'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#   'http://books.toscrape.com/catalogue/so-cute-it-hurts-vol-6-so-cute-it-hurts-6_734/index.html',
#   Decimal('35.43'),
#   'In stock',
#   4,
#   4),
#  (100,
#   'Robin War',
#   'http://books.toscrape.com/catalogue/robin-war_730/index.html',
#   Decimal('47.82'),
#   'In stock',
#   3,
#   4),
#  (101,
#   'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#   'http://books.toscrape.com/catalogue/red-hoodarsenal-vol-1-open-for-business-red-hoodarsenal-1_729/index.html',
#   Decimal('25.48'),
#   'In stock',
#   2,
#   4),
#  (102,
#   'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#   'http://books.toscrape.com/catalogue/naruto-3-in-1-edition-vol-14-includes-vols-40-41-42-naruto-omnibus-14_721/index.html',
#   Decimal('38.39'),
#   'In stock',
#   2,
#   4),
#  (104,
#   'El Deafo',
#   'http://books.toscrape.com/catalogue/el-deafo_691/index.html',
#   Decimal('57.62'),
#   'In stock',
#   5,
#   4),
#  (105,
#   'Batman: Europa',
#   'http://books.toscrape.com/catalogue/batman-europa_668/index.html',
#   Decimal('32.01'),
#   'In stock',
#   2,
#   4),
#  (106,
#   'Art Ops Vol. 1',
#   'http://books.toscrape.com/catalogue/art-ops-vol-1_664/index.html',
#   Decimal('48.80'),
#   'In stock',
#   3,
#   4),
#  (107,
#   'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#   'http://books.toscrape.com/catalogue/adulthood-is-a-myth-a-sarahs-scribbles-collection_659/index.html',
#   Decimal('10.90'),
#   'In stock',
#   3,
#   4),
#  (108,
#   'Fruits Basket, Vol. 9 (Fruits Basket #9)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-9-fruits-basket-9_563/index.html',
#   Decimal('33.95'),
#   'In stock',
#   4,
#   4),
#  (109,
#   'Roller Girl',
#   'http://books.toscrape.com/catalogue/roller-girl_540/index.html',
#   Decimal('14.10'),
#   'In stock',
#   3,
#   4),
#  (110,
#   'Fruits Basket, Vol. 7 (Fruits Basket #7)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-7-fruits-basket-7_468/index.html',
#   Decimal('19.57'),
#   'In stock',
#   3,
#   4),
#  (111,
#   'Fruits Basket, Vol. 6 (Fruits Basket #6)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-6-fruits-basket-6_427/index.html',
#   Decimal('20.96'),
#   'In stock',
#   4,
#   4),
#  (112,
#   'Death Note, Vol. 6: Give-and-Take (Death Note #6)',
#   'http://books.toscrape.com/catalogue/death-note-vol-6-give-and-take-death-note-6_425/index.html',
#   Decimal('36.39'),
#   'In stock',
#   3,
#   4),
#  (113,
#   'Fruits Basket, Vol. 5 (Fruits Basket #5)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-5-fruits-basket-5_376/index.html',
#   Decimal('16.33'),
#   'In stock',
#   3,
#   4),
#  (115,
#   'The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of Momochi House #4)',
#   'http://books.toscrape.com/catalogue/the-demon-prince-of-momochi-house-vol-4-the-demon-prince-of-momochi-house-4_344/index.html',
#   Decimal('27.88'),
#   'In stock',
#   2,
#   4),
#  (116,
#   'Fruits Basket, Vol. 4 (Fruits Basket #4)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-4-fruits-basket-4_321/index.html',
#   Decimal('50.44'),
#   'In stock',
#   4,
#   4),
#  (117,
#   'The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine)',
#   'http://books.toscrape.com/catalogue/the-wicked-the-divine-vol-3-commercial-suicide-the-wicked-the-divine_287/index.html',
#   Decimal('14.41'),
#   'In stock',
#   3,
#   4),
#  (118,
#   'The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)',
#   'http://books.toscrape.com/catalogue/the-sandman-vol-3-dream-country-the-sandman-volumes-3_279/index.html',
#   Decimal('55.55'),
#   'In stock',
#   5,
#   4),
#  (119,
#   'Saga, Volume 3 (Saga (Collected Editions) #3)',
#   'http://books.toscrape.com/catalogue/saga-volume-3-saga-collected-editions-3_216/index.html',
#   Decimal('21.57'),
#   'In stock',
#   5,
#   4),
#  (120,
#   'Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)',
#   'http://books.toscrape.com/catalogue/prodigy-the-graphic-novel-legend-the-graphic-novel-2_207/index.html',
#   Decimal('43.63'),
#   'In stock',
#   3,
#   4),
#  (121,
#   'Persepolis: The Story of a Childhood (Persepolis #1-2)',
#   'http://books.toscrape.com/catalogue/persepolis-the-story-of-a-childhood-persepolis-1-2_206/index.html',
#   Decimal('39.13'),
#   'In stock',
#   1,
#   4),
#  (122,
#   'Original Fake',
#   'http://books.toscrape.com/catalogue/original-fake_203/index.html',
#   Decimal('31.45'),
#   'In stock',
#   3,
#   4),
#  (123,
#   'Grayson, Vol 3: Nemesis (Grayson #3)',
#   'http://books.toscrape.com/catalogue/grayson-vol-3-nemesis-grayson-3_164/index.html',
#   Decimal('42.72'),
#   'In stock',
#   1,
#   4),
#  (124,
#   'Fruits Basket, Vol. 3 (Fruits Basket #3)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-3-fruits-basket-3_159/index.html',
#   Decimal('45.17'),
#   'In stock',
#   2,
#   4),
#  (125,
#   'Black Butler, Vol. 1 (Black Butler #1)',
#   'http://books.toscrape.com/catalogue/black-butler-vol-1-black-butler-1_130/index.html',
#   Decimal('49.31'),
#   'In stock',
#   1,
#   4),
#  (126,
#   'Awkward',
#   'http://books.toscrape.com/catalogue/awkward_124/index.html',
#   Decimal('38.02'),
#   'In stock',
#   2,
#   4),
#  (128,
#   'Saga, Volume 2 (Saga (Collected Editions) #2)',
#   'http://books.toscrape.com/catalogue/saga-volume-2-saga-collected-editions-2_107/index.html',
#   Decimal('11.75'),
#   'In stock',
#   3,
#   4),
#  (129,
#   'Fruits Basket, Vol. 2 (Fruits Basket #2)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-2-fruits-basket-2_100/index.html',
#   Decimal('11.64'),
#   'In stock',
#   3,
#   4),
#  (130,
#   'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#   'http://books.toscrape.com/catalogue/y-the-last-man-vol-1-unmanned-y-the-last-man-1_98/index.html',
#   Decimal('18.51'),
#   'In stock',
#   3,
#   4),
#  (131,
#   'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#   'http://books.toscrape.com/catalogue/the-wicked-the-divine-vol-1-the-faust-act-the-wicked-the-divine_86/index.html',
#   Decimal('36.52'),
#   'In stock',
#   2,
#   4),
#  (132,
#   'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)',
#   'http://books.toscrape.com/catalogue/the-sandman-vol-1-preludes-and-nocturnes-the-sandman-volumes-1_79/index.html',
#   Decimal('54.12'),
#   'In stock',
#   3,
#   4),
#  (133,
#   'The Complete Maus (Maus #1-2)',
#   'http://books.toscrape.com/catalogue/the-complete-maus-maus-1-2_62/index.html',
#   Decimal('10.64'),
#   'In stock',
#   3,
#   4),
#  (134,
#   'Skip Beat!, Vol. 01 (Skip Beat! #1)',
#   'http://books.toscrape.com/catalogue/skip-beat-vol-01-skip-beat-1_55/index.html',
#   Decimal('42.12'),
#   'In stock',
#   3,
#   4),
#  (135,
#   'Saga, Volume 1 (Saga (Collected Editions) #1)',
#   'http://books.toscrape.com/catalogue/saga-volume-1-saga-collected-editions-1_48/index.html',
#   Decimal('28.48'),
#   'In stock',
#   1,
#   4),
#  (136,
#   'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#   'http://books.toscrape.com/catalogue/rat-queens-vol-1-sass-sorcery-rat-queens-collected-editions-1-5_46/index.html',
#   Decimal('46.96'),
#   'In stock',
#   5,
#   4),
#  (137,
#   'Paper Girls, Vol. 1 (Paper Girls #1-5)',
#   'http://books.toscrape.com/catalogue/paper-girls-vol-1-paper-girls-1-5_44/index.html',
#   Decimal('21.71'),
#   'In stock',
#   4,
#   4),
#  (138,
#   'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',
#   'http://books.toscrape.com/catalogue/ouran-high-school-host-club-vol-1-ouran-high-school-host-club-1_43/index.html',
#   Decimal('29.87'),
#   'In stock',
#   3,
#   4),
#  (139,
#   'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#   'http://books.toscrape.com/catalogue/ms-marvel-vol-1-no-normal-ms-marvel-2014-2015-1_34/index.html',
#   Decimal('39.39'),
#   'In stock',
#   4,
#   4),
#  (140,
#   'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',
#   'http://books.toscrape.com/catalogue/hawkeye-vol-1-my-life-as-a-weapon-hawkeye-1_24/index.html',
#   Decimal('45.24'),
#   'In stock',
#   3,
#   4),
#  (141,
#   'Giant Days, Vol. 1 (Giant Days #1-4)',
#   'http://books.toscrape.com/catalogue/giant-days-vol-1-giant-days-1-4_22/index.html',
#   Decimal('56.76'),
#   'In stock',
#   4,
#   4),
#  (142,
#   'Fruits Basket, Vol. 1 (Fruits Basket #1)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-1-fruits-basket-1_21/index.html',
#   Decimal('40.28'),
#   'In stock',
#   5,
#   4),
#  (143,
#   'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#   'http://books.toscrape.com/catalogue/bleach-vol-1-strawberry-and-the-soul-reapers-bleach-1_7/index.html',
#   Decimal('34.65'),
#   'In stock',
#   5,
#   4),
#  (144,
#   'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#   'http://books.toscrape.com/catalogue/ajin-demi-human-volume-1-ajin-demi-human-1_4/index.html',
#   Decimal('57.06'),
#   'In stock',
#   4,
#   4),
#  (145,
#   'The Secret Garden',
#   'http://books.toscrape.com/catalogue/the-secret-garden_413/index.html',
#   Decimal('15.08'),
#   'In stock',
#   3,
#   5),
#  (146,
#   'The Metamorphosis',
#   'http://books.toscrape.com/catalogue/the-metamorphosis_409/index.html',
#   Decimal('28.58'),
#   'In stock',
#   1,
#   5),
#  (148,
#   'The Hound of the Baskervilles (Sherlock Holmes #5)',
#   'http://books.toscrape.com/catalogue/the-hound-of-the-baskervilles-sherlock-holmes-5_348/index.html',
#   Decimal('14.82'),
#   'In stock',
#   3,
#   5),
#  (149,
#   'Little Women (Little Women #1)',
#   'http://books.toscrape.com/catalogue/little-women-little-women-1_331/index.html',
#   Decimal('28.07'),
#   'In stock',
#   4,
#   5),
#  (150,
#   'Gone with the Wind',
#   'http://books.toscrape.com/catalogue/gone-with-the-wind_324/index.html',
#   Decimal('32.49'),
#   'In stock',
#   3,
#   5),
#  (151,
#   'Candide',
#   'http://books.toscrape.com/catalogue/candide_316/index.html',
#   Decimal('58.63'),
#   'In stock',
#   3,
#   5),
#  (152,
#   'Animal Farm',
#   'http://books.toscrape.com/catalogue/animal-farm_313/index.html',
#   Decimal('57.22'),
#   'In stock',
#   3,
#   5),
#  (153,
#   'Wuthering Heights',
#   'http://books.toscrape.com/catalogue/wuthering-heights_307/index.html',
#   Decimal('17.73'),
#   'In stock',
#   3,
#   5),
#  (154,
#   'The Picture of Dorian Gray',
#   'http://books.toscrape.com/catalogue/the-picture-of-dorian-gray_270/index.html',
#   Decimal('29.70'),
#   'In stock',
#   2,
#   5),
#  (155,
#   'The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',
#   'http://books.toscrape.com/catalogue/the-complete-stories-and-poems-the-works-of-edgar-allan-poe-cameo-edition_238/index.html',
#   Decimal('26.78'),
#   'In stock',
#   4,
#   5),
#  (156,
#   'Beowulf',
#   'http://books.toscrape.com/catalogue/beowulf_126/index.html',
#   Decimal('38.35'),
#   'In stock',
#   2,
#   5),
#  (157,
#   'And Then There Were None',
#   'http://books.toscrape.com/catalogue/and-then-there-were-none_119/index.html',
#   Decimal('35.01'),
#   'In stock',
#   2,
#   5),
#  (158,
#   'The Story of Hong Gildong',
#   'http://books.toscrape.com/catalogue/the-story-of-hong-gildong_84/index.html',
#   Decimal('43.19'),
#   'In stock',
#   4,
#   5),
#  (159,
#   'The Little Prince',
#   'http://books.toscrape.com/catalogue/the-little-prince_72/index.html',
#   Decimal('45.42'),
#   'In stock',
#   2,
#   5),
#  (160,
#   'Sense and Sensibility',
#   'http://books.toscrape.com/catalogue/sense-and-sensibility_49/index.html',
#   Decimal('37.46'),
#   'In stock',
#   1,
#   5),
#  (161,
#   'Of Mice and Men',
#   'http://books.toscrape.com/catalogue/of-mice-and-men_37/index.html',
#   Decimal('47.11'),
#   'In stock',
#   2,
#   5),
#  (162,
#   'Emma',
#   'http://books.toscrape.com/catalogue/emma_17/index.html',
#   Decimal('32.93'),
#   'In stock',
#   2,
#   5),
#  (164,
#   "Sophie's World",
#   'http://books.toscrape.com/catalogue/sophies-world_966/index.html',
#   Decimal('15.94'),
#   'In stock',
#   3,
#   6),
#  (165,
#   'The Death of Humanity: and the Case for Life',
#   'http://books.toscrape.com/catalogue/the-death-of-humanity-and-the-case-for-life_932/index.html',
#   Decimal('58.11'),
#   'In stock',
#   4,
#   6),
#  (166,
#   'The Stranger',
#   'http://books.toscrape.com/catalogue/the-stranger_861/index.html',
#   Decimal('17.44'),
#   'In stock',
#   3,
#   6),
#  (168,
#   'Kierkegaard: A Christian Missionary to Christians',
#   'http://books.toscrape.com/catalogue/kierkegaard-a-christian-missionary-to-christians_527/index.html',
#   Decimal('47.13'),
#   'In stock',
#   1,
#   6),
#  (169,
#   'At The Existentialist Café: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',
#   'http://books.toscrape.com/catalogue/at-the-existentialist-cafe-freedom-being-and-apricot-cocktails-with-jean-paul-sartre-simone-de-beauvoir-albert-camus-martin-heidegger-edmund-husserl-karl-jaspers-maurice-merleau-ponty-and-others_459/index.html',
#   Decimal('29.93'),
#   'In stock',
#   5,
#   6),
#  (170,
#   'Critique of Pure Reason',
#   'http://books.toscrape.com/catalogue/critique-of-pure-reason_366/index.html',
#   Decimal('20.75'),
#   'In stock',
#   1,
#   6),
#  (171,
#   'Run, Spot, Run: The Ethics of Keeping Pets',
#   'http://books.toscrape.com/catalogue/run-spot-run-the-ethics-of-keeping-pets_106/index.html',
#   Decimal('20.02'),
#   'In stock',
#   1,
#   6),
#  (172,
#   'The Nicomachean Ethics',
#   'http://books.toscrape.com/catalogue/the-nicomachean-ethics_75/index.html',
#   Decimal('36.34'),
#   'In stock',
#   1,
#   6),
#  (173,
#   'Meditations',
#   'http://books.toscrape.com/catalogue/meditations_33/index.html',
#   Decimal('25.89'),
#   'In stock',
#   2,
#   6),
#  (174,
#   'Beyond Good and Evil',
#   'http://books.toscrape.com/catalogue/beyond-good-and-evil_6/index.html',
#   Decimal('43.38'),
#   'In stock',
#   1,
#   6),
#  (175,
#   'Chase Me (Paris Nights #2)',
#   'http://books.toscrape.com/catalogue/chase-me-paris-nights-2_977/index.html',
#   Decimal('25.27'),
#   'In stock',
#   5,
#   7),
#  (176,
#   'Black Dust',
#   'http://books.toscrape.com/catalogue/black-dust_976/index.html',
#   Decimal('34.53'),
#   'In stock',
#   5,
#   7),
#  (177,
#   'Her Backup Boyfriend (The Sorensen Family #1)',
#   'http://books.toscrape.com/catalogue/her-backup-boyfriend-the-sorensen-family-1_896/index.html',
#   Decimal('33.97'),
#   'In stock',
#   1,
#   7),
#  (178,
#   'First and First (Five Boroughs #3)',
#   'http://books.toscrape.com/catalogue/first-and-first-five-boroughs-3_893/index.html',
#   Decimal('15.97'),
#   'In stock',
#   3,
#   7),
#  (179,
#   'Fifty Shades Darker (Fifty Shades #2)',
#   'http://books.toscrape.com/catalogue/fifty-shades-darker-fifty-shades-2_892/index.html',
#   Decimal('21.96'),
#   'In stock',
#   1,
#   7),
#  (180,
#   'The Wedding Dress',
#   'http://books.toscrape.com/catalogue/the-wedding-dress_864/index.html',
#   Decimal('24.12'),
#   'In stock',
#   1,
#   7),
#  (182,
#   'Something More Than This',
#   'http://books.toscrape.com/catalogue/something-more-than-this_834/index.html',
#   Decimal('16.24'),
#   'In stock',
#   3,
#   7),
#  (183,
#   'Doing It Over (Most Likely To #1)',
#   'http://books.toscrape.com/catalogue/doing-it-over-most-likely-to-1_802/index.html',
#   Decimal('35.61'),
#   'In stock',
#   3,
#   7),
#  (184,
#   "The Wedding Pact (The O'Malleys #2)",
#   'http://books.toscrape.com/catalogue/the-wedding-pact-the-omalleys-2_767/index.html',
#   Decimal('32.61'),
#   'In stock',
#   3,
#   7),
#  (185,
#   'Hold Your Breath (Search and Rescue #1)',
#   'http://books.toscrape.com/catalogue/hold-your-breath-search-and-rescue-1_700/index.html',
#   Decimal('28.82'),
#   'In stock',
#   1,
#   7),
#  (186,
#   'Dirty (Dive Bar #1)',
#   'http://books.toscrape.com/catalogue/dirty-dive-bar-1_615/index.html',
#   Decimal('40.83'),
#   'In stock',
#   4,
#   7),
#  (187,
#   'Take Me Home Tonight (Rock Star Romance #3)',
#   'http://books.toscrape.com/catalogue/take-me-home-tonight-rock-star-romance-3_605/index.html',
#   Decimal('53.98'),
#   'In stock',
#   3,
#   7),
#  (188,
#   'Off the Hook (Fishing for Trouble #1)',
#   'http://books.toscrape.com/catalogue/off-the-hook-fishing-for-trouble-1_601/index.html',
#   Decimal('47.67'),
#   'In stock',
#   3,
#   7),
#  (189,
#   "A Gentleman's Position (Society of Gentlemen #3)",
#   'http://books.toscrape.com/catalogue/a-gentlemans-position-society-of-gentlemen-3_584/index.html',
#   Decimal('14.75'),
#   'In stock',
#   3,
#   7),
#  (190,
#   'Sit, Stay, Love',
#   'http://books.toscrape.com/catalogue/sit-stay-love_486/index.html',
#   Decimal('20.90'),
#   'In stock',
#   3,
#   7),
#  (191,
#   "A Girl's Guide to Moving On (New Beginnings #2)",
#   'http://books.toscrape.com/catalogue/a-girls-guide-to-moving-on-new-beginnings-2_359/index.html',
#   Decimal('31.30'),
#   'In stock',
#   1,
#   7),
#  (192,
#   'The Perfect Play (Play by Play #1)',
#   'http://books.toscrape.com/catalogue/the-perfect-play-play-by-play-1_352/index.html',
#   Decimal('59.99'),
#   'In stock',
#   3,
#   7),
#  (193,
#   'Dark Lover (Black Dagger Brotherhood #1)',
#   'http://books.toscrape.com/catalogue/dark-lover-black-dagger-brotherhood-1_319/index.html',
#   Decimal('12.87'),
#   'In stock',
#   3,
#   7),
#  (194,
#   'Changing the Game (Play by Play #2)',
#   'http://books.toscrape.com/catalogue/changing-the-game-play-by-play-2_317/index.html',
#   Decimal('13.38'),
#   'In stock',
#   3,
#   7),
#  (196,
#   'The Purest Hook (Second Circle Tattoos #3)',
#   'http://books.toscrape.com/catalogue/the-purest-hook-second-circle-tattoos-3_271/index.html',
#   Decimal('12.25'),
#   'In stock',
#   3,
#   7),
#  (197,
#   'The Obsession',
#   'http://books.toscrape.com/catalogue/the-obsession_268/index.html',
#   Decimal('45.43'),
#   'In stock',
#   1,
#   7),
#  (198,
#   'Reservations for Two',
#   'http://books.toscrape.com/catalogue/reservations-for-two_211/index.html',
#   Decimal('11.10'),
#   'In stock',
#   3,
#   7),
#  (199,
#   "Best of My Love (Fool's Gold #20)",
#   'http://books.toscrape.com/catalogue/best-of-my-love-fools-gold-20_127/index.html',
#   Decimal('27.41'),
#   'In stock',
#   2,
#   7),
#  (200,
#   'Where Lightning Strikes (Bleeding Stars #3)',
#   'http://books.toscrape.com/catalogue/where-lightning-strikes-bleeding-stars-3_96/index.html',
#   Decimal('39.77'),
#   'In stock',
#   3,
#   7),
#  (201,
#   'This One Moment (Pushing Limits #1)',
#   'http://books.toscrape.com/catalogue/this-one-moment-pushing-limits-1_88/index.html',
#   Decimal('48.71'),
#   'In stock',
#   1,
#   7),
#  (202,
#   'Rhythm, Chord & Malykhin',
#   'http://books.toscrape.com/catalogue/rhythm-chord-malykhin_47/index.html',
#   Decimal('28.34'),
#   'In stock',
#   2,
#   7),
#  (203,
#   'My Perfect Mistake (Over the Top #1)',
#   'http://books.toscrape.com/catalogue/my-perfect-mistake-over-the-top-1_35/index.html',
#   Decimal('38.92'),
#   'In stock',
#   2,
#   7),
#  (204,
#   'Listen to Me (Fusion #1)',
#   'http://books.toscrape.com/catalogue/listen-to-me-fusion-1_29/index.html',
#   Decimal('58.99'),
#   'In stock',
#   3,
#   7),
#  (205,
#   'Imperfect Harmony',
#   'http://books.toscrape.com/catalogue/imperfect-harmony_26/index.html',
#   Decimal('34.74'),
#   'In stock',
#   4,
#   7),
#  (206,
#   'Fighting Fate (Fighting #6)',
#   'http://books.toscrape.com/catalogue/fighting-fate-fighting-6_18/index.html',
#   Decimal('39.24'),
#   'In stock',
#   3,
#   7),
#  (207,
#   'Deep Under (Walker Security #1)',
#   'http://books.toscrape.com/catalogue/deep-under-walker-security-1_15/index.html',
#   Decimal('47.09'),
#   'In stock',
#   5,
#   7),
#  (208,
#   "Charity's Cross (Charles Towne Belles #4)",
#   'http://books.toscrape.com/catalogue/charitys-cross-charles-towne-belles-4_12/index.html',
#   Decimal('41.24'),
#   'In stock',
#   1,
#   7),
#  (209,
#   'Bounty (Colorado Mountain #7)',
#   'http://books.toscrape.com/catalogue/bounty-colorado-mountain-7_9/index.html',
#   Decimal('37.26'),
#   'In stock',
#   4,
#   7),
#  (210,
#   'I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   'http://books.toscrape.com/catalogue/i-had-a-nice-time-and-other-lies-how-to-find-love-sht-like-that_814/index.html',
#   Decimal('57.36'),
#   'In stock',
#   4,
#   8),
#  (211,
#   "Will You Won't You Want Me?",
#   'http://books.toscrape.com/catalogue/will-you-wont-you-want-me_644/index.html',
#   Decimal('13.86'),
#   'In stock',
#   3,
#   8),
#  (212,
#   'Keep Me Posted',
#   'http://books.toscrape.com/catalogue/keep-me-posted_594/index.html',
#   Decimal('20.46'),
#   'In stock',
#   4,
#   8),
#  (213,
#   'Grey (Fifty Shades #4)',
#   'http://books.toscrape.com/catalogue/grey-fifty-shades-4_592/index.html',
#   Decimal('48.49'),
#   'In stock',
#   4,
#   8),
#  (214,
#   'Meternity',
#   'http://books.toscrape.com/catalogue/meternity_478/index.html',
#   Decimal('43.58'),
#   'In stock',
#   3,
#   8),
#  (215,
#   'Some Women',
#   'http://books.toscrape.com/catalogue/some-women_341/index.html',
#   Decimal('13.73'),
#   'In stock',
#   3,
#   8),
#  (216,
#   'Shopaholic Ties the Knot (Shopaholic #3)',
#   'http://books.toscrape.com/catalogue/shopaholic-ties-the-knot-shopaholic-3_340/index.html',
#   Decimal('48.39'),
#   'In stock',
#   5,
#   8),
#  (217,
#   'Can You Keep a Secret?',
#   'http://books.toscrape.com/catalogue/can-you-keep-a-secret_315/index.html',
#   Decimal('21.94'),
#   'In stock',
#   1,
#   8),
#  (218,
#   'Twenties Girl',
#   'http://books.toscrape.com/catalogue/twenties-girl_292/index.html',
#   Decimal('42.80'),
#   'In stock',
#   2,
#   8),
#  (219,
#   'The Undomestic Goddess',
#   'http://books.toscrape.com/catalogue/the-undomestic-goddess_286/index.html',
#   Decimal('45.75'),
#   'In stock',
#   4,
#   8),
#  (220,
#   'The Nanny Diaries (Nanny #1)',
#   'http://books.toscrape.com/catalogue/the-nanny-diaries-nanny-1_265/index.html',
#   Decimal('52.53'),
#   'In stock',
#   5,
#   8),
#  (221,
#   'The Devil Wears Prada (The Devil Wears Prada #1)',
#   'http://books.toscrape.com/catalogue/the-devil-wears-prada-the-devil-wears-prada-1_243/index.html',
#   Decimal('44.29'),
#   'In stock',
#   1,
#   8),
#  (222,
#   'Something Borrowed (Darcy & Rachel #1)',
#   'http://books.toscrape.com/catalogue/something-borrowed-darcy-rachel-1_224/index.html',
#   Decimal('48.96'),
#   'In stock',
#   5,
#   8),
#  (224,
#   "I've Got Your Number",
#   'http://books.toscrape.com/catalogue/ive-got-your-number_173/index.html',
#   Decimal('19.69'),
#   'In stock',
#   3,
#   8),
#  (225,
#   'The Edge of Reason (Bridget Jones #2)',
#   'http://books.toscrape.com/catalogue/the-edge-of-reason-bridget-jones-2_63/index.html',
#   Decimal('19.18'),
#   'In stock',
#   3,
#   8),
#  (226,
#   "Bridget Jones's Diary (Bridget Jones #1)",
#   'http://books.toscrape.com/catalogue/bridget-joness-diary-bridget-jones-1_10/index.html',
#   Decimal('29.82'),
#   'In stock',
#   1,
#   8),
#  (228,
#   'Private Paris (Private #10)',
#   'http://books.toscrape.com/catalogue/private-paris-private-10_958/index.html',
#   Decimal('47.61'),
#   'In stock',
#   5,
#   9),
#  (229,
#   'We Love You, Charlie Freeman',
#   'http://books.toscrape.com/catalogue/we-love-you-charlie-freeman_954/index.html',
#   Decimal('50.27'),
#   'In stock',
#   5,
#   9),
#  (230,
#   'Thirst',
#   'http://books.toscrape.com/catalogue/thirst_946/index.html',
#   Decimal('17.27'),
#   'In stock',
#   3,
#   9),
#  (231,
#   'The Murder That Never Was (Forensic Instincts #5)',
#   'http://books.toscrape.com/catalogue/the-murder-that-never-was-forensic-instincts-5_939/index.html',
#   Decimal('54.11'),
#   'In stock',
#   3,
#   9),
#  (232,
#   'Tuesday Nights in 1980',
#   'http://books.toscrape.com/catalogue/tuesday-nights-in-1980_870/index.html',
#   Decimal('21.04'),
#   'In stock',
#   2,
#   9),
#  (233,
#   'The Vacationers',
#   'http://books.toscrape.com/catalogue/the-vacationers_863/index.html',
#   Decimal('42.15'),
#   'In stock',
#   4,
#   9),
#  (234,
#   'The Regional Office Is Under Attack!',
#   'http://books.toscrape.com/catalogue/the-regional-office-is-under-attack_858/index.html',
#   Decimal('51.36'),
#   'In stock',
#   5,
#   9),
#  (235,
#   'Finders Keepers (Bill Hodges Trilogy #2)',
#   'http://books.toscrape.com/catalogue/finders-keepers-bill-hodges-trilogy-2_807/index.html',
#   Decimal('53.53'),
#   'In stock',
#   5,
#   9),
#  (236,
#   'The Time Keeper',
#   'http://books.toscrape.com/catalogue/the-time-keeper_766/index.html',
#   Decimal('27.88'),
#   'In stock',
#   5,
#   9),
#  (237,
#   'The Testament of Mary',
#   'http://books.toscrape.com/catalogue/the-testament-of-mary_765/index.html',
#   Decimal('52.67'),
#   'In stock',
#   4,
#   9),
#  (238,
#   'The First Hostage (J.B. Collins #2)',
#   'http://books.toscrape.com/catalogue/the-first-hostage-jb-collins-2_749/index.html',
#   Decimal('25.85'),
#   'In stock',
#   3,
#   9),
#  (239,
#   'Take Me with You',
#   'http://books.toscrape.com/catalogue/take-me-with-you_741/index.html',
#   Decimal('45.21'),
#   'In stock',
#   3,
#   9),
#  (240,
#   'Still Life with Bread Crumbs',
#   'http://books.toscrape.com/catalogue/still-life-with-bread-crumbs_738/index.html',
#   Decimal('26.41'),
#   'In stock',
#   3,
#   9),
#  (241,
#   'Shtum',
#   'http://books.toscrape.com/catalogue/shtum_733/index.html',
#   Decimal('55.84'),
#   'In stock',
#   4,
#   9),
#  (242,
#   'My Name Is Lucy Barton',
#   'http://books.toscrape.com/catalogue/my-name-is-lucy-barton_720/index.html',
#   Decimal('41.56'),
#   'In stock',
#   1,
#   9),
#  (243,
#   'My Mrs. Brown',
#   'http://books.toscrape.com/catalogue/my-mrs-brown_719/index.html',
#   Decimal('24.48'),
#   'In stock',
#   3,
#   9),
#  (244,
#   'Mr. Mercedes (Bill Hodges Trilogy #1)',
#   'http://books.toscrape.com/catalogue/mr-mercedes-bill-hodges-trilogy-1_717/index.html',
#   Decimal('28.90'),
#   'In stock',
#   1,
#   9),
#  (245,
#   'I Am Pilgrim (Pilgrim #1)',
#   'http://books.toscrape.com/catalogue/i-am-pilgrim-pilgrim-1_703/index.html',
#   Decimal('10.60'),
#   'In stock',
#   3,
#   9),
#  (246,
#   'Eligible (The Austen Project #4)',
#   'http://books.toscrape.com/catalogue/eligible-the-austen-project-4_692/index.html',
#   Decimal('27.09'),
#   'In stock',
#   3,
#   9),
#  (247,
#   'Eight Hundred Grapes',
#   'http://books.toscrape.com/catalogue/eight-hundred-grapes_690/index.html',
#   Decimal('14.39'),
#   'In stock',
#   3,
#   9),
#  (248,
#   'Dear Mr. Knightley',
#   'http://books.toscrape.com/catalogue/dear-mr-knightley_684/index.html',
#   Decimal('11.21'),
#   'In stock',
#   3,
#   9),
#  (249,
#   'Cometh the Hour (The Clifton Chronicles #6)',
#   'http://books.toscrape.com/catalogue/cometh-the-hour-the-clifton-chronicles-6_681/index.html',
#   Decimal('25.01'),
#   'In stock',
#   3,
#   9),
#  (250,
#   'Balloon Animals',
#   'http://books.toscrape.com/catalogue/balloon-animals_665/index.html',
#   Decimal('17.03'),
#   'In stock',
#   3,
#   9),
#  (251,
#   'A Man Called Ove',
#   'http://books.toscrape.com/catalogue/a-man-called-ove_653/index.html',
#   Decimal('39.72'),
#   'In stock',
#   1,
#   9),
#  (252,
#   'The Silent Sister (Riley MacPherson #1)',
#   'http://books.toscrape.com/catalogue/the-silent-sister-riley-macpherson-1_641/index.html',
#   Decimal('46.29'),
#   'In stock',
#   5,
#   9),
#  (255,
#   'Mothering Sunday',
#   'http://books.toscrape.com/catalogue/mothering-sunday_600/index.html',
#   Decimal('13.34'),
#   'In stock',
#   3,
#   9),
#  (256,
#   'Lies and Other Acts of Love',
#   'http://books.toscrape.com/catalogue/lies-and-other-acts-of-love_596/index.html',
#   Decimal('45.14'),
#   'In stock',
#   1,
#   9),
#  (257,
#   'Daredevils',
#   'http://books.toscrape.com/catalogue/daredevils_590/index.html',
#   Decimal('16.34'),
#   'In stock',
#   3,
#   9),
#  (258,
#   '11/22/63',
#   'http://books.toscrape.com/catalogue/112263_583/index.html',
#   Decimal('48.48'),
#   'In stock',
#   3,
#   9),
#  (259,
#   'The Shack',
#   'http://books.toscrape.com/catalogue/the-shack_576/index.html',
#   Decimal('28.03'),
#   'In stock',
#   1,
#   9),
#  (262,
#   'Hystopia: A Novel',
#   'http://books.toscrape.com/catalogue/hystopia-a-novel_523/index.html',
#   Decimal('21.96'),
#   'In stock',
#   4,
#   9),
#  (263,
#   'The Bourne Identity (Jason Bourne #1)',
#   'http://books.toscrape.com/catalogue/the-bourne-identity-jason-bourne-1_492/index.html',
#   Decimal('42.78'),
#   'In stock',
#   4,
#   9),
#  (264,
#   'Sister Dear',
#   'http://books.toscrape.com/catalogue/sister-dear_485/index.html',
#   Decimal('40.20'),
#   'In stock',
#   4,
#   9),
#  (265,
#   'Memoirs of a Geisha',
#   'http://books.toscrape.com/catalogue/memoirs-of-a-geisha_477/index.html',
#   Decimal('49.67'),
#   'In stock',
#   3,
#   9),
#  (266,
#   'Me Before You (Me Before You #1)',
#   'http://books.toscrape.com/catalogue/me-before-you-me-before-you-1_434/index.html',
#   Decimal('19.02'),
#   'In stock',
#   3,
#   9),
#  (267,
#   'Deception Point',
#   'http://books.toscrape.com/catalogue/deception-point_426/index.html',
#   Decimal('40.32'),
#   'In stock',
#   4,
#   9),
#  (268,
#   'The Little Paris Bookshop',
#   'http://books.toscrape.com/catalogue/the-little-paris-bookshop_407/index.html',
#   Decimal('24.73'),
#   'In stock',
#   3,
#   9),
#  (269,
#   'The Firm',
#   'http://books.toscrape.com/catalogue/the-firm_404/index.html',
#   Decimal('45.56'),
#   'In stock',
#   3,
#   9),
#  (270,
#   'The Expatriates',
#   'http://books.toscrape.com/catalogue/the-expatriates_401/index.html',
#   Decimal('44.58'),
#   'In stock',
#   2,
#   9),
#  (271,
#   'Siddhartha',
#   'http://books.toscrape.com/catalogue/siddhartha_393/index.html',
#   Decimal('34.22'),
#   'In stock',
#   5,
#   9),
#  (272,
#   'Last One Home (New Beginnings #1)',
#   'http://books.toscrape.com/catalogue/last-one-home-new-beginnings-1_383/index.html',
#   Decimal('59.98'),
#   'In stock',
#   3,
#   9),
#  (273,
#   'Digital Fortress',
#   'http://books.toscrape.com/catalogue/digital-fortress_369/index.html',
#   Decimal('58.00'),
#   'In stock',
#   5,
#   9),
#  (274,
#   'Atlas Shrugged',
#   'http://books.toscrape.com/catalogue/atlas-shrugged_314/index.html',
#   Decimal('26.58'),
#   'In stock',
#   5,
#   9),
#  (275,
#   'Three-Martini Lunch',
#   'http://books.toscrape.com/catalogue/three-martini-lunch_290/index.html',
#   Decimal('23.21'),
#   'In stock',
#   3,
#   9),
#  (276,
#   'The Nightingale',
#   'http://books.toscrape.com/catalogue/the-nightingale_267/index.html',
#   Decimal('26.26'),
#   'In stock',
#   4,
#   9),
#  (277,
#   'The Infinities',
#   'http://books.toscrape.com/catalogue/the-infinities_257/index.html',
#   Decimal('27.41'),
#   'In stock',
#   1,
#   9),
#  (278,
#   "The Husband's Secret",
#   'http://books.toscrape.com/catalogue/the-husbands-secret_256/index.html',
#   Decimal('52.51'),
#   'In stock',
#   5,
#   9),
#  (279,
#   'The Da Vinci Code (Robert Langdon #2)',
#   'http://books.toscrape.com/catalogue/the-da-vinci-code-robert-langdon-2_240/index.html',
#   Decimal('22.96'),
#   'In stock',
#   2,
#   9),
#  (280,
#   'The Art of Fielding',
#   'http://books.toscrape.com/catalogue/the-art-of-fielding_228/index.html',
#   Decimal('22.10'),
#   'In stock',
#   1,
#   9),
#  (281,
#   'Lila (Gilead #3)',
#   'http://books.toscrape.com/catalogue/lila-gilead-3_190/index.html',
#   Decimal('12.47'),
#   'In stock',
#   3,
#   9),
#  (282,
#   'Jurassic Park (Jurassic Park #1)',
#   'http://books.toscrape.com/catalogue/jurassic-park-jurassic-park-1_180/index.html',
#   Decimal('44.97'),
#   'In stock',
#   1,
#   9),
#  (283,
#   'Inferno (Robert Langdon #4)',
#   'http://books.toscrape.com/catalogue/inferno-robert-langdon-4_176/index.html',
#   Decimal('41.00'),
#   'In stock',
#   5,
#   9),
#  (284,
#   'Crazy Rich Asians (Crazy Rich Asians #1)',
#   'http://books.toscrape.com/catalogue/crazy-rich-asians-crazy-rich-asians-1_143/index.html',
#   Decimal('49.13'),
#   'In stock',
#   5,
#   9),
#  (285,
#   'Big Little Lies',
#   'http://books.toscrape.com/catalogue/big-little-lies_129/index.html',
#   Decimal('22.11'),
#   'In stock',
#   1,
#   9),
#  (286,
#   'The Course of Love',
#   'http://books.toscrape.com/catalogue/the-course-of-love_109/index.html',
#   Decimal('16.78'),
#   'In stock',
#   3,
#   9),
#  (287,
#   "When I'm Gone",
#   'http://books.toscrape.com/catalogue/when-im-gone_95/index.html',
#   Decimal('51.96'),
#   'In stock',
#   3,
#   9),
#  (288,
#   'The Silent Wife',
#   'http://books.toscrape.com/catalogue/the-silent-wife_83/index.html',
#   Decimal('12.34'),
#   'In stock',
#   3,
#   9),
#  (289,
#   'The Bette Davis Club',
#   'http://books.toscrape.com/catalogue/the-bette-davis-club_59/index.html',
#   Decimal('30.66'),
#   'In stock',
#   3,
# ...
#   'http://books.toscrape.com/catalogue/naturally-lean-125-nourishing-gluten-free-plant-based-recipes-all-under-300-calories_479/index.html',
#   Decimal('11.38'),
#   'In stock',
#   3,
#   32),
#  (924,
#   'How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#   'http://books.toscrape.com/catalogue/how-to-cook-everything-vegetarian-simple-meatless-recipes-for-great-food-how-to-cook-everything_471/index.html',
#   Decimal('46.01'),
#   'In stock',
#   4,
#   32),
#  (925,
#   'How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#   'http://books.toscrape.com/catalogue/how-to-be-a-domestic-goddess-baking-and-the-art-of-comfort-cooking_470/index.html',
#   Decimal('28.25'),
#   'In stock',
#   2,
#   32),
#  (926,
#   'The Barefoot Contessa Cookbook',
#   'http://books.toscrape.com/catalogue/the-barefoot-contessa-cookbook_440/index.html',
#   Decimal('59.92'),
#   'In stock',
#   5,
#   32),
#  (927,
#   'Better Homes and Gardens New Cook Book',
#   'http://books.toscrape.com/catalogue/better-homes-and-gardens-new-cook-book_423/index.html',
#   Decimal('39.61'),
#   'In stock',
#   3,
#   32),
#  (928,
#   'The Power Greens Cookbook: 140 Delicious Superfood Recipes',
#   'http://books.toscrape.com/catalogue/the-power-greens-cookbook-140-delicious-superfood-recipes_410/index.html',
#   Decimal('11.05'),
#   'In stock',
#   3,
#   32),
#  (929,
#   'Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens',
#   'http://books.toscrape.com/catalogue/mexican-today-new-and-rediscovered-recipes-for-contemporary-kitchens_387/index.html',
#   Decimal('24.91'),
#   'In stock',
#   5,
#   32),
#  (930,
#   'Vegan Vegetarian Omnivore: Dinner for Everyone at the Table',
#   'http://books.toscrape.com/catalogue/vegan-vegetarian-omnivore-dinner-for-everyone-at-the-table_297/index.html',
#   Decimal('13.66'),
#   'In stock',
#   3,
#   32),
#  (931,
#   'The Smitten Kitchen Cookbook',
#   'http://books.toscrape.com/catalogue/the-smitten-kitchen-cookbook_281/index.html',
#   Decimal('23.59'),
#   'In stock',
#   1,
#   32),
#  (932,
#   'The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution',
#   'http://books.toscrape.com/catalogue/the-art-of-simple-food-notes-lessons-and-recipes-from-a-delicious-revolution_229/index.html',
#   Decimal('34.32'),
#   'In stock',
#   3,
#   32),
#  (933,
#   'Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',
#   'http://books.toscrape.com/catalogue/hungry-girl-clean-hungry-easy-all-natural-recipes-for-healthy-eating-in-the-real-world_171/index.html',
#   Decimal('33.14'),
#   'In stock',
#   3,
#   32),
#  (934,
#   'Redeeming Love',
#   'http://books.toscrape.com/catalogue/redeeming-love_826/index.html',
#   Decimal('20.47'),
#   'In stock',
#   5,
#   33),
#  (935,
#   'Close to You',
#   'http://books.toscrape.com/catalogue/close-to-you_798/index.html',
#   Decimal('49.46'),
#   'In stock',
#   4,
#   33),
#  (936,
#   'Shadows of the Past (Logan Point #1)',
#   'http://books.toscrape.com/catalogue/shadows-of-the-past-logan-point-1_541/index.html',
#   Decimal('39.67'),
#   'In stock',
#   5,
#   33),
#  (937,
#   'Like Never Before (Walker Family #2)',
#   'http://books.toscrape.com/catalogue/like-never-before-walker-family-2_476/index.html',
#   Decimal('28.77'),
#   'In stock',
#   2,
#   33),
#  (938,
#   'Counted With the Stars (Out from Egypt #1)',
#   'http://books.toscrape.com/catalogue/counted-with-the-stars-out-from-egypt-1_463/index.html',
#   Decimal('17.97'),
#   'In stock',
#   3,
#   33),
#  (939,
#   'If I Run (If I Run #1)',
#   'http://books.toscrape.com/catalogue/if-i-run-if-i-run-1_174/index.html',
#   Decimal('49.97'),
#   'In stock',
#   4,
#   33),
#  (940,
#   'The Dirty Little Secrets of Getting Your Dream Job',
#   'http://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#   Decimal('33.34'),
#   'In stock',
#   4,
#   34),
#  (941,
#   'The Third Wave: An Entrepreneur’s Vision of the Future',
#   'http://books.toscrape.com/catalogue/the-third-wave-an-entrepreneurs-vision-of-the-future_862/index.html',
#   Decimal('12.61'),
#   'In stock',
#   3,
#   34),
#  (942,
#   'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#   'http://books.toscrape.com/catalogue/the-10-entrepreneur-live-your-startup-dream-without-quitting-your-day-job_836/index.html',
#   Decimal('27.55'),
#   'In stock',
#   3,
#   34),
#  (943,
#   'Shoe Dog: A Memoir by the Creator of NIKE',
#   'http://books.toscrape.com/catalogue/shoe-dog-a-memoir-by-the-creator-of-nike_831/index.html',
#   Decimal('23.99'),
#   'In stock',
#   2,
#   34),
#  (944,
#   'Made to Stick: Why Some Ideas Survive and Others Die',
#   'http://books.toscrape.com/catalogue/made-to-stick-why-some-ideas-survive-and-others-die_715/index.html',
#   Decimal('38.85'),
#   'In stock',
#   5,
#   34),
#  (945,
#   'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#   'http://books.toscrape.com/catalogue/quench-your-own-thirst-business-lessons-learned-over-a-beer-or-two_629/index.html',
#   Decimal('43.14'),
#   'In stock',
#   1,
#   34),
#  (946,
#   'The Art of Startup Fundraising',
#   'http://books.toscrape.com/catalogue/the-art-of-startup-fundraising_606/index.html',
#   Decimal('21.00'),
#   'In stock',
#   3,
#   34),
#  (947,
#   'Born for This: How to Find the Work You Were Meant to Do',
#   'http://books.toscrape.com/catalogue/born-for-this-how-to-find-the-work-you-were-meant-to-do_588/index.html',
#   Decimal('21.59'),
#   'In stock',
#   5,
#   34),
#  (948,
#   "The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",
#   'http://books.toscrape.com/catalogue/the-e-myth-revisited-why-most-small-businesses-dont-work-and-what-to-do-about-it_545/index.html',
#   Decimal('36.91'),
#   'In stock',
#   1,
#   34),
#  (950,
#   "The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses",
#   'http://books.toscrape.com/catalogue/the-lean-startup-how-todays-entrepreneurs-use-continuous-innovation-to-create-radically-successful-businesses_260/index.html',
#   Decimal('33.92'),
#   'In stock',
#   3,
#   34),
#  (951,
#   'Rework',
#   'http://books.toscrape.com/catalogue/rework_212/index.html',
#   Decimal('44.88'),
#   'In stock',
#   2,
#   34),
#  (952,
#   'Louisa: The Extraordinary Life of Mrs. Adams',
#   'http://books.toscrape.com/catalogue/louisa-the-extraordinary-life-of-mrs-adams_818/index.html',
#   Decimal('16.85'),
#   'In stock',
#   3,
#   35),
#  (953,
#   'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   'http://books.toscrape.com/catalogue/setting-the-world-on-fire-the-brief-astonishing-life-of-st-catherine-of-siena_603/index.html',
#   Decimal('21.15'),
#   'In stock',
#   2,
#   35),
#  (954,
#   "The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",
#   'http://books.toscrape.com/catalogue/the-faith-of-christopher-hitchens-the-restless-soul-of-the-worlds-most-notorious-atheist_495/index.html',
#   Decimal('39.55'),
#   'In stock',
#   1,
#   35),
#  (955,
#   'Benjamin Franklin: An American Life',
#   'http://books.toscrape.com/catalogue/benjamin-franklin-an-american-life_460/index.html',
#   Decimal('48.19'),
#   'In stock',
#   3,
#   35),
#  (956,
#   'The Rise of Theodore Roosevelt (Theodore Roosevelt #1)',
#   'http://books.toscrape.com/catalogue/the-rise-of-theodore-roosevelt-theodore-roosevelt-1_276/index.html',
#   Decimal('42.57'),
#   'In stock',
#   3,
#   35),
#  (957,
#   'In Her Wake',
#   'http://books.toscrape.com/catalogue/in-her-wake_980/index.html',
#   Decimal('12.84'),
#   'In stock',
#   3,
#   36),
#  (958,
#   'The Elephant Tree',
#   'http://books.toscrape.com/catalogue/the-elephant-tree_968/index.html',
#   Decimal('23.82'),
#   'In stock',
#   5,
#   36),
#  (959,
#   'Behind Closed Doors',
#   'http://books.toscrape.com/catalogue/behind-closed-doors_962/index.html',
#   Decimal('52.22'),
#   'In stock',
#   4,
#   36),
#  (960,
#   'You (You #1)',
#   'http://books.toscrape.com/catalogue/you-you-1_784/index.html',
#   Decimal('43.61'),
#   'In stock',
#   5,
#   36),
#  (961,
#   'The Guilty (Will Robie #4)',
#   'http://books.toscrape.com/catalogue/the-guilty-will-robie-4_750/index.html',
#   Decimal('13.82'),
#   'In stock',
#   3,
#   36),
#  (962,
#   'The 14th Colony (Cotton Malone #11)',
#   'http://books.toscrape.com/catalogue/the-14th-colony-cotton-malone-11_744/index.html',
#   Decimal('39.24'),
#   'In stock',
#   1,
#   36),
#  (963,
#   'Give It Back',
#   'http://books.toscrape.com/catalogue/give-it-back_430/index.html',
#   Decimal('18.32'),
#   'In stock',
#   3,
#   36),
#  (964,
#   'Killing Floor (Jack Reacher #1)',
#   'http://books.toscrape.com/catalogue/killing-floor-jack-reacher-1_382/index.html',
#   Decimal('31.49'),
#   'In stock',
#   4,
#   36),
#  (965,
#   'The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)',
#   'http://books.toscrape.com/catalogue/the-bone-hunters-lexy-vaughan-steven-macaulay-2_343/index.html',
#   Decimal('59.71'),
#   'In stock',
#   3,
#   36),
#  (966,
#   'Far From True (Promise Falls Trilogy #2)',
#   'http://books.toscrape.com/catalogue/far-from-true-promise-falls-trilogy-2_320/index.html',
#   Decimal('34.93'),
#   'In stock',
#   2,
#   36),
#  (967,
#   'The Travelers',
#   'http://books.toscrape.com/catalogue/the-travelers_285/index.html',
#   Decimal('15.77'),
#   'In stock',
#   3,
#   36),
#  (968,
#   'When We Collided',
#   'http://books.toscrape.com/catalogue/when-we-collided_955/index.html',
#   Decimal('31.77'),
#   'In stock',
#   1,
#   37),
#  (969,
#   'Someone Like You (The Harrisons #2)',
#   'http://books.toscrape.com/catalogue/someone-like-you-the-harrisons-2_735/index.html',
#   Decimal('52.79'),
#   'In stock',
#   5,
#   37),
#  (970,
#   'We Are All Completely Beside Ourselves',
#   'http://books.toscrape.com/catalogue/we-are-all-completely-beside-ourselves_301/index.html',
#   Decimal('24.04'),
#   'In stock',
#   1,
#   37),
#  (971,
#   'The Four Agreements: A Practical Guide to Personal Freedom',
#   'http://books.toscrape.com/catalogue/the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html',
#   Decimal('17.66'),
#   'In stock',
#   3,
#   38),
#  (972,
#   "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   'http://books.toscrape.com/catalogue/the-activists-tao-te-ching-ancient-advice-for-a-modern-revolution_928/index.html',
#   Decimal('32.24'),
#   'In stock',
#   5,
#   38),
#  (973,
#   'Chasing Heaven: What Dying Taught Me About Living',
#   'http://books.toscrape.com/catalogue/chasing-heaven-what-dying-taught-me-about-living_797/index.html',
#   Decimal('37.80'),
#   'In stock',
#   2,
#   38),
#  (974,
#   "If I Gave You God's Phone Number....: Searching for Spirituality in America",
#   'http://books.toscrape.com/catalogue/if-i-gave-you-gods-phone-number-searching-for-spirituality-in-america_564/index.html',
#   Decimal('20.91'),
#   'In stock',
#   1,
#   38),
#  (975,
#   'Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain',
#   'http://books.toscrape.com/catalogue/unreasonable-hope-finding-faith-in-the-god-who-brings-purpose-to-your-pain_505/index.html',
#   Decimal('46.33'),
#   'In stock',
#   2,
#   38),
#  (976,
#   "A New Earth: Awakening to Your Life's Purpose",
#   'http://books.toscrape.com/catalogue/a-new-earth-awakening-to-your-lifes-purpose_311/index.html',
#   Decimal('55.65'),
#   'In stock',
#   5,
#   38),
#  (977,
#   'Logan Kade (Fallen Crest High #5.5)',
#   'http://books.toscrape.com/catalogue/logan-kade-fallen-crest-high-55_384/index.html',
#   Decimal('13.12'),
#   'In stock',
#   3,
#   39),
#  (978,
#   'Online Marketing for Busy Authors: A Step-By-Step Guide',
#   'http://books.toscrape.com/catalogue/online-marketing-for-busy-authors-a-step-by-step-guide_913/index.html',
#   Decimal('46.35'),
#   'In stock',
#   1,
#   40),
#  (979,
#   'How to Be Miserable: 40 Strategies You Already Use',
#   'http://books.toscrape.com/catalogue/how-to-be-miserable-40-strategies-you-already-use_897/index.html',
#   Decimal('46.03'),
#   'In stock',
#   1,
#   40),
#  (980,
#   'Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress',
#   'http://books.toscrape.com/catalogue/overload-how-to-unplug-unwind-and-unleash-yourself-from-the-pressure-of-stress_725/index.html',
#   Decimal('52.15'),
#   'In stock',
#   3,
#   40),
#  (981,
#   'You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#   'http://books.toscrape.com/catalogue/you-are-a-badass-how-to-stop-doubting-your-greatness-and-start-living-an-awesome-life_508/index.html',
#   Decimal('12.08'),
#   'In stock',
#   3,
#   40),
#  (982,
#   'How to Stop Worrying and Start Living',
#   'http://books.toscrape.com/catalogue/how-to-stop-worrying-and-start-living_431/index.html',
#   Decimal('46.49'),
#   'In stock',
#   5,
#   40),
#  (983,
#   'All the Light We Cannot See',
#   'http://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html',
#   Decimal('29.87'),
#   'In stock',
#   5,
#   41),
#  (984,
#   'The Girl You Left Behind (The Girl You Left Behind #1)',
#   'http://books.toscrape.com/catalogue/the-girl-you-left-behind-the-girl-you-left-behind-1_443/index.html',
#   Decimal('15.79'),
#   'In stock',
#   3,
#   41),
#  (985,
#   '(Un)Qualified: How God Uses Broken People to Do Big Things',
#   'http://books.toscrape.com/catalogue/unqualified-how-god-uses-broken-people-to-do-big-things_873/index.html',
#   Decimal('54.00'),
#   'In stock',
#   5,
#   42),
#  (986,
#   'Crazy Love: Overwhelmed by a Relentless God',
#   'http://books.toscrape.com/catalogue/crazy-love-overwhelmed-by-a-relentless-god_682/index.html',
#   Decimal('47.72'),
#   'In stock',
#   2,
#   42),
#  (987,
#   'Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',
#   'http://books.toscrape.com/catalogue/blue-like-jazz-nonreligious-thoughts-on-christian-spirituality_461/index.html',
#   Decimal('25.77'),
#   'In stock',
#   1,
#   42),
#  (988,
#   'Silence in the Dark (Logan Point #4)',
#   'http://books.toscrape.com/catalogue/silence-in-the-dark-logan-point-4_542/index.html',
#   Decimal('58.33'),
#   'In stock',
#   3,
#   43),
#  (989,
#   'The Grownup',
#   'http://books.toscrape.com/catalogue/the-grownup_546/index.html',
#   Decimal('35.88'),
#   'In stock',
#   1,
#   44),
#  (990,
#   'Suzie Snowflake: One beautiful flake (a self-esteem story)',
#   'http://books.toscrape.com/catalogue/suzie-snowflake-one-beautiful-flake-a-self-esteem-story_568/index.html',
#   Decimal('54.81'),
#   'In stock',
#   5,
#   45),
#  (991,
#   'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#   'http://books.toscrape.com/catalogue/the-bulletproof-diet-lose-up-to-a-pound-a-day-reclaim-energy-and-focus-upgrade-your-life_931/index.html',
#   Decimal('49.05'),
#   'In stock',
#   3,
#   46),
#  (993,
#   '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#   'http://books.toscrape.com/catalogue/10-day-green-smoothie-cleanse-lose-up-to-15-pounds-in-10-days_581/index.html',
#   Decimal('49.71'),
#   'In stock',
#   5,
#   46),
#  (994,
#   'The Art and Science of Low Carbohydrate Living',
#   'http://books.toscrape.com/catalogue/the-art-and-science-of-low-carbohydrate-living_570/index.html',
#   Decimal('52.98'),
#   'In stock',
#   5,
#   46),
#  (996,
#   'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   'http://books.toscrape.com/catalogue/why-the-right-went-wrong-conservatism-from-goldwater-to-the-tea-party-and-beyond_781/index.html',
#   Decimal('52.65'),
#   'In stock',
#   4,
#   47),
#  (998,
#   'Amid the Chaos',
#   'http://books.toscrape.com/catalogue/amid-the-chaos_788/index.html',
#   Decimal('36.58'),
#   'In stock',
#   1,
#   48),
#  (999,
#   'Dark Notes',
#   'http://books.toscrape.com/catalogue/dark-notes_800/index.html',
#   Decimal('19.19'),
#   'In stock',
#   3,
#   49),
#  (1000,
#   'The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   'http://books.toscrape.com/catalogue/the-long-shadow-of-small-ghosts-murder-and-memory-in-an-american-city_848/index.html',
#   Decimal('10.97'),
#   'In stock',
#   3,
#   50),
#  (1001,
#   'Sapiens: A Brief History of Humankind',
#   '#',
#   Decimal('49.99'),
#   'In stock',
#   5,
#   54),
#  (1002, 'Guns, Germs, and Steel', '#', Decimal('39.50'), 'In stock', 4, 54),
#  (1003, 'The Silk Roads', '#', Decimal('35.00'), 'In stock', 4, 54),
#  (1004, 'The Wright Brothers', '#', Decimal('28.90'), 'In stock', 3, 54),
#  (1005,
#   'The History of the Ancient World',
#   '#',
#   Decimal('41.75'),
#   'In stock',
#   5,
#   54)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#      book_id                                              title  \
# 0          1                            It's Only the Himalayas
# 1          2  Full Moon over Noah’s Ark: An Odyssey to Mount...
# 2          3  See America: A Celebration of Our National Par...
# 3          4  Vagabonding: An Uncommon Guide to the Art of L...
# 4          5                               Under the Tuscan Sun
# ..       ...                                                ...
# 926     1001              Sapiens: A Brief History of Humankind
# 927     1002                             Guns, Germs, and Steel
# 928     1003                                     The Silk Roads
# 929     1004                                The Wright Brothers
# 930     1005                   The History of the Ancient World
#
#                                                    url  price availability  \
# 0    http://books.toscrape.com/catalogue/its-only-t...  45.17     In stock
# 1    http://books.toscrape.com/catalogue/full-moon-...  49.43     In stock
# 2    http://books.toscrape.com/catalogue/see-americ...  48.87     In stock
# 3    http://books.toscrape.com/catalogue/vagabondin...  36.94     In stock
# 4    http://books.toscrape.com/catalogue/under-the-...  37.33     In stock
# ..                                                 ...    ...          ...
# 926                                                  #  49.99     In stock
# 927                                                  #  39.50     In stock
# 928                                                  #  35.00     In stock
# 929                                                  #  28.90     In stock
# 930                                                  #  41.75     In stock
#
#      rating  category_id
# 0         2            1
# 1         4            1
# 2         3            1
# 3         2            1
# 4         3            1
# ..      ...          ...
# 926       5           54
# 927       4           54
# 928       4           54
# 929       3           54
# 930       5           54
#
# [931 rows x 7 columns]

# %% [markdown]
# #### 03) Write a sql query to get books that has rate not 3.

# %%
qry = '''
SELECT * FROM books_catalog 
WHERE rating <> 3;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(1,
#   "It's Only the Himalayas",
#   'http://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html',
#   Decimal('45.17'),
#   'In stock',
#   2,
#   1),
#  (2,
#   'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#   'http://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html',
#   Decimal('49.43'),
#   'In stock',
#   4,
#   1),
#  (4,
#   'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   'http://books.toscrape.com/catalogue/vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html',
#   Decimal('36.94'),
#   'In stock',
#   2,
#   1),
#  (6,
#   'A Summer In Europe',
#   'http://books.toscrape.com/catalogue/a-summer-in-europe_458/index.html',
#   Decimal('44.34'),
#   'In stock',
#   2,
#   1),
#  (7,
#   'The Great Railway Bazaar',
#   'http://books.toscrape.com/catalogue/the-great-railway-bazaar_446/index.html',
#   Decimal('30.54'),
#   'In stock',
#   1,
#   1),
#  (8,
#   'A Year in Provence (Provence #1)',
#   'http://books.toscrape.com/catalogue/a-year-in-provence-provence-1_421/index.html',
#   Decimal('56.88'),
#   'In stock',
#   4,
#   1),
#  (9,
#   'The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#   'http://books.toscrape.com/catalogue/the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html',
#   Decimal('23.21'),
#   'In stock',
#   1,
#   1),
#  (11,
#   '1,000 Places to See Before You Die',
#   'http://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html',
#   Decimal('26.08'),
#   'In stock',
#   5,
#   1),
#  (12,
#   'Sharp Objects',
#   'http://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#   Decimal('47.82'),
#   'In stock',
#   4,
#   2),
#  (14,
#   'The Past Never Ends',
#   'http://books.toscrape.com/catalogue/the-past-never-ends_942/index.html',
#   Decimal('56.50'),
#   'In stock',
#   4,
#   2),
#  (16,
#   'The Murder of Roger Ackroyd (Hercule Poirot #4)',
#   'http://books.toscrape.com/catalogue/the-murder-of-roger-ackroyd-hercule-poirot-4_852/index.html',
#   Decimal('44.10'),
#   'In stock',
#   4,
#   2),
#  (20,
#   'A Time of Torment (Charlie Parker #14)',
#   'http://books.toscrape.com/catalogue/a-time-of-torment-charlie-parker-14_657/index.html',
#   Decimal('48.35'),
#   'In stock',
#   5,
#   2),
#  (23,
#   'Murder at the 42nd Street Library (Raymond Ambler #1)',
#   'http://books.toscrape.com/catalogue/murder-at-the-42nd-street-library-raymond-ambler-1_624/index.html',
#   Decimal('54.36'),
#   'In stock',
#   4,
#   2),
#  (27,
#   'The Widow',
#   'http://books.toscrape.com/catalogue/the-widow_609/index.html',
#   Decimal('27.26'),
#   'In stock',
#   2,
#   2),
#  (29,
#   'What Happened on Beale Street (Secrets of the South Mysteries #2)',
#   'http://books.toscrape.com/catalogue/what-happened-on-beale-street-secrets-of-the-south-mysteries-2_506/index.html',
#   Decimal('25.37'),
#   'In stock',
#   5,
#   2),
#  (30,
#   "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#   'http://books.toscrape.com/catalogue/the-bachelor-girls-guide-to-murder-herringford-and-watts-mysteries-1_491/index.html',
#   Decimal('52.30'),
#   'In stock',
#   5,
#   2),
#  (31,
#   'Delivering the Truth (Quaker Midwife Mystery #1)',
#   'http://books.toscrape.com/catalogue/delivering-the-truth-quaker-midwife-mystery-1_464/index.html',
#   Decimal('20.89'),
#   'In stock',
#   4,
#   2),
#  (32,
#   'The Mysterious Affair at Styles (Hercule Poirot #1)',
#   'http://books.toscrape.com/catalogue/the-mysterious-affair-at-styles-hercule-poirot-1_452/index.html',
#   Decimal('24.80'),
#   'In stock',
#   4,
#   2),
#  (33,
#   'In the Woods (Dublin Murder Squad #1)',
#   'http://books.toscrape.com/catalogue/in-the-woods-dublin-murder-squad-1_433/index.html',
#   Decimal('38.38'),
#   'In stock',
#   2,
#   2),
#  (34,
#   'The Silkworm (Cormoran Strike #2)',
#   'http://books.toscrape.com/catalogue/the-silkworm-cormoran-strike-2_280/index.html',
#   Decimal('23.05'),
#   'In stock',
#   5,
#   2),
#  (38,
#   'Career of Evil (Cormoran Strike #3)',
#   'http://books.toscrape.com/catalogue/career-of-evil-cormoran-strike-3_137/index.html',
#   Decimal('24.72'),
#   'In stock',
#   2,
#   2),
#  (39,
#   "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#   'http://books.toscrape.com/catalogue/the-no-1-ladies-detective-agency-no-1-ladies-detective-agency-1_76/index.html',
#   Decimal('57.70'),
#   'In stock',
#   4,
#   2),
#  (46,
#   'A Flight of Arrows (The Pathfinders #2)',
#   'http://books.toscrape.com/catalogue/a-flight-of-arrows-the-pathfinders-2_876/index.html',
#   Decimal('55.53'),
#   'In stock',
#   5,
#   3),
#  (47,
#   'The House by the Lake',
#   'http://books.toscrape.com/catalogue/the-house-by-the-lake_846/index.html',
#   Decimal('36.95'),
#   'In stock',
#   1,
#   3),
#  (48,
#   'Mrs. Houdini',
#   'http://books.toscrape.com/catalogue/mrs-houdini_821/index.html',
#   Decimal('30.25'),
#   'In stock',
#   5,
#   3),
#  (49,
#   'The Marriage of Opposites',
#   'http://books.toscrape.com/catalogue/the-marriage-of-opposites_759/index.html',
#   Decimal('28.08'),
#   'In stock',
#   4,
#   3),
#  (51,
#   'Love, Lies and Spies',
#   'http://books.toscrape.com/catalogue/love-lies-and-spies_622/index.html',
#   Decimal('20.55'),
#   'In stock',
#   2,
#   3),
#  (52,
#   'A Paris Apartment',
#   'http://books.toscrape.com/catalogue/a-paris-apartment_612/index.html',
#   Decimal('39.01'),
#   'In stock',
#   4,
#   3),
#  (55,
#   'The Invention of Wings',
#   'http://books.toscrape.com/catalogue/the-invention-of-wings_448/index.html',
#   Decimal('37.34'),
#   'In stock',
#   1,
#   3),
#  (56,
#   'World Without End (The Pillars of the Earth #2)',
#   'http://books.toscrape.com/catalogue/world-without-end-the-pillars-of-the-earth-2_420/index.html',
#   Decimal('32.97'),
#   'In stock',
#   4,
#   3),
#  (57,
#   'The Passion of Dolssa',
#   'http://books.toscrape.com/catalogue/the-passion-of-dolssa_351/index.html',
#   Decimal('28.32'),
#   'In stock',
#   5,
#   3),
#  (58,
#   'Girl With a Pearl Earring',
#   'http://books.toscrape.com/catalogue/girl-with-a-pearl-earring_322/index.html',
#   Decimal('26.77'),
#   'In stock',
#   1,
#   3),
#  (59,
#   'Voyager (Outlander #3)',
#   'http://books.toscrape.com/catalogue/voyager-outlander-3_299/index.html',
#   Decimal('21.07'),
#   'In stock',
#   5,
#   3),
#  (60,
#   'The Red Tent',
#   'http://books.toscrape.com/catalogue/the-red-tent_273/index.html',
#   Decimal('35.66'),
#   'In stock',
#   5,
#   3),
#  (62,
#   'The Guernsey Literary and Potato Peel Pie Society',
#   'http://books.toscrape.com/catalogue/the-guernsey-literary-and-potato-peel-pie-society_253/index.html',
#   Decimal('49.53'),
#   'In stock',
#   1,
#   3),
#  (63,
#   'Girl in the Blue Coat',
#   'http://books.toscrape.com/catalogue/girl-in-the-blue-coat_160/index.html',
#   Decimal('46.83'),
#   'In stock',
#   2,
#   3),
#  (64,
#   'Between Shades of Gray',
#   'http://books.toscrape.com/catalogue/between-shades-of-gray_128/index.html',
#   Decimal('20.79'),
#   'In stock',
#   5,
#   3),
#  (65,
#   'While You Were Mine',
#   'http://books.toscrape.com/catalogue/while-you-were-mine_97/index.html',
#   Decimal('41.32'),
#   'In stock',
#   5,
#   3),
#  (68,
#   'Lost Among the Living',
#   'http://books.toscrape.com/catalogue/lost-among-the-living_31/index.html',
#   Decimal('27.70'),
#   'In stock',
#   4,
#   3),
#  (70,
#   "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   'http://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html',
#   Decimal('52.29'),
#   'In stock',
#   5,
#   4),
#  (73,
#   'The Nameless City (The Nameless City #1)',
#   'http://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html',
#   Decimal('38.16'),
#   'In stock',
#   4,
#   4),
#  (80,
#   'orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   'http://books.toscrape.com/catalogue/orange-the-complete-collection-1-orange-the-complete-collection-1_914/index.html',
#   Decimal('48.41'),
#   'In stock',
#   1,
#   4),
#  (81,
#   'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   'http://books.toscrape.com/catalogue/lumberjanes-vol-2-friendship-to-the-max-lumberjanes-5-8_907/index.html',
#   Decimal('46.91'),
#   'In stock',
#   2,
#   4),
#  (84,
#   'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   'http://books.toscrape.com/catalogue/i-hate-fairyland-vol-1-madly-ever-after-i-hate-fairyland-compilations-1-5_899/index.html',
#   Decimal('29.17'),
#   'In stock',
#   2,
#   4),
#  (86,
#   'Giant Days, Vol. 2 (Giant Days #5-8)',
#   'http://books.toscrape.com/catalogue/giant-days-vol-2-giant-days-5-8_895/index.html',
#   Decimal('22.11'),
#   'In stock',
#   2,
#   4),
#  (87,
#   'Danganronpa Volume 1',
#   'http://books.toscrape.com/catalogue/danganronpa-volume-1_889/index.html',
#   Decimal('51.99'),
#   'In stock',
#   4,
#   4),
#  (88,
#   'Codename Baboushka, Volume 1: The Conclave of Death',
#   'http://books.toscrape.com/catalogue/codename-baboushka-volume-1-the-conclave-of-death_887/index.html',
#   Decimal('36.72'),
#   'In stock',
#   4,
#   4),
#  (90,
#   'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   'http://books.toscrape.com/catalogue/bitch-planet-vol-1-extraordinary-machine-bitch-planet-collected-editions_882/index.html',
#   Decimal('37.92'),
#   'In stock',
#   2,
#   4),
#  (91,
#   'The Shadow Hero (The Shadow Hero)',
#   'http://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html',
#   Decimal('33.14'),
#   'In stock',
#   1,
#   4),
#  (92,
#   'Fables, Vol. 1: Legends in Exile (Fables #1)',
#   'http://books.toscrape.com/catalogue/fables-vol-1-legends-in-exile-fables-1_806/index.html',
#   Decimal('41.62'),
#   'In stock',
#   4,
#   4),
#  (93,
#   'Batman: The Long Halloween (Batman)',
#   'http://books.toscrape.com/catalogue/batman-the-long-halloween-batman_793/index.html',
#   Decimal('36.50'),
#   'In stock',
#   2,
#   4),
#  (95,
#   'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   'http://books.toscrape.com/catalogue/wonder-woman-earth-one-volume-one-wonder-woman-earth-one-1_783/index.html',
#   Decimal('37.34'),
#   'In stock',
#   4,
#   4),
#  (97,
#   'Through the Woods',
#   'http://books.toscrape.com/catalogue/through-the-woods_772/index.html',
#   Decimal('25.38'),
#   'In stock',
#   2,
#   4),
#  (99,
#   'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#   'http://books.toscrape.com/catalogue/so-cute-it-hurts-vol-6-so-cute-it-hurts-6_734/index.html',
#   Decimal('35.43'),
#   'In stock',
#   4,
#   4),
#  (101,
#   'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#   'http://books.toscrape.com/catalogue/red-hoodarsenal-vol-1-open-for-business-red-hoodarsenal-1_729/index.html',
#   Decimal('25.48'),
#   'In stock',
#   2,
#   4),
#  (102,
#   'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#   'http://books.toscrape.com/catalogue/naruto-3-in-1-edition-vol-14-includes-vols-40-41-42-naruto-omnibus-14_721/index.html',
#   Decimal('38.39'),
#   'In stock',
#   2,
#   4),
#  (104,
#   'El Deafo',
#   'http://books.toscrape.com/catalogue/el-deafo_691/index.html',
#   Decimal('57.62'),
#   'In stock',
#   5,
#   4),
#  (105,
#   'Batman: Europa',
#   'http://books.toscrape.com/catalogue/batman-europa_668/index.html',
#   Decimal('32.01'),
#   'In stock',
#   2,
#   4),
#  (108,
#   'Fruits Basket, Vol. 9 (Fruits Basket #9)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-9-fruits-basket-9_563/index.html',
#   Decimal('33.95'),
#   'In stock',
#   4,
#   4),
#  (111,
#   'Fruits Basket, Vol. 6 (Fruits Basket #6)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-6-fruits-basket-6_427/index.html',
#   Decimal('20.96'),
#   'In stock',
#   4,
#   4),
#  (115,
#   'The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of Momochi House #4)',
#   'http://books.toscrape.com/catalogue/the-demon-prince-of-momochi-house-vol-4-the-demon-prince-of-momochi-house-4_344/index.html',
#   Decimal('27.88'),
#   'In stock',
#   2,
#   4),
#  (116,
#   'Fruits Basket, Vol. 4 (Fruits Basket #4)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-4-fruits-basket-4_321/index.html',
#   Decimal('50.44'),
#   'In stock',
#   4,
#   4),
#  (118,
#   'The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)',
#   'http://books.toscrape.com/catalogue/the-sandman-vol-3-dream-country-the-sandman-volumes-3_279/index.html',
#   Decimal('55.55'),
#   'In stock',
#   5,
#   4),
#  (119,
#   'Saga, Volume 3 (Saga (Collected Editions) #3)',
#   'http://books.toscrape.com/catalogue/saga-volume-3-saga-collected-editions-3_216/index.html',
#   Decimal('21.57'),
#   'In stock',
#   5,
#   4),
#  (121,
#   'Persepolis: The Story of a Childhood (Persepolis #1-2)',
#   'http://books.toscrape.com/catalogue/persepolis-the-story-of-a-childhood-persepolis-1-2_206/index.html',
#   Decimal('39.13'),
#   'In stock',
#   1,
#   4),
#  (123,
#   'Grayson, Vol 3: Nemesis (Grayson #3)',
#   'http://books.toscrape.com/catalogue/grayson-vol-3-nemesis-grayson-3_164/index.html',
#   Decimal('42.72'),
#   'In stock',
#   1,
#   4),
#  (124,
#   'Fruits Basket, Vol. 3 (Fruits Basket #3)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-3-fruits-basket-3_159/index.html',
#   Decimal('45.17'),
#   'In stock',
#   2,
#   4),
#  (125,
#   'Black Butler, Vol. 1 (Black Butler #1)',
#   'http://books.toscrape.com/catalogue/black-butler-vol-1-black-butler-1_130/index.html',
#   Decimal('49.31'),
#   'In stock',
#   1,
#   4),
#  (126,
#   'Awkward',
#   'http://books.toscrape.com/catalogue/awkward_124/index.html',
#   Decimal('38.02'),
#   'In stock',
#   2,
#   4),
#  (131,
#   'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#   'http://books.toscrape.com/catalogue/the-wicked-the-divine-vol-1-the-faust-act-the-wicked-the-divine_86/index.html',
#   Decimal('36.52'),
#   'In stock',
#   2,
#   4),
#  (135,
#   'Saga, Volume 1 (Saga (Collected Editions) #1)',
#   'http://books.toscrape.com/catalogue/saga-volume-1-saga-collected-editions-1_48/index.html',
#   Decimal('28.48'),
#   'In stock',
#   1,
#   4),
#  (136,
#   'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#   'http://books.toscrape.com/catalogue/rat-queens-vol-1-sass-sorcery-rat-queens-collected-editions-1-5_46/index.html',
#   Decimal('46.96'),
#   'In stock',
#   5,
#   4),
#  (137,
#   'Paper Girls, Vol. 1 (Paper Girls #1-5)',
#   'http://books.toscrape.com/catalogue/paper-girls-vol-1-paper-girls-1-5_44/index.html',
#   Decimal('21.71'),
#   'In stock',
#   4,
#   4),
#  (139,
#   'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#   'http://books.toscrape.com/catalogue/ms-marvel-vol-1-no-normal-ms-marvel-2014-2015-1_34/index.html',
#   Decimal('39.39'),
#   'In stock',
#   4,
#   4),
#  (141,
#   'Giant Days, Vol. 1 (Giant Days #1-4)',
#   'http://books.toscrape.com/catalogue/giant-days-vol-1-giant-days-1-4_22/index.html',
#   Decimal('56.76'),
#   'In stock',
#   4,
#   4),
#  (142,
#   'Fruits Basket, Vol. 1 (Fruits Basket #1)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-1-fruits-basket-1_21/index.html',
#   Decimal('40.28'),
#   'In stock',
#   5,
#   4),
#  (143,
#   'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#   'http://books.toscrape.com/catalogue/bleach-vol-1-strawberry-and-the-soul-reapers-bleach-1_7/index.html',
#   Decimal('34.65'),
#   'In stock',
#   5,
#   4),
#  (144,
#   'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#   'http://books.toscrape.com/catalogue/ajin-demi-human-volume-1-ajin-demi-human-1_4/index.html',
#   Decimal('57.06'),
#   'In stock',
#   4,
#   4),
#  (146,
#   'The Metamorphosis',
#   'http://books.toscrape.com/catalogue/the-metamorphosis_409/index.html',
#   Decimal('28.58'),
#   'In stock',
#   1,
#   5),
#  (149,
#   'Little Women (Little Women #1)',
#   'http://books.toscrape.com/catalogue/little-women-little-women-1_331/index.html',
#   Decimal('28.07'),
#   'In stock',
#   4,
#   5),
#  (154,
#   'The Picture of Dorian Gray',
#   'http://books.toscrape.com/catalogue/the-picture-of-dorian-gray_270/index.html',
#   Decimal('29.70'),
#   'In stock',
#   2,
#   5),
#  (155,
#   'The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',
#   'http://books.toscrape.com/catalogue/the-complete-stories-and-poems-the-works-of-edgar-allan-poe-cameo-edition_238/index.html',
#   Decimal('26.78'),
#   'In stock',
#   4,
#   5),
#  (156,
#   'Beowulf',
#   'http://books.toscrape.com/catalogue/beowulf_126/index.html',
#   Decimal('38.35'),
#   'In stock',
#   2,
#   5),
#  (157,
#   'And Then There Were None',
#   'http://books.toscrape.com/catalogue/and-then-there-were-none_119/index.html',
#   Decimal('35.01'),
#   'In stock',
#   2,
#   5),
#  (158,
#   'The Story of Hong Gildong',
#   'http://books.toscrape.com/catalogue/the-story-of-hong-gildong_84/index.html',
#   Decimal('43.19'),
#   'In stock',
#   4,
#   5),
#  (159,
#   'The Little Prince',
#   'http://books.toscrape.com/catalogue/the-little-prince_72/index.html',
#   Decimal('45.42'),
#   'In stock',
#   2,
#   5),
#  (160,
#   'Sense and Sensibility',
#   'http://books.toscrape.com/catalogue/sense-and-sensibility_49/index.html',
#   Decimal('37.46'),
#   'In stock',
#   1,
#   5),
#  (161,
#   'Of Mice and Men',
#   'http://books.toscrape.com/catalogue/of-mice-and-men_37/index.html',
#   Decimal('47.11'),
#   'In stock',
#   2,
#   5),
#  (162,
#   'Emma',
#   'http://books.toscrape.com/catalogue/emma_17/index.html',
#   Decimal('32.93'),
#   'In stock',
#   2,
#   5),
#  (165,
#   'The Death of Humanity: and the Case for Life',
#   'http://books.toscrape.com/catalogue/the-death-of-humanity-and-the-case-for-life_932/index.html',
#   Decimal('58.11'),
#   'In stock',
#   4,
#   6),
#  (168,
#   'Kierkegaard: A Christian Missionary to Christians',
#   'http://books.toscrape.com/catalogue/kierkegaard-a-christian-missionary-to-christians_527/index.html',
#   Decimal('47.13'),
#   'In stock',
#   1,
#   6),
#  (169,
#   'At The Existentialist Café: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',
#   'http://books.toscrape.com/catalogue/at-the-existentialist-cafe-freedom-being-and-apricot-cocktails-with-jean-paul-sartre-simone-de-beauvoir-albert-camus-martin-heidegger-edmund-husserl-karl-jaspers-maurice-merleau-ponty-and-others_459/index.html',
#   Decimal('29.93'),
#   'In stock',
#   5,
#   6),
#  (170,
#   'Critique of Pure Reason',
#   'http://books.toscrape.com/catalogue/critique-of-pure-reason_366/index.html',
#   Decimal('20.75'),
#   'In stock',
#   1,
#   6),
#  (171,
#   'Run, Spot, Run: The Ethics of Keeping Pets',
#   'http://books.toscrape.com/catalogue/run-spot-run-the-ethics-of-keeping-pets_106/index.html',
#   Decimal('20.02'),
#   'In stock',
#   1,
#   6),
#  (172,
#   'The Nicomachean Ethics',
#   'http://books.toscrape.com/catalogue/the-nicomachean-ethics_75/index.html',
#   Decimal('36.34'),
#   'In stock',
#   1,
#   6),
#  (173,
#   'Meditations',
#   'http://books.toscrape.com/catalogue/meditations_33/index.html',
#   Decimal('25.89'),
#   'In stock',
#   2,
#   6),
#  (174,
#   'Beyond Good and Evil',
#   'http://books.toscrape.com/catalogue/beyond-good-and-evil_6/index.html',
#   Decimal('43.38'),
#   'In stock',
#   1,
#   6),
#  (175,
#   'Chase Me (Paris Nights #2)',
#   'http://books.toscrape.com/catalogue/chase-me-paris-nights-2_977/index.html',
#   Decimal('25.27'),
#   'In stock',
#   5,
#   7),
#  (176,
#   'Black Dust',
#   'http://books.toscrape.com/catalogue/black-dust_976/index.html',
#   Decimal('34.53'),
#   'In stock',
#   5,
#   7),
#  (177,
#   'Her Backup Boyfriend (The Sorensen Family #1)',
#   'http://books.toscrape.com/catalogue/her-backup-boyfriend-the-sorensen-family-1_896/index.html',
#   Decimal('33.97'),
#   'In stock',
#   1,
#   7),
#  (179,
#   'Fifty Shades Darker (Fifty Shades #2)',
#   'http://books.toscrape.com/catalogue/fifty-shades-darker-fifty-shades-2_892/index.html',
#   Decimal('21.96'),
#   'In stock',
#   1,
#   7),
#  (180,
#   'The Wedding Dress',
#   'http://books.toscrape.com/catalogue/the-wedding-dress_864/index.html',
#   Decimal('24.12'),
#   'In stock',
#   1,
#   7),
#  (185,
#   'Hold Your Breath (Search and Rescue #1)',
#   'http://books.toscrape.com/catalogue/hold-your-breath-search-and-rescue-1_700/index.html',
#   Decimal('28.82'),
#   'In stock',
#   1,
#   7),
#  (186,
#   'Dirty (Dive Bar #1)',
#   'http://books.toscrape.com/catalogue/dirty-dive-bar-1_615/index.html',
#   Decimal('40.83'),
#   'In stock',
#   4,
#   7),
#  (191,
#   "A Girl's Guide to Moving On (New Beginnings #2)",
#   'http://books.toscrape.com/catalogue/a-girls-guide-to-moving-on-new-beginnings-2_359/index.html',
#   Decimal('31.30'),
#   'In stock',
#   1,
#   7),
#  (197,
#   'The Obsession',
#   'http://books.toscrape.com/catalogue/the-obsession_268/index.html',
#   Decimal('45.43'),
#   'In stock',
#   1,
#   7),
#  (199,
#   "Best of My Love (Fool's Gold #20)",
#   'http://books.toscrape.com/catalogue/best-of-my-love-fools-gold-20_127/index.html',
#   Decimal('27.41'),
#   'In stock',
#   2,
#   7),
#  (201,
#   'This One Moment (Pushing Limits #1)',
#   'http://books.toscrape.com/catalogue/this-one-moment-pushing-limits-1_88/index.html',
#   Decimal('48.71'),
#   'In stock',
#   1,
#   7),
#  (202,
#   'Rhythm, Chord & Malykhin',
#   'http://books.toscrape.com/catalogue/rhythm-chord-malykhin_47/index.html',
#   Decimal('28.34'),
#   'In stock',
#   2,
#   7),
#  (203,
#   'My Perfect Mistake (Over the Top #1)',
#   'http://books.toscrape.com/catalogue/my-perfect-mistake-over-the-top-1_35/index.html',
#   Decimal('38.92'),
#   'In stock',
#   2,
#   7),
#  (205,
#   'Imperfect Harmony',
#   'http://books.toscrape.com/catalogue/imperfect-harmony_26/index.html',
#   Decimal('34.74'),
#   'In stock',
#   4,
#   7),
#  (207,
#   'Deep Under (Walker Security #1)',
#   'http://books.toscrape.com/catalogue/deep-under-walker-security-1_15/index.html',
#   Decimal('47.09'),
#   'In stock',
#   5,
#   7),
#  (208,
#   "Charity's Cross (Charles Towne Belles #4)",
#   'http://books.toscrape.com/catalogue/charitys-cross-charles-towne-belles-4_12/index.html',
#   Decimal('41.24'),
#   'In stock',
#   1,
#   7),
#  (209,
#   'Bounty (Colorado Mountain #7)',
#   'http://books.toscrape.com/catalogue/bounty-colorado-mountain-7_9/index.html',
#   Decimal('37.26'),
#   'In stock',
#   4,
#   7),
#  (210,
#   'I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   'http://books.toscrape.com/catalogue/i-had-a-nice-time-and-other-lies-how-to-find-love-sht-like-that_814/index.html',
#   Decimal('57.36'),
#   'In stock',
#   4,
#   8),
#  (212,
#   'Keep Me Posted',
#   'http://books.toscrape.com/catalogue/keep-me-posted_594/index.html',
#   Decimal('20.46'),
#   'In stock',
#   4,
#   8),
#  (213,
#   'Grey (Fifty Shades #4)',
#   'http://books.toscrape.com/catalogue/grey-fifty-shades-4_592/index.html',
#   Decimal('48.49'),
#   'In stock',
#   4,
#   8),
#  (216,
#   'Shopaholic Ties the Knot (Shopaholic #3)',
#   'http://books.toscrape.com/catalogue/shopaholic-ties-the-knot-shopaholic-3_340/index.html',
#   Decimal('48.39'),
#   'In stock',
#   5,
#   8),
#  (217,
#   'Can You Keep a Secret?',
#   'http://books.toscrape.com/catalogue/can-you-keep-a-secret_315/index.html',
#   Decimal('21.94'),
#   'In stock',
#   1,
#   8),
#  (218,
#   'Twenties Girl',
#   'http://books.toscrape.com/catalogue/twenties-girl_292/index.html',
#   Decimal('42.80'),
#   'In stock',
#   2,
#   8),
#  (219,
#   'The Undomestic Goddess',
#   'http://books.toscrape.com/catalogue/the-undomestic-goddess_286/index.html',
#   Decimal('45.75'),
#   'In stock',
#   4,
#   8),
#  (220,
#   'The Nanny Diaries (Nanny #1)',
#   'http://books.toscrape.com/catalogue/the-nanny-diaries-nanny-1_265/index.html',
#   Decimal('52.53'),
#   'In stock',
#   5,
#   8),
#  (221,
#   'The Devil Wears Prada (The Devil Wears Prada #1)',
#   'http://books.toscrape.com/catalogue/the-devil-wears-prada-the-devil-wears-prada-1_243/index.html',
#   Decimal('44.29'),
#   'In stock',
#   1,
#   8),
#  (222,
#   'Something Borrowed (Darcy & Rachel #1)',
#   'http://books.toscrape.com/catalogue/something-borrowed-darcy-rachel-1_224/index.html',
#   Decimal('48.96'),
#   'In stock',
#   5,
#   8),
#  (226,
#   "Bridget Jones's Diary (Bridget Jones #1)",
#   'http://books.toscrape.com/catalogue/bridget-joness-diary-bridget-jones-1_10/index.html',
#   Decimal('29.82'),
#   'In stock',
#   1,
#   8),
#  (228,
#   'Private Paris (Private #10)',
#   'http://books.toscrape.com/catalogue/private-paris-private-10_958/index.html',
#   Decimal('47.61'),
#   'In stock',
#   5,
#   9),
#  (229,
#   'We Love You, Charlie Freeman',
#   'http://books.toscrape.com/catalogue/we-love-you-charlie-freeman_954/index.html',
#   Decimal('50.27'),
#   'In stock',
#   5,
#   9),
#  (232,
#   'Tuesday Nights in 1980',
#   'http://books.toscrape.com/catalogue/tuesday-nights-in-1980_870/index.html',
#   Decimal('21.04'),
#   'In stock',
#   2,
#   9),
#  (233,
#   'The Vacationers',
#   'http://books.toscrape.com/catalogue/the-vacationers_863/index.html',
#   Decimal('42.15'),
#   'In stock',
#   4,
#   9),
#  (234,
#   'The Regional Office Is Under Attack!',
#   'http://books.toscrape.com/catalogue/the-regional-office-is-under-attack_858/index.html',
#   Decimal('51.36'),
#   'In stock',
#   5,
#   9),
#  (235,
#   'Finders Keepers (Bill Hodges Trilogy #2)',
#   'http://books.toscrape.com/catalogue/finders-keepers-bill-hodges-trilogy-2_807/index.html',
#   Decimal('53.53'),
#   'In stock',
#   5,
#   9),
#  (236,
#   'The Time Keeper',
#   'http://books.toscrape.com/catalogue/the-time-keeper_766/index.html',
#   Decimal('27.88'),
#   'In stock',
#   5,
#   9),
#  (237,
#   'The Testament of Mary',
#   'http://books.toscrape.com/catalogue/the-testament-of-mary_765/index.html',
#   Decimal('52.67'),
#   'In stock',
#   4,
#   9),
#  (241,
#   'Shtum',
#   'http://books.toscrape.com/catalogue/shtum_733/index.html',
#   Decimal('55.84'),
#   'In stock',
#   4,
#   9),
#  (242,
#   'My Name Is Lucy Barton',
#   'http://books.toscrape.com/catalogue/my-name-is-lucy-barton_720/index.html',
#   Decimal('41.56'),
#   'In stock',
#   1,
#   9),
#  (244,
#   'Mr. Mercedes (Bill Hodges Trilogy #1)',
#   'http://books.toscrape.com/catalogue/mr-mercedes-bill-hodges-trilogy-1_717/index.html',
#   Decimal('28.90'),
#   'In stock',
#   1,
#   9),
#  (251,
#   'A Man Called Ove',
#   'http://books.toscrape.com/catalogue/a-man-called-ove_653/index.html',
#   Decimal('39.72'),
#   'In stock',
#   1,
#   9),
#  (252,
#   'The Silent Sister (Riley MacPherson #1)',
#   'http://books.toscrape.com/catalogue/the-silent-sister-riley-macpherson-1_641/index.html',
#   Decimal('46.29'),
#   'In stock',
#   5,
#   9),
#  (256,
#   'Lies and Other Acts of Love',
#   'http://books.toscrape.com/catalogue/lies-and-other-acts-of-love_596/index.html',
#   Decimal('45.14'),
#   'In stock',
#   1,
#   9),
#  (259,
#   'The Shack',
#   'http://books.toscrape.com/catalogue/the-shack_576/index.html',
#   Decimal('28.03'),
#   'In stock',
#   1,
#   9),
#  (262,
#   'Hystopia: A Novel',
#   'http://books.toscrape.com/catalogue/hystopia-a-novel_523/index.html',
#   Decimal('21.96'),
#   'In stock',
#   4,
#   9),
#  (263,
#   'The Bourne Identity (Jason Bourne #1)',
#   'http://books.toscrape.com/catalogue/the-bourne-identity-jason-bourne-1_492/index.html',
#   Decimal('42.78'),
#   'In stock',
#   4,
#   9),
#  (264,
#   'Sister Dear',
#   'http://books.toscrape.com/catalogue/sister-dear_485/index.html',
#   Decimal('40.20'),
#   'In stock',
#   4,
#   9),
#  (267,
#   'Deception Point',
#   'http://books.toscrape.com/catalogue/deception-point_426/index.html',
#   Decimal('40.32'),
#   'In stock',
#   4,
#   9),
#  (270,
#   'The Expatriates',
#   'http://books.toscrape.com/catalogue/the-expatriates_401/index.html',
#   Decimal('44.58'),
#   'In stock',
#   2,
#   9),
#  (271,
#   'Siddhartha',
#   'http://books.toscrape.com/catalogue/siddhartha_393/index.html',
#   Decimal('34.22'),
#   'In stock',
#   5,
#   9),
#  (273,
#   'Digital Fortress',
#   'http://books.toscrape.com/catalogue/digital-fortress_369/index.html',
#   Decimal('58.00'),
#   'In stock',
#   5,
#   9),
#  (274,
#   'Atlas Shrugged',
#   'http://books.toscrape.com/catalogue/atlas-shrugged_314/index.html',
#   Decimal('26.58'),
#   'In stock',
#   5,
#   9),
#  (276,
#   'The Nightingale',
#   'http://books.toscrape.com/catalogue/the-nightingale_267/index.html',
#   Decimal('26.26'),
#   'In stock',
#   4,
#   9),
#  (277,
#   'The Infinities',
#   'http://books.toscrape.com/catalogue/the-infinities_257/index.html',
#   Decimal('27.41'),
#   'In stock',
#   1,
#   9),
#  (278,
#   "The Husband's Secret",
#   'http://books.toscrape.com/catalogue/the-husbands-secret_256/index.html',
#   Decimal('52.51'),
#   'In stock',
#   5,
#   9),
#  (279,
#   'The Da Vinci Code (Robert Langdon #2)',
#   'http://books.toscrape.com/catalogue/the-da-vinci-code-robert-langdon-2_240/index.html',
#   Decimal('22.96'),
#   'In stock',
#   2,
#   9),
#  (280,
#   'The Art of Fielding',
#   'http://books.toscrape.com/catalogue/the-art-of-fielding_228/index.html',
#   Decimal('22.10'),
#   'In stock',
#   1,
#   9),
#  (282,
#   'Jurassic Park (Jurassic Park #1)',
#   'http://books.toscrape.com/catalogue/jurassic-park-jurassic-park-1_180/index.html',
#   Decimal('44.97'),
#   'In stock',
#   1,
#   9),
#  (283,
#   'Inferno (Robert Langdon #4)',
#   'http://books.toscrape.com/catalogue/inferno-robert-langdon-4_176/index.html',
#   Decimal('41.00'),
#   'In stock',
#   5,
#   9),
#  (284,
#   'Crazy Rich Asians (Crazy Rich Asians #1)',
#   'http://books.toscrape.com/catalogue/crazy-rich-asians-crazy-rich-asians-1_143/index.html',
#   Decimal('49.13'),
#   'In stock',
#   5,
#   9),
#  (285,
#   'Big Little Lies',
#   'http://books.toscrape.com/catalogue/big-little-lies_129/index.html',
#   Decimal('22.11'),
#   'In stock',
#   1,
#   9),
#  (290,
#   'Kitchens of the Great Midwest',
#   'http://books.toscrape.com/catalogue/kitchens-of-the-great-midwest_28/index.html',
#   Decimal('57.20'),
#   'In stock',
#   5,
#   9),
#  (291,
#   'Bright Lines',
#   'http://books.toscrape.com/catalogue/bright-lines_11/index.html',
#   Decimal('39.07'),
#   'In stock',
#   5,
#   9),
#  (293,
#   'The Bear and the Piano',
#   'http://books.toscrape.com/catalogue/the-bear-and-the-piano_967/index.html',
#   Decimal('36.89'),
#   'In stock',
#   1,
#   10),
#  (295,
#   'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”',
#   'http://books.toscrape.com/catalogue/the-white-cat-and-the-monk-a-retelling-of-the-poem-pangur-ban_865/index.html',
#   Decimal('58.08'),
#   'In stock',
#   4,
#   10),
#  (298,
#   'Twenty Yawns',
#   'http://books.toscrape.com/catalogue/twenty-yawns_773/index.html',
#   Decimal('22.08'),
#   'In stock',
#   2,
#   10),
#  (302,
#   'Nap-a-Roo',
#   'http://books.toscrape.com/catalogue/nap-a-roo_567/index.html',
#   Decimal('25.08'),
#   'In stock',
#   1,
#   10),
#  (303,
#   'The Whale',
#   'http://books.toscrape.com/catalogue/the-whale_501/index.html',
#   Decimal('35.96'),
#   'In stock',
#   4,
#   10),
#  (305,
#   'Raymie Nightingale',
#   'http://books.toscrape.com/catalogue/raymie-nightingale_482/index.html',
#   Decimal('34.41'),
#   'In stock',
#   2,
#   10),
#  (306,
#   'Playing from the Heart',
#   'http://books.toscrape.com/catalogue/playing-from-the-heart_481/index.html',
#   Decimal('32.38'),
#   'In stock',
#   1,
#   10),
#  (307,
#   'Maybe Something Beautiful: How Art Transformed a Neighborhood',
#   'http://books.toscrape.com/catalogue/maybe-something-beautiful-how-art-transformed-a-neighborhood_386/index.html',
#   Decimal('22.54'),
#   'In stock',
#   1,
#   10),
#  (309,
#   'The Thing About Jellyfish',
#   'http://books.toscrape.com/catalogue/the-thing-about-jellyfish_283/index.html',
#   Decimal('48.77'),
#   'In stock',
#   1,
#   10),
#  (310,
#   'The Lonely Ones',
#   'http://books.toscrape.com/catalogue/the-lonely-ones_261/index.html',
#   Decimal('43.59'),
#   'In stock',
#   5,
#   10),
#  (311,
#   'The Day the Crayons Came Home (Crayons)',
#   'http://books.toscrape.com/catalogue/the-day-the-crayons-came-home-crayons_241/index.html',
#   Decimal('26.33'),
#   'In stock',
#   5,
#   10),
#  (314,
#   'Horrible Bear!',
#   'http://books.toscrape.com/catalogue/horrible-bear_168/index.html',
#   Decimal('37.52'),
#   'In stock',
#   2,
#   10),
#  (318,
#   'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#   'http://books.toscrape.com/catalogue/diary-of-a-minecraft-zombie-book-1-a-scare-of-a-dare-an-unofficial-minecraft-book_99/index.html',
#   Decimal('52.88'),
#   'In stock',
#   4,
#   10),
#  (319,
#   'Matilda',
#   'http://books.toscrape.com/catalogue/matilda_32/index.html',
#   Decimal('28.34'),
#   'In stock',
#   1,
#   10),
#  (321,
#   "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#   'http://books.toscrape.com/catalogue/dont-be-a-jerk-and-other-practical-advice-from-dogen-japans-greatest-zen-master_890/index.html',
#   Decimal('37.97'),
#   'In stock',
#   2,
#   11),
#  (322,
#   'You Are What You Love: The Spiritual Power of Habit',
#   'http://books.toscrape.com/catalogue/you-are-what-you-love-the-spiritual-power-of-habit_872/index.html',
#   Decimal('21.87'),
#   'In stock',
#   4,
#   11),
#  (323,
#   'God: The Most Unpleasant Character in All Fiction',
#   'http://books.toscrape.com/catalogue/god-the-most-unpleasant-character-in-all-fiction_697/index.html',
#   Decimal('30.03'),
#   'In stock',
#   5,
#   11),
#  (325,
#   'A History of God: The 4,000-Year Quest of Judaism, Christianity, and Islam',
#   'http://books.toscrape.com/catalogue/a-history-of-god-the-4000-year-quest-of-judaism-christianity-and-islam_310/index.html',
#   Decimal('27.62'),
#   'In stock',
#   1,
#   11),
#  (327,
#   "Choosing Our Religion: The Spiritual Lives of America's Nones",
#   'http://books.toscrape.com/catalogue/choosing-our-religion-the-spiritual-lives-of-americas-nones_14/index.html',
#   Decimal('28.42'),
#   'In stock',
#   4,
#   11),
#  (328,
#   'Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#   'http://books.toscrape.com/catalogue/worlds-elsewhere-journeys-around-shakespeares-globe_972/index.html',
#   Decimal('40.30'),
#   'In stock',
#   5,
#   12),
#  (330,
#   'Reasons to Stay Alive',
#   'http://books.toscrape.com/catalogue/reasons-to-stay-alive_959/index.html',
#   Decimal('26.41'),
#   'In stock',
#   2,
#   12),
#  (331,
#   '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   'http://books.toscrape.com/catalogue/higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957/index.html',
#   Decimal('23.11'),
#   'In stock',
#   5,
#   12),
#  (332,
#   'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   'http://books.toscrape.com/catalogue/unseen-city-the-majesty-of-pigeons-the-discreet-charm-of-snails-other-wonders-of-the-urban-wilderness_952/index.html',
#   Decimal('44.18'),
#   'In stock',
#   4,
#   12),
#  (335,
#   'The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#   'http://books.toscrape.com/catalogue/the-gutsy-girl-escapades-for-your-life-of-epic-adventure_934/index.html',
#   Decimal('37.13'),
#   'In stock',
#   1,
#   12),
#  (337,
#   'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   'http://books.toscrape.com/catalogue/spark-joy-an-illustrated-master-class-on-the-art-of-organizing-and-tidying-up_927/index.html',
#   Decimal('41.83'),
#   'In stock',
#   4,
#   12),
#  (339,
#   'In the Country We Love: My Family Divided',
#   'http://books.toscrape.com/catalogue/in-the-country-we-love-my-family-divided_901/index.html',
#   Decimal('22.00'),
#   'In stock',
#   4,
#   12),
#  (341,
#   'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#   'http://books.toscrape.com/catalogue/call-the-nurse-true-stories-of-a-country-nurse-on-a-scottish-isle_885/index.html',
#   Decimal('29.14'),
#   'In stock',
#   5,
#   12),
#  (342,
#   'Algorithms to Live By: The Computer Science of Human Decisions',
#   'http://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html',
#   Decimal('30.81'),
#   'In stock',
#   1,
#   12),
#  (343,
#   'The Power of Now: A Guide to Spiritual Enlightenment',
#   'http://books.toscrape.com/catalogue/the-power-of-now-a-guide-to-spiritual-enlightenment_855/index.html',
#   Decimal('43.54'),
#   'In stock',
#   2,
#   12),
#  (344,
#   "The Omnivore's Dilemma: A Natural History of Four Meals",
#   'http://books.toscrape.com/catalogue/the-omnivores-dilemma-a-natural-history-of-four-meals_854/index.html',
#   Decimal('38.21'),
#   'In stock',
#   2,
#   12),
#  (346,
#   "The Artist's Way: A Spiritual Path to Higher Creativity",
#   'http://books.toscrape.com/catalogue/the-artists-way-a-spiritual-path-to-higher-creativity_839/index.html',
#   Decimal('38.49'),
#   'In stock',
#   5,
#   12),
#  (350,
#   'Becoming Wise: An Inquiry into the Mystery and Art of Living',
#   'http://books.toscrape.com/catalogue/becoming-wise-an-inquiry-into-the-mystery-and-art-of-living_795/index.html',
#   Decimal('27.43'),
#   'In stock',
#   2,
#   12),
#  (352,
#   'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   'http://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html',
#   Decimal('38.20'),
#   'In stock',
#   4,
#   12),
#  (354,
#   'The Year of Magical Thinking',
#   'http://books.toscrape.com/catalogue/the-year-of-magical-thinking_770/index.html',
#   Decimal('43.04'),
#   'In stock',
#   2,
#   12),
#  (357,
#   'Swell: A Year of Waves',
#   'http://books.toscrape.com/catalogue/swell-a-year-of-waves_740/index.html',
#   Decimal('45.58'),
#   'In stock',
#   1,
#   12),
#  (358,
#   'No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon',
#   'http://books.toscrape.com/catalogue/no-dream-is-too-high-life-lessons-from-a-man-who-walked-on-the-moon_722/index.html',
#   Decimal('21.95'),
#   'In stock',
#   2,
#   12),
#  (359,
#   'Looking for Lovely: Collecting the Moments that Matter',
#   'http://books.toscrape.com/catalogue/looking-for-lovely-collecting-the-moments-that-matter_710/index.html',
#   Decimal('29.14'),
#   'In stock',
#   5,
#   12),
#  (360,
#   'Let It Out: A Journey Through Journaling',
#   'http://books.toscrape.com/catalogue/let-it-out-a-journey-through-journaling_708/index.html',
#   Decimal('26.79'),
#   'In stock',
#   5,
#   12),
#  (363,
#   'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#   'http://books.toscrape.com/catalogue/eaternity-more-than-150-deliciously-easy-vegan-recipes-for-a-long-healthy-satisfied-joyful-life_689/index.html',
#   Decimal('51.75'),
#   'In stock',
#   5,
#   12),
#  (364,
#   'Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#   'http://books.toscrape.com/catalogue/buying-in-the-secret-dialogue-between-what-we-buy-and-who-we-are_670/index.html',
#   Decimal('37.80'),
#   'In stock',
#   4,
#   12),
#  (365,
#   'Brain on Fire: My Month of Madness',
#   'http://books.toscrape.com/catalogue/brain-on-fire-my-month-of-madness_669/index.html',
#   Decimal('49.32'),
#   'In stock',
#   5,
#   12),
#  (366,
#   'Abstract City',
#   'http://books.toscrape.com/catalogue/abstract-city_658/index.html',
#   Decimal('56.37'),
#   'In stock',
#   5,
#   12),
#  (367,
#   '13 Hours: The Inside Account of What Really Happened In Benghazi',
#   'http://books.toscrape.com/catalogue/13-hours-the-inside-account-of-what-really-happened-in-benghazi_645/index.html',
#   Decimal('27.06'),
#   'In stock',
#   1,
#   12),
#  (368,
#   'The Lonely City: Adventures in the Art of Being Alone',
#   'http://books.toscrape.com/catalogue/the-lonely-city-adventures-in-the-art-of-being-alone_639/index.html',
#   Decimal('33.26'),
#   'In stock',
#   2,
#   12),
#  (371,
#   'Furiously Happy: A Funny Book About Horrible Things',
#   'http://books.toscrape.com/catalogue/furiously-happy-a-funny-book-about-horrible-things_619/index.html',
#   Decimal('41.46'),
#   'In stock',
#   4,
#   12),
#  (375,
#   '10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works',
#   'http://books.toscrape.com/catalogue/10-happier-how-i-tamed-the-voice-in-my-head-reduced-stress-without-losing-my-edge-and-found-self-help-that-actually-works_582/index.html',
#   Decimal('24.57'),
#   'In stock',
#   2,
#   12),
#  (376,
#   "Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster",
#   'http://books.toscrape.com/catalogue/chernobyl-012340-the-incredible-true-story-of-the-worlds-worst-nuclear-disaster_560/index.html',
#   Decimal('35.92'),
#   'In stock',
#   2,
#   12),
#  (379,
#   'When Breath Becomes Air',
#   'http://books.toscrape.com/catalogue/when-breath-becomes-air_553/index.html',
#   Decimal('39.36'),
#   'In stock',
#   2,
#   12),
#  (380,
#   "The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#   'http://books.toscrape.com/catalogue/the-midnight-assassin-panic-scandal-and-the-hunt-for-americas-first-serial-killer_549/index.html',
#   Decimal('28.45'),
#   'In stock',
#   4,
#   12),
#  (381,
#   'Smarter Faster Better: The Secrets of Being Productive in Life and Business',
#   'http://books.toscrape.com/catalogue/smarter-faster-better-the-secrets-of-being-productive-in-life-and-business_543/index.html',
#   Decimal('38.89'),
#   'In stock',
#   5,
#   12),
#  (384,
#   "Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations",
#   'http://books.toscrape.com/catalogue/love-that-boy-what-two-presidents-eight-road-trips-and-my-son-taught-me-about-a-parents-expectations_532/index.html',
#   Decimal('25.06'),
#   'In stock',
#   2,
#   12),
#  (386,
#   'I Will Find You',
#   'http://books.toscrape.com/catalogue/i-will-find-you_524/index.html',
#   Decimal('44.21'),
#   'In stock',
#   1,
#   12),
#  (388,
#   'Between the World and Me',
#   'http://books.toscrape.com/catalogue/between-the-world-and-me_513/index.html',
#   Decimal('56.91'),
#   'In stock',
#   4,
#   12),
#  (389,
#   'Being Mortal: Medicine and What Matters in the End',
#   'http://books.toscrape.com/catalogue/being-mortal-medicine-and-what-matters-in-the-end_512/index.html',
#   Decimal('55.06'),
#   'In stock',
#   4,
#   12),
#  (392,
#   'Finding God in the Ruins: How God Redeems Pain',
#   'http://books.toscrape.com/catalogue/finding-god-in-the-ruins-how-god-redeems-pain_466/index.html',
#   Decimal('46.64'),
#   'In stock',
#   2,
#   12),
#  (393,
#   'The Man Who Mistook His Wife for a Hat and Other Clinical Tales',
#   'http://books.toscrape.com/catalogue/the-man-who-mistook-his-wife-for-a-hat-and-other-clinical-tales_451/index.html',
#   Decimal('59.45'),
#   'In stock',
#   4,
#   12),
#  (394,
#   'In Cold Blood',
#   'http://books.toscrape.com/catalogue/in-cold-blood_432/index.html',
#   Decimal('49.98'),
#   'In stock',
#   4,
#   12),
#  (396,
#   'Why Save the Bankers?: And Other Essays on Our Economic and Political Crisis',
#   'http://books.toscrape.com/catalogue/why-save-the-bankers-and-other-essays-on-our-economic-and-political-crisis_418/index.html',
#   Decimal('48.67'),
#   'In stock',
#   2,
#   12),
#  (397,
#   "Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut",
#   'http://books.toscrape.com/catalogue/talking-to-girls-about-duran-duran-one-young-mans-quest-for-true-love-and-a-cooler-haircut_394/index.html',
#   Decimal('25.15'),
#   'In stock',
#   4,
#   12),
#  (398,
#   'My Mother Was Nuts',
#   'http://books.toscrape.com/catalogue/my-mother-was-nuts_388/index.html',
#   Decimal('31.63'),
#   'In stock',
#   4,
#   12),
#  (402,
#   "The Geography of Bliss: One Grump's Search for the Happiest Places in the World",
#   'http://books.toscrape.com/catalogue/the-geography-of-bliss-one-grumps-search-for-the-happiest-places-in-the-world_346/index.html',
#   Decimal('28.23'),
#   'In stock',
#   2,
#   12),
#  (403,
#   'God Is Not Great: How Religion Poisons Everything',
#   'http://books.toscrape.com/catalogue/god-is-not-great-how-religion-poisons-everything_323/index.html',
#   Decimal('27.80'),
#   'In stock',
#   1,
#   12),
#  (407,
#   'Under the Banner of Heaven: A Story of Violent Faith',
#   'http://books.toscrape.com/catalogue/under-the-banner-of-heaven-a-story-of-violent-faith_295/index.html',
#   Decimal('30.00'),
#   'In stock',
#   1,
#   12),
#  (409,
#   'The Name of God is Mercy',
#   'http://books.toscrape.com/catalogue/the-name-of-god-is-mercy_264/index.html',
#   Decimal('37.25'),
#   'In stock',
#   2,
#   12),
#  (411,
#   'Spilled Milk: Based on a True Story',
#   'http://books.toscrape.com/catalogue/spilled-milk-based-on-a-true-story_225/index.html',
#   Decimal('49.51'),
#   'In stock',
#   1,
#   12),
#  (412,
#   'Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',
#   'http://books.toscrape.com/catalogue/rise-of-the-rocket-girls-the-women-who-propelled-us-from-missiles-to-the-moon-to-mars_213/index.html',
#   Decimal('41.67'),
#   'In stock',
#   4,
#   12),
#  (414,
#   'Notes from a Small Island (Notes From a Small Island #1)',
#   'http://books.toscrape.com/catalogue/notes-from-a-small-island-notes-from-a-small-island-1_200/index.html',
#   Decimal('40.17'),
#   'In stock',
#   1,
#   12),
#  (417,
#   'Letter to a Christian Nation',
#   'http://books.toscrape.com/catalogue/letter-to-a-christian-nation_186/index.html',
#   Decimal('22.20'),
#   'In stock',
#   1,
#   12),
#  (418,
#   "Let's Pretend This Never Happened: A Mostly True Memoir",
#   'http://books.toscrape.com/catalogue/lets-pretend-this-never-happened-a-mostly-true-memoir_185/index.html',
#   Decimal('45.11'),
#   'In stock',
#   1,
#   12),
#  (419,
#   "It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond",
#   'http://books.toscrape.com/catalogue/its-never-too-late-to-begin-again-discovering-creativity-and-meaning-at-midlife-and-beyond_179/index.html',
#   Decimal('42.38'),
#   'In stock',
#   1,
#   12),
#  (420,
#   'Into the Wild',
#   'http://books.toscrape.com/catalogue/into-the-wild_177/index.html',
#   Decimal('56.70'),
#   'In stock',
#   5,
#   12),
#  (422,
#   'I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban',
#   'http://books.toscrape.com/catalogue/i-am-malala-the-girl-who-stood-up-for-education-and-was-shot-by-the-taliban_172/index.html',
#   Decimal('28.88'),
#   'In stock',
#   2,
#   12),
#  (423,
#   'Gratitude',
#   'http://books.toscrape.com/catalogue/gratitude_163/index.html',
#   Decimal('26.66'),
#   'In stock',
#   5,
#   12),
#  (425,
#   'Brave Enough',
#   'http://books.toscrape.com/catalogue/brave-enough_135/index.html',
#   Decimal('51.32'),
#   'In stock',
#   5,
#   12),
#  (426,
#   'Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen',
#   'http://books.toscrape.com/catalogue/born-to-run-a-hidden-tribe-superathletes-and-the-greatest-race-the-world-has-never-seen_133/index.html',
#   Decimal('27.35'),
#   'In stock',
#   2,
#   12),
#  (427,
#   'Blink: The Power of Thinking Without Thinking',
#   'http://books.toscrape.com/catalogue/blink-the-power-of-thinking-without-thinking_132/index.html',
#   Decimal('21.74'),
#   'In stock',
#   5,
#   12),
#  (428,
#   'Black Flags: The Rise of ISIS',
#   'http://books.toscrape.com/catalogue/black-flags-the-rise-of-isis_131/index.html',
#   Decimal('40.87'),
#   'In stock',
#   1,
#   12),
#  (430,
#   'A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#   'http://books.toscrape.com/catalogue/a-walk-in-the-woods-rediscovering-america-on-the-appalachian-trail_118/index.html',
#   Decimal('30.48'),
#   'In stock',
#   4,
#   12),
#  (433,
#   'H is for Hawk',
#   'http://books.toscrape.com/catalogue/h-is-for-hawk_102/index.html',
#   Decimal('57.42'),
#   'In stock',
#   5,
#   12),
#  (434,
#   'Travels with Charley: In Search of America',
#   'http://books.toscrape.com/catalogue/travels-with-charley-in-search-of-america_90/index.html',
#   Decimal('57.82'),
#   'In stock',
#   5,
#   12),
#  (435,
#   'The Tumor',
#   'http://books.toscrape.com/catalogue/the-tumor_85/index.html',
#   Decimal('41.56'),
#   'In stock',
#   5,
#   12),
#  (438,
#   'Rip it Up and Start Again',
#   'http://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html',
#   Decimal('35.02'),
#   'In stock',
#   5,
#   13),
#  (440,
#   'How Music Works',
#   'http://books.toscrape.com/catalogue/how-music-works_979/index.html',
#   Decimal('37.32'),
#   'In stock',
#   2,
#   13),
#  (442,
#   'Please Kill Me: The Uncensored Oral History of Punk',
#   'http://books.toscrape.com/catalogue/please-kill-me-the-uncensored-oral-history-of-punk_537/index.html',
#   Decimal('31.19'),
#   'In stock',
#   4,
#   13),
#  (443,
#   "Kill 'Em and Leave: Searching for James Brown and the American Soul",
#   'http://books.toscrape.com/catalogue/kill-em-and-leave-searching-for-james-brown-and-the-american-soul_528/index.html',
#   Decimal('45.05'),
#   'In stock',
#   5,
#   13),
#  (445,
#   'This Is Your Brain on Music: The Science of a Human Obsession',
#   'http://books.toscrape.com/catalogue/this-is-your-brain-on-music-the-science-of-a-human-obsession_414/index.html',
#   Decimal('38.40'),
#   'In stock',
#   1,
#   13),
#  (447,
#   'No One Here Gets Out Alive',
#   'http://books.toscrape.com/catalogue/no-one-here-gets-out-alive_336/index.html',
#   Decimal('20.02'),
#   'In stock',
#   5,
#   13),
#  (448,
#   'Life',
#   'http://books.toscrape.com/catalogue/life_104/index.html',
#   Decimal('31.58'),
#   'In stock',
#   5,
#   13),
#  (452,
#   'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'http://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#   Decimal('22.60'),
#   'In stock',
#   4,
#   14),
#  (458,
#   'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
# ...
#   30),
#  (870,
#   'Follow You Home',
#   'http://books.toscrape.com/catalogue/follow-you-home_809/index.html',
#   Decimal('21.36'),
#   'In stock',
#   1,
#   30),
#  (871,
#   'The Loney',
#   'http://books.toscrape.com/catalogue/the-loney_756/index.html',
#   Decimal('23.40'),
#   'In stock',
#   1,
#   30),
#  (873,
#   'Doctor Sleep (The Shining #2)',
#   'http://books.toscrape.com/catalogue/doctor-sleep-the-shining-2_686/index.html',
#   Decimal('40.12'),
#   'In stock',
#   2,
#   30),
#  (874,
#   'Psycho: Sanitarium (Psycho #1.5)',
#   'http://books.toscrape.com/catalogue/psycho-sanitarium-psycho-15_628/index.html',
#   Decimal('36.97'),
#   'In stock',
#   5,
#   30),
#  (875,
#   'Can You Keep a Secret? (Fear Street Relaunch #4)',
#   'http://books.toscrape.com/catalogue/can-you-keep-a-secret-fear-street-relaunch-4_614/index.html',
#   Decimal('48.64'),
#   'In stock',
#   1,
#   30),
#  (877,
#   'Dracula the Un-Dead',
#   'http://books.toscrape.com/catalogue/dracula-the-un-dead_370/index.html',
#   Decimal('35.63'),
#   'In stock',
#   5,
#   30),
#  (879,
#   'Needful Things',
#   'http://books.toscrape.com/catalogue/needful-things_334/index.html',
#   Decimal('47.51'),
#   'In stock',
#   4,
#   30),
#  (880,
#   'Misery',
#   'http://books.toscrape.com/catalogue/misery_332/index.html',
#   Decimal('34.79'),
#   'In stock',
#   2,
#   30),
#  (882,
#   "'Salem's Lot",
#   'http://books.toscrape.com/catalogue/salems-lot_309/index.html',
#   Decimal('49.56'),
#   'In stock',
#   4,
#   30),
#  (886,
#   'Sapiens: A Brief History of Humankind',
#   'http://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html',
#   Decimal('54.23'),
#   'In stock',
#   5,
#   31),
#  (887,
#   'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#   'http://books.toscrape.com/catalogue/unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950/index.html',
#   Decimal('25.52'),
#   'In stock',
#   1,
#   31),
#  (889,
#   'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   'http://books.toscrape.com/catalogue/political-suicide-missteps-peccadilloes-bad-calls-backroom-hijinx-sordid-pasts-rotten-breaks-and-just-plain-dumb-mistakes-in-the-annals-of-american-politics_917/index.html',
#   Decimal('36.28'),
#   'In stock',
#   2,
#   31),
#  (895,
#   '"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',
#   'http://books.toscrape.com/catalogue/most-blessed-of-the-patriarchs-thomas-jefferson-and-the-empire-of-the-imagination_509/index.html',
#   Decimal('44.48'),
#   'In stock',
#   5,
#   31),
#  (896,
#   'A Short History of Nearly Everything',
#   'http://books.toscrape.com/catalogue/a-short-history-of-nearly-everything_457/index.html',
#   Decimal('52.40'),
#   'In stock',
#   5,
#   31),
#  (897,
#   'The Rise and Fall of the Third Reich: A History of Nazi Germany',
#   'http://books.toscrape.com/catalogue/the-rise-and-fall-of-the-third-reich-a-history-of-nazi-germany_454/index.html',
#   Decimal('39.67'),
#   'In stock',
#   2,
#   31),
#  (898,
#   'Catherine the Great: Portrait of a Woman',
#   'http://books.toscrape.com/catalogue/catherine-the-great-portrait-of-a-woman_424/index.html',
#   Decimal('58.55'),
#   'In stock',
#   4,
#   31),
#  (899,
#   "The Mathews Men: Seven Brothers and the War Against Hitler's U-boats",
#   'http://books.toscrape.com/catalogue/the-mathews-men-seven-brothers-and-the-war-against-hitlers-u-boats_408/index.html',
#   Decimal('42.91'),
#   'In stock',
#   5,
#   31),
#  (900,
#   'The Hiding Place',
#   'http://books.toscrape.com/catalogue/the-hiding-place_406/index.html',
#   Decimal('55.91'),
#   'In stock',
#   4,
#   31),
#  (903,
#   'House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth',
#   'http://books.toscrape.com/catalogue/house-of-lost-worlds-dinosaurs-dynasties-and-the-story-of-life-on-earth_170/index.html',
#   Decimal('43.70'),
#   'In stock',
#   2,
#   31),
#  (906,
#   'My Paris Kitchen: Recipes and Stories',
#   'http://books.toscrape.com/catalogue/my-paris-kitchen-recipes-and-stories_910/index.html',
#   Decimal('33.37'),
#   'In stock',
#   2,
#   32),
#  (908,
#   'Layered: Baking, Building, and Styling Spectacular Cakes',
#   'http://books.toscrape.com/catalogue/layered-baking-building-and-styling-spectacular-cakes_904/index.html',
#   Decimal('40.11'),
#   'In stock',
#   1,
#   32),
#  (909,
#   'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#   'http://books.toscrape.com/catalogue/the-nerdy-nummies-cookbook-sweet-treats-for-the-geek-in-all-of-us_853/index.html',
#   Decimal('37.34'),
#   'In stock',
#   5,
#   32),
#  (910,
#   'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#   'http://books.toscrape.com/catalogue/the-love-and-lemons-cookbook-an-apple-to-zucchini-celebration-of-impromptu-cooking_849/index.html',
#   Decimal('37.60'),
#   'In stock',
#   2,
#   32),
#  (911,
#   'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#   'http://books.toscrape.com/catalogue/the-cookies-cups-cookbook-125-sweet-savory-recipes-reminding-you-to-always-eat-dessert-first_841/index.html',
#   Decimal('41.25'),
#   'In stock',
#   1,
#   32),
#  (915,
#   'Barefoot Contessa Back to Basics',
#   'http://books.toscrape.com/catalogue/barefoot-contessa-back-to-basics_667/index.html',
#   Decimal('28.01'),
#   'In stock',
#   1,
#   32),
#  (916,
#   "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   'http://books.toscrape.com/catalogue/barefoot-contessa-at-home-everyday-recipes-youll-make-over-and-over-again_666/index.html',
#   Decimal('50.62'),
#   'In stock',
#   5,
#   32),
#  (918,
#   'Everyday Italian: 125 Simple and Delicious Recipes',
#   'http://books.toscrape.com/catalogue/everyday-italian-125-simple-and-delicious-recipes_618/index.html',
#   Decimal('20.10'),
#   'In stock',
#   5,
#   32),
#  (919,
#   'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#   'http://books.toscrape.com/catalogue/a-la-mode-120-recipes-in-60-pairings-pies-tarts-cakes-crisps-and-more-topped-with-ice-cream-gelato-frozen-custard-and-more_611/index.html',
#   Decimal('38.77'),
#   'In stock',
#   1,
#   32),
#  (924,
#   'How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#   'http://books.toscrape.com/catalogue/how-to-cook-everything-vegetarian-simple-meatless-recipes-for-great-food-how-to-cook-everything_471/index.html',
#   Decimal('46.01'),
#   'In stock',
#   4,
#   32),
#  (925,
#   'How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#   'http://books.toscrape.com/catalogue/how-to-be-a-domestic-goddess-baking-and-the-art-of-comfort-cooking_470/index.html',
#   Decimal('28.25'),
#   'In stock',
#   2,
#   32),
#  (926,
#   'The Barefoot Contessa Cookbook',
#   'http://books.toscrape.com/catalogue/the-barefoot-contessa-cookbook_440/index.html',
#   Decimal('59.92'),
#   'In stock',
#   5,
#   32),
#  (929,
#   'Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens',
#   'http://books.toscrape.com/catalogue/mexican-today-new-and-rediscovered-recipes-for-contemporary-kitchens_387/index.html',
#   Decimal('24.91'),
#   'In stock',
#   5,
#   32),
#  (931,
#   'The Smitten Kitchen Cookbook',
#   'http://books.toscrape.com/catalogue/the-smitten-kitchen-cookbook_281/index.html',
#   Decimal('23.59'),
#   'In stock',
#   1,
#   32),
#  (934,
#   'Redeeming Love',
#   'http://books.toscrape.com/catalogue/redeeming-love_826/index.html',
#   Decimal('20.47'),
#   'In stock',
#   5,
#   33),
#  (935,
#   'Close to You',
#   'http://books.toscrape.com/catalogue/close-to-you_798/index.html',
#   Decimal('49.46'),
#   'In stock',
#   4,
#   33),
#  (936,
#   'Shadows of the Past (Logan Point #1)',
#   'http://books.toscrape.com/catalogue/shadows-of-the-past-logan-point-1_541/index.html',
#   Decimal('39.67'),
#   'In stock',
#   5,
#   33),
#  (937,
#   'Like Never Before (Walker Family #2)',
#   'http://books.toscrape.com/catalogue/like-never-before-walker-family-2_476/index.html',
#   Decimal('28.77'),
#   'In stock',
#   2,
#   33),
#  (939,
#   'If I Run (If I Run #1)',
#   'http://books.toscrape.com/catalogue/if-i-run-if-i-run-1_174/index.html',
#   Decimal('49.97'),
#   'In stock',
#   4,
#   33),
#  (940,
#   'The Dirty Little Secrets of Getting Your Dream Job',
#   'http://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#   Decimal('33.34'),
#   'In stock',
#   4,
#   34),
#  (943,
#   'Shoe Dog: A Memoir by the Creator of NIKE',
#   'http://books.toscrape.com/catalogue/shoe-dog-a-memoir-by-the-creator-of-nike_831/index.html',
#   Decimal('23.99'),
#   'In stock',
#   2,
#   34),
#  (944,
#   'Made to Stick: Why Some Ideas Survive and Others Die',
#   'http://books.toscrape.com/catalogue/made-to-stick-why-some-ideas-survive-and-others-die_715/index.html',
#   Decimal('38.85'),
#   'In stock',
#   5,
#   34),
#  (945,
#   'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#   'http://books.toscrape.com/catalogue/quench-your-own-thirst-business-lessons-learned-over-a-beer-or-two_629/index.html',
#   Decimal('43.14'),
#   'In stock',
#   1,
#   34),
#  (947,
#   'Born for This: How to Find the Work You Were Meant to Do',
#   'http://books.toscrape.com/catalogue/born-for-this-how-to-find-the-work-you-were-meant-to-do_588/index.html',
#   Decimal('21.59'),
#   'In stock',
#   5,
#   34),
#  (948,
#   "The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",
#   'http://books.toscrape.com/catalogue/the-e-myth-revisited-why-most-small-businesses-dont-work-and-what-to-do-about-it_545/index.html',
#   Decimal('36.91'),
#   'In stock',
#   1,
#   34),
#  (951,
#   'Rework',
#   'http://books.toscrape.com/catalogue/rework_212/index.html',
#   Decimal('44.88'),
#   'In stock',
#   2,
#   34),
#  (953,
#   'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   'http://books.toscrape.com/catalogue/setting-the-world-on-fire-the-brief-astonishing-life-of-st-catherine-of-siena_603/index.html',
#   Decimal('21.15'),
#   'In stock',
#   2,
#   35),
#  (954,
#   "The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",
#   'http://books.toscrape.com/catalogue/the-faith-of-christopher-hitchens-the-restless-soul-of-the-worlds-most-notorious-atheist_495/index.html',
#   Decimal('39.55'),
#   'In stock',
#   1,
#   35),
#  (958,
#   'The Elephant Tree',
#   'http://books.toscrape.com/catalogue/the-elephant-tree_968/index.html',
#   Decimal('23.82'),
#   'In stock',
#   5,
#   36),
#  (959,
#   'Behind Closed Doors',
#   'http://books.toscrape.com/catalogue/behind-closed-doors_962/index.html',
#   Decimal('52.22'),
#   'In stock',
#   4,
#   36),
#  (960,
#   'You (You #1)',
#   'http://books.toscrape.com/catalogue/you-you-1_784/index.html',
#   Decimal('43.61'),
#   'In stock',
#   5,
#   36),
#  (962,
#   'The 14th Colony (Cotton Malone #11)',
#   'http://books.toscrape.com/catalogue/the-14th-colony-cotton-malone-11_744/index.html',
#   Decimal('39.24'),
#   'In stock',
#   1,
#   36),
#  (964,
#   'Killing Floor (Jack Reacher #1)',
#   'http://books.toscrape.com/catalogue/killing-floor-jack-reacher-1_382/index.html',
#   Decimal('31.49'),
#   'In stock',
#   4,
#   36),
#  (966,
#   'Far From True (Promise Falls Trilogy #2)',
#   'http://books.toscrape.com/catalogue/far-from-true-promise-falls-trilogy-2_320/index.html',
#   Decimal('34.93'),
#   'In stock',
#   2,
#   36),
#  (968,
#   'When We Collided',
#   'http://books.toscrape.com/catalogue/when-we-collided_955/index.html',
#   Decimal('31.77'),
#   'In stock',
#   1,
#   37),
#  (969,
#   'Someone Like You (The Harrisons #2)',
#   'http://books.toscrape.com/catalogue/someone-like-you-the-harrisons-2_735/index.html',
#   Decimal('52.79'),
#   'In stock',
#   5,
#   37),
#  (970,
#   'We Are All Completely Beside Ourselves',
#   'http://books.toscrape.com/catalogue/we-are-all-completely-beside-ourselves_301/index.html',
#   Decimal('24.04'),
#   'In stock',
#   1,
#   37),
#  (972,
#   "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   'http://books.toscrape.com/catalogue/the-activists-tao-te-ching-ancient-advice-for-a-modern-revolution_928/index.html',
#   Decimal('32.24'),
#   'In stock',
#   5,
#   38),
#  (973,
#   'Chasing Heaven: What Dying Taught Me About Living',
#   'http://books.toscrape.com/catalogue/chasing-heaven-what-dying-taught-me-about-living_797/index.html',
#   Decimal('37.80'),
#   'In stock',
#   2,
#   38),
#  (974,
#   "If I Gave You God's Phone Number....: Searching for Spirituality in America",
#   'http://books.toscrape.com/catalogue/if-i-gave-you-gods-phone-number-searching-for-spirituality-in-america_564/index.html',
#   Decimal('20.91'),
#   'In stock',
#   1,
#   38),
#  (975,
#   'Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain',
#   'http://books.toscrape.com/catalogue/unreasonable-hope-finding-faith-in-the-god-who-brings-purpose-to-your-pain_505/index.html',
#   Decimal('46.33'),
#   'In stock',
#   2,
#   38),
#  (976,
#   "A New Earth: Awakening to Your Life's Purpose",
#   'http://books.toscrape.com/catalogue/a-new-earth-awakening-to-your-lifes-purpose_311/index.html',
#   Decimal('55.65'),
#   'In stock',
#   5,
#   38),
#  (978,
#   'Online Marketing for Busy Authors: A Step-By-Step Guide',
#   'http://books.toscrape.com/catalogue/online-marketing-for-busy-authors-a-step-by-step-guide_913/index.html',
#   Decimal('46.35'),
#   'In stock',
#   1,
#   40),
#  (979,
#   'How to Be Miserable: 40 Strategies You Already Use',
#   'http://books.toscrape.com/catalogue/how-to-be-miserable-40-strategies-you-already-use_897/index.html',
#   Decimal('46.03'),
#   'In stock',
#   1,
#   40),
#  (982,
#   'How to Stop Worrying and Start Living',
#   'http://books.toscrape.com/catalogue/how-to-stop-worrying-and-start-living_431/index.html',
#   Decimal('46.49'),
#   'In stock',
#   5,
#   40),
#  (983,
#   'All the Light We Cannot See',
#   'http://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html',
#   Decimal('29.87'),
#   'In stock',
#   5,
#   41),
#  (985,
#   '(Un)Qualified: How God Uses Broken People to Do Big Things',
#   'http://books.toscrape.com/catalogue/unqualified-how-god-uses-broken-people-to-do-big-things_873/index.html',
#   Decimal('54.00'),
#   'In stock',
#   5,
#   42),
#  (986,
#   'Crazy Love: Overwhelmed by a Relentless God',
#   'http://books.toscrape.com/catalogue/crazy-love-overwhelmed-by-a-relentless-god_682/index.html',
#   Decimal('47.72'),
#   'In stock',
#   2,
#   42),
#  (987,
#   'Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',
#   'http://books.toscrape.com/catalogue/blue-like-jazz-nonreligious-thoughts-on-christian-spirituality_461/index.html',
#   Decimal('25.77'),
#   'In stock',
#   1,
#   42),
#  (989,
#   'The Grownup',
#   'http://books.toscrape.com/catalogue/the-grownup_546/index.html',
#   Decimal('35.88'),
#   'In stock',
#   1,
#   44),
#  (990,
#   'Suzie Snowflake: One beautiful flake (a self-esteem story)',
#   'http://books.toscrape.com/catalogue/suzie-snowflake-one-beautiful-flake-a-self-esteem-story_568/index.html',
#   Decimal('54.81'),
#   'In stock',
#   5,
#   45),
#  (993,
#   '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#   'http://books.toscrape.com/catalogue/10-day-green-smoothie-cleanse-lose-up-to-15-pounds-in-10-days_581/index.html',
#   Decimal('49.71'),
#   'In stock',
#   5,
#   46),
#  (994,
#   'The Art and Science of Low Carbohydrate Living',
#   'http://books.toscrape.com/catalogue/the-art-and-science-of-low-carbohydrate-living_570/index.html',
#   Decimal('52.98'),
#   'In stock',
#   5,
#   46),
#  (996,
#   'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   'http://books.toscrape.com/catalogue/why-the-right-went-wrong-conservatism-from-goldwater-to-the-tea-party-and-beyond_781/index.html',
#   Decimal('52.65'),
#   'In stock',
#   4,
#   47),
#  (998,
#   'Amid the Chaos',
#   'http://books.toscrape.com/catalogue/amid-the-chaos_788/index.html',
#   Decimal('36.58'),
#   'In stock',
#   1,
#   48),
#  (1001,
#   'Sapiens: A Brief History of Humankind',
#   '#',
#   Decimal('49.99'),
#   'In stock',
#   5,
#   54),
#  (1002, 'Guns, Germs, and Steel', '#', Decimal('39.50'), 'In stock', 4, 54),
#  (1003, 'The Silk Roads', '#', Decimal('35.00'), 'In stock', 4, 54),
#  (1005,
#   'The History of the Ancient World',
#   '#',
#   Decimal('41.75'),
#   'In stock',
#   5,
#   54)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#      book_id                                              title  \
# 0          1                            It's Only the Himalayas
# 1          2  Full Moon over Noah’s Ark: An Odyssey to Mount...
# 2          4  Vagabonding: An Uncommon Guide to the Art of L...
# 3          6                                 A Summer In Europe
# 4          7                           The Great Railway Bazaar
# ..       ...                                                ...
# 567      998                                     Amid the Chaos
# 568     1001              Sapiens: A Brief History of Humankind
# 569     1002                             Guns, Germs, and Steel
# 570     1003                                     The Silk Roads
# 571     1005                   The History of the Ancient World
#
#                                                    url  price availability  \
# 0    http://books.toscrape.com/catalogue/its-only-t...  45.17     In stock
# 1    http://books.toscrape.com/catalogue/full-moon-...  49.43     In stock
# 2    http://books.toscrape.com/catalogue/vagabondin...  36.94     In stock
# 3    http://books.toscrape.com/catalogue/a-summer-i...  44.34     In stock
# 4    http://books.toscrape.com/catalogue/the-great-...  30.54     In stock
# ..                                                 ...    ...          ...
# 567  http://books.toscrape.com/catalogue/amid-the-c...  36.58     In stock
# 568                                                  #  49.99     In stock
# 569                                                  #  39.50     In stock
# 570                                                  #  35.00     In stock
# 571                                                  #  41.75     In stock
#
#      rating  category_id
# 0         2            1
# 1         4            1
# 2         2            1
# 3         2            1
# 4         1            1
# ..      ...          ...
# 567       1           48
# 568       5           54
# 569       4           54
# 570       4           54
# 571       5           54
#
# [572 rows x 7 columns]

# %% [markdown]
# #### 04) Write a sql query to get books that has price between 10 and 40 and has rate 3 or 4 or 1.

# %%
qry = '''
SELECT * FROM books_catalog 
WHERE price BETWEEN 10 AND 40 AND rating IN(3 , 4);
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(5,
#   'Under the Tuscan Sun',
#   'http://books.toscrape.com/catalogue/under-the-tuscan-sun_504/index.html',
#   Decimal('37.33'),
#   'In stock',
#   3,
#   1),
#  (10,
#   'Neither Here nor There: Travels in Europe',
#   'http://books.toscrape.com/catalogue/neither-here-nor-there-travels-in-europe_198/index.html',
#   Decimal('38.95'),
#   'In stock',
#   3,
#   1),
#  (13,
#   'In a Dark, Dark Wood',
#   'http://books.toscrape.com/catalogue/in-a-dark-dark-wood_963/index.html',
#   Decimal('19.63'),
#   'In stock',
#   3,
#   2),
#  (15,
#   'A Murder in Time',
#   'http://books.toscrape.com/catalogue/a-murder-in-time_877/index.html',
#   Decimal('16.64'),
#   'In stock',
#   3,
#   2),
#  (18,
#   'That Darkness (Gardiner and Renner #1)',
#   'http://books.toscrape.com/catalogue/that-darkness-gardiner-and-renner-1_743/index.html',
#   Decimal('13.92'),
#   'In stock',
#   3,
#   2),
#  (19,
#   'Tastes Like Fear (DI Marnie Rome #3)',
#   'http://books.toscrape.com/catalogue/tastes-like-fear-di-marnie-rome-3_742/index.html',
#   Decimal('10.69'),
#   'In stock',
#   3,
#   2),
#  (21,
#   'A Study in Scarlet (Sherlock Holmes #1)',
#   'http://books.toscrape.com/catalogue/a-study-in-scarlet-sherlock-holmes-1_656/index.html',
#   Decimal('16.73'),
#   'In stock',
#   3,
#   2),
#  (22,
#   'Poisonous (Max Revere Novels #3)',
#   'http://books.toscrape.com/catalogue/poisonous-max-revere-novels-3_627/index.html',
#   Decimal('26.80'),
#   'In stock',
#   3,
#   2),
#  (24,
#   'Most Wanted',
#   'http://books.toscrape.com/catalogue/most-wanted_623/index.html',
#   Decimal('35.28'),
#   'In stock',
#   3,
#   2),
#  (25,
#   'Hide Away (Eve Duncan #20)',
#   'http://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html',
#   Decimal('11.84'),
#   'In stock',
#   3,
#   2),
#  (28,
#   'Playing with Fire',
#   'http://books.toscrape.com/catalogue/playing-with-fire_602/index.html',
#   Decimal('13.71'),
#   'In stock',
#   3,
#   2),
#  (31,
#   'Delivering the Truth (Quaker Midwife Mystery #1)',
#   'http://books.toscrape.com/catalogue/delivering-the-truth-quaker-midwife-mystery-1_464/index.html',
#   Decimal('20.89'),
#   'In stock',
#   4,
#   2),
#  (32,
#   'The Mysterious Affair at Styles (Hercule Poirot #1)',
#   'http://books.toscrape.com/catalogue/the-mysterious-affair-at-styles-hercule-poirot-1_452/index.html',
#   Decimal('24.80'),
#   'In stock',
#   4,
#   2),
#  (36,
#   "The Cuckoo's Calling (Cormoran Strike #1)",
#   'http://books.toscrape.com/catalogue/the-cuckoos-calling-cormoran-strike-1_239/index.html',
#   Decimal('19.21'),
#   'In stock',
#   3,
#   2),
#  (37,
#   'Extreme Prey (Lucas Davenport #26)',
#   'http://books.toscrape.com/catalogue/extreme-prey-lucas-davenport-26_154/index.html',
#   Decimal('25.40'),
#   'In stock',
#   3,
#   2),
#  (40,
#   'The Girl You Lost',
#   'http://books.toscrape.com/catalogue/the-girl-you-lost_66/index.html',
#   Decimal('12.29'),
#   'In stock',
#   3,
#   2),
#  (41,
#   'The Girl In The Ice (DCI Erika Foster #1)',
#   'http://books.toscrape.com/catalogue/the-girl-in-the-ice-dci-erika-foster-1_65/index.html',
#   Decimal('15.85'),
#   'In stock',
#   3,
#   2),
#  (42,
#   'Blood Defense (Samantha Brinkman #1)',
#   'http://books.toscrape.com/catalogue/blood-defense-samantha-brinkman-1_8/index.html',
#   Decimal('20.30'),
#   'In stock',
#   3,
#   2),
#  (45,
#   'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#   'http://books.toscrape.com/catalogue/forever-and-forever-the-courtship-of-henry-longfellow-and-fanny-appleton_894/index.html',
#   Decimal('29.69'),
#   'In stock',
#   3,
#   3),
#  (49,
#   'The Marriage of Opposites',
#   'http://books.toscrape.com/catalogue/the-marriage-of-opposites_759/index.html',
#   Decimal('28.08'),
#   'In stock',
#   4,
#   3),
#  (52,
#   'A Paris Apartment',
#   'http://books.toscrape.com/catalogue/a-paris-apartment_612/index.html',
#   Decimal('39.01'),
#   'In stock',
#   4,
#   3),
#  (53,
#   'Lilac Girls',
#   'http://books.toscrape.com/catalogue/lilac-girls_597/index.html',
#   Decimal('17.28'),
#   'In stock',
#   3,
#   3),
#  (54,
#   'The Constant Princess (The Tudor Court #1)',
#   'http://books.toscrape.com/catalogue/the-constant-princess-the-tudor-court-1_493/index.html',
#   Decimal('16.62'),
#   'In stock',
#   3,
#   3),
#  (56,
#   'World Without End (The Pillars of the Earth #2)',
#   'http://books.toscrape.com/catalogue/world-without-end-the-pillars-of-the-earth-2_420/index.html',
#   Decimal('32.97'),
#   'In stock',
#   4,
#   3),
#  (66,
#   'The Secret Healer',
#   'http://books.toscrape.com/catalogue/the-secret-healer_80/index.html',
#   Decimal('34.56'),
#   'In stock',
#   3,
#   3),
#  (67,
#   'Starlark',
#   'http://books.toscrape.com/catalogue/starlark_56/index.html',
#   Decimal('25.83'),
#   'In stock',
#   3,
#   3),
#  (68,
#   'Lost Among the Living',
#   'http://books.toscrape.com/catalogue/lost-among-the-living_31/index.html',
#   Decimal('27.70'),
#   'In stock',
#   4,
#   3),
#  (69,
#   "A Spy's Devotion (The Regency Spies of London #1)",
#   'http://books.toscrape.com/catalogue/a-spys-devotion-the-regency-spies-of-london-1_3/index.html',
#   Decimal('16.97'),
#   'In stock',
#   3,
#   3),
#  (71,
#   'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   'http://books.toscrape.com/catalogue/tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949/index.html',
#   Decimal('16.28'),
#   'In stock',
#   3,
#   4),
#  (72,
#   'This One Summer',
#   'http://books.toscrape.com/catalogue/this-one-summer_947/index.html',
#   Decimal('19.49'),
#   'In stock',
#   3,
#   4),
#  (73,
#   'The Nameless City (The Nameless City #1)',
#   'http://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html',
#   Decimal('38.16'),
#   'In stock',
#   4,
#   4),
#  (76,
#   'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   'http://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html',
#   Decimal('13.61'),
#   'In stock',
#   3,
#   4),
#  (77,
#   'Pop Gun War, Volume 1: Gift',
#   'http://books.toscrape.com/catalogue/pop-gun-war-volume-1-gift_918/index.html',
#   Decimal('18.97'),
#   'In stock',
#   3,
#   4),
#  (78,
#   'Patience',
#   'http://books.toscrape.com/catalogue/patience_916/index.html',
#   Decimal('10.16'),
#   'In stock',
#   3,
#   4),
#  (79,
#   'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   'http://books.toscrape.com/catalogue/outcast-vol-1-a-darkness-surrounds-him-outcast-1_915/index.html',
#   Decimal('15.44'),
#   'In stock',
#   3,
#   4),
#  (83,
#   'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   'http://books.toscrape.com/catalogue/lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905/index.html',
#   Decimal('19.92'),
#   'In stock',
#   3,
#   4),
#  (88,
#   'Codename Baboushka, Volume 1: The Conclave of Death',
#   'http://books.toscrape.com/catalogue/codename-baboushka-volume-1-the-conclave-of-death_887/index.html',
#   Decimal('36.72'),
#   'In stock',
#   4,
#   4),
#  (89,
#   'Camp Midnight',
#   'http://books.toscrape.com/catalogue/camp-midnight_886/index.html',
#   Decimal('17.08'),
#   'In stock',
#   3,
#   4),
#  (94,
#   'Batman: The Dark Knight Returns (Batman)',
#   'http://books.toscrape.com/catalogue/batman-the-dark-knight-returns-batman_792/index.html',
#   Decimal('15.38'),
#   'In stock',
#   3,
#   4),
#  (95,
#   'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   'http://books.toscrape.com/catalogue/wonder-woman-earth-one-volume-one-wonder-woman-earth-one-1_783/index.html',
#   Decimal('37.34'),
#   'In stock',
#   4,
#   4),
#  (98,
#   'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#   'http://books.toscrape.com/catalogue/superman-vol-1-before-truth-superman-by-gene-luen-yang-1_739/index.html',
#   Decimal('11.89'),
#   'In stock',
#   3,
#   4),
#  (99,
#   'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#   'http://books.toscrape.com/catalogue/so-cute-it-hurts-vol-6-so-cute-it-hurts-6_734/index.html',
#   Decimal('35.43'),
#   'In stock',
#   4,
#   4),
#  (107,
#   'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#   'http://books.toscrape.com/catalogue/adulthood-is-a-myth-a-sarahs-scribbles-collection_659/index.html',
#   Decimal('10.90'),
#   'In stock',
#   3,
#   4),
#  (108,
#   'Fruits Basket, Vol. 9 (Fruits Basket #9)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-9-fruits-basket-9_563/index.html',
#   Decimal('33.95'),
#   'In stock',
#   4,
#   4),
#  (109,
#   'Roller Girl',
#   'http://books.toscrape.com/catalogue/roller-girl_540/index.html',
#   Decimal('14.10'),
#   'In stock',
#   3,
#   4),
#  (110,
#   'Fruits Basket, Vol. 7 (Fruits Basket #7)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-7-fruits-basket-7_468/index.html',
#   Decimal('19.57'),
#   'In stock',
#   3,
#   4),
#  (111,
#   'Fruits Basket, Vol. 6 (Fruits Basket #6)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-6-fruits-basket-6_427/index.html',
#   Decimal('20.96'),
#   'In stock',
#   4,
#   4),
#  (112,
#   'Death Note, Vol. 6: Give-and-Take (Death Note #6)',
#   'http://books.toscrape.com/catalogue/death-note-vol-6-give-and-take-death-note-6_425/index.html',
#   Decimal('36.39'),
#   'In stock',
#   3,
#   4),
#  (113,
#   'Fruits Basket, Vol. 5 (Fruits Basket #5)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-5-fruits-basket-5_376/index.html',
#   Decimal('16.33'),
#   'In stock',
#   3,
#   4),
#  (117,
#   'The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine)',
#   'http://books.toscrape.com/catalogue/the-wicked-the-divine-vol-3-commercial-suicide-the-wicked-the-divine_287/index.html',
#   Decimal('14.41'),
#   'In stock',
#   3,
#   4),
#  (122,
#   'Original Fake',
#   'http://books.toscrape.com/catalogue/original-fake_203/index.html',
#   Decimal('31.45'),
#   'In stock',
#   3,
#   4),
#  (128,
#   'Saga, Volume 2 (Saga (Collected Editions) #2)',
#   'http://books.toscrape.com/catalogue/saga-volume-2-saga-collected-editions-2_107/index.html',
#   Decimal('11.75'),
#   'In stock',
#   3,
#   4),
#  (129,
#   'Fruits Basket, Vol. 2 (Fruits Basket #2)',
#   'http://books.toscrape.com/catalogue/fruits-basket-vol-2-fruits-basket-2_100/index.html',
#   Decimal('11.64'),
#   'In stock',
#   3,
#   4),
#  (130,
#   'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#   'http://books.toscrape.com/catalogue/y-the-last-man-vol-1-unmanned-y-the-last-man-1_98/index.html',
#   Decimal('18.51'),
#   'In stock',
#   3,
#   4),
#  (133,
#   'The Complete Maus (Maus #1-2)',
#   'http://books.toscrape.com/catalogue/the-complete-maus-maus-1-2_62/index.html',
#   Decimal('10.64'),
#   'In stock',
#   3,
#   4),
#  (137,
#   'Paper Girls, Vol. 1 (Paper Girls #1-5)',
#   'http://books.toscrape.com/catalogue/paper-girls-vol-1-paper-girls-1-5_44/index.html',
#   Decimal('21.71'),
#   'In stock',
#   4,
#   4),
#  (138,
#   'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',
#   'http://books.toscrape.com/catalogue/ouran-high-school-host-club-vol-1-ouran-high-school-host-club-1_43/index.html',
#   Decimal('29.87'),
#   'In stock',
#   3,
#   4),
#  (139,
#   'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#   'http://books.toscrape.com/catalogue/ms-marvel-vol-1-no-normal-ms-marvel-2014-2015-1_34/index.html',
#   Decimal('39.39'),
#   'In stock',
#   4,
#   4),
#  (145,
#   'The Secret Garden',
#   'http://books.toscrape.com/catalogue/the-secret-garden_413/index.html',
#   Decimal('15.08'),
#   'In stock',
#   3,
#   5),
#  (148,
#   'The Hound of the Baskervilles (Sherlock Holmes #5)',
#   'http://books.toscrape.com/catalogue/the-hound-of-the-baskervilles-sherlock-holmes-5_348/index.html',
#   Decimal('14.82'),
#   'In stock',
#   3,
#   5),
#  (149,
#   'Little Women (Little Women #1)',
#   'http://books.toscrape.com/catalogue/little-women-little-women-1_331/index.html',
#   Decimal('28.07'),
#   'In stock',
#   4,
#   5),
#  (150,
#   'Gone with the Wind',
#   'http://books.toscrape.com/catalogue/gone-with-the-wind_324/index.html',
#   Decimal('32.49'),
#   'In stock',
#   3,
#   5),
#  (153,
#   'Wuthering Heights',
#   'http://books.toscrape.com/catalogue/wuthering-heights_307/index.html',
#   Decimal('17.73'),
#   'In stock',
#   3,
#   5),
#  (155,
#   'The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',
#   'http://books.toscrape.com/catalogue/the-complete-stories-and-poems-the-works-of-edgar-allan-poe-cameo-edition_238/index.html',
#   Decimal('26.78'),
#   'In stock',
#   4,
#   5),
#  (164,
#   "Sophie's World",
#   'http://books.toscrape.com/catalogue/sophies-world_966/index.html',
#   Decimal('15.94'),
#   'In stock',
#   3,
#   6),
#  (166,
#   'The Stranger',
#   'http://books.toscrape.com/catalogue/the-stranger_861/index.html',
#   Decimal('17.44'),
#   'In stock',
#   3,
#   6),
#  (178,
#   'First and First (Five Boroughs #3)',
#   'http://books.toscrape.com/catalogue/first-and-first-five-boroughs-3_893/index.html',
#   Decimal('15.97'),
#   'In stock',
#   3,
#   7),
#  (182,
#   'Something More Than This',
#   'http://books.toscrape.com/catalogue/something-more-than-this_834/index.html',
#   Decimal('16.24'),
#   'In stock',
#   3,
#   7),
#  (183,
#   'Doing It Over (Most Likely To #1)',
#   'http://books.toscrape.com/catalogue/doing-it-over-most-likely-to-1_802/index.html',
#   Decimal('35.61'),
#   'In stock',
#   3,
#   7),
#  (184,
#   "The Wedding Pact (The O'Malleys #2)",
#   'http://books.toscrape.com/catalogue/the-wedding-pact-the-omalleys-2_767/index.html',
#   Decimal('32.61'),
#   'In stock',
#   3,
#   7),
#  (189,
#   "A Gentleman's Position (Society of Gentlemen #3)",
#   'http://books.toscrape.com/catalogue/a-gentlemans-position-society-of-gentlemen-3_584/index.html',
#   Decimal('14.75'),
#   'In stock',
#   3,
#   7),
#  (190,
#   'Sit, Stay, Love',
#   'http://books.toscrape.com/catalogue/sit-stay-love_486/index.html',
#   Decimal('20.90'),
#   'In stock',
#   3,
#   7),
#  (193,
#   'Dark Lover (Black Dagger Brotherhood #1)',
#   'http://books.toscrape.com/catalogue/dark-lover-black-dagger-brotherhood-1_319/index.html',
#   Decimal('12.87'),
#   'In stock',
#   3,
#   7),
#  (194,
#   'Changing the Game (Play by Play #2)',
#   'http://books.toscrape.com/catalogue/changing-the-game-play-by-play-2_317/index.html',
#   Decimal('13.38'),
#   'In stock',
#   3,
#   7),
#  (196,
#   'The Purest Hook (Second Circle Tattoos #3)',
#   'http://books.toscrape.com/catalogue/the-purest-hook-second-circle-tattoos-3_271/index.html',
#   Decimal('12.25'),
#   'In stock',
#   3,
#   7),
#  (198,
#   'Reservations for Two',
#   'http://books.toscrape.com/catalogue/reservations-for-two_211/index.html',
#   Decimal('11.10'),
#   'In stock',
#   3,
#   7),
#  (200,
#   'Where Lightning Strikes (Bleeding Stars #3)',
#   'http://books.toscrape.com/catalogue/where-lightning-strikes-bleeding-stars-3_96/index.html',
#   Decimal('39.77'),
#   'In stock',
#   3,
#   7),
#  (205,
#   'Imperfect Harmony',
#   'http://books.toscrape.com/catalogue/imperfect-harmony_26/index.html',
#   Decimal('34.74'),
#   'In stock',
#   4,
#   7),
#  (206,
#   'Fighting Fate (Fighting #6)',
#   'http://books.toscrape.com/catalogue/fighting-fate-fighting-6_18/index.html',
#   Decimal('39.24'),
#   'In stock',
#   3,
#   7),
#  (209,
#   'Bounty (Colorado Mountain #7)',
#   'http://books.toscrape.com/catalogue/bounty-colorado-mountain-7_9/index.html',
#   Decimal('37.26'),
#   'In stock',
#   4,
#   7),
#  (211,
#   "Will You Won't You Want Me?",
#   'http://books.toscrape.com/catalogue/will-you-wont-you-want-me_644/index.html',
#   Decimal('13.86'),
#   'In stock',
#   3,
#   8),
#  (212,
#   'Keep Me Posted',
#   'http://books.toscrape.com/catalogue/keep-me-posted_594/index.html',
#   Decimal('20.46'),
#   'In stock',
#   4,
#   8),
#  (215,
#   'Some Women',
#   'http://books.toscrape.com/catalogue/some-women_341/index.html',
#   Decimal('13.73'),
#   'In stock',
#   3,
#   8),
#  (224,
#   "I've Got Your Number",
#   'http://books.toscrape.com/catalogue/ive-got-your-number_173/index.html',
#   Decimal('19.69'),
#   'In stock',
#   3,
#   8),
#  (225,
#   'The Edge of Reason (Bridget Jones #2)',
#   'http://books.toscrape.com/catalogue/the-edge-of-reason-bridget-jones-2_63/index.html',
#   Decimal('19.18'),
#   'In stock',
#   3,
#   8),
#  (230,
#   'Thirst',
#   'http://books.toscrape.com/catalogue/thirst_946/index.html',
#   Decimal('17.27'),
#   'In stock',
#   3,
#   9),
#  (238,
#   'The First Hostage (J.B. Collins #2)',
#   'http://books.toscrape.com/catalogue/the-first-hostage-jb-collins-2_749/index.html',
#   Decimal('25.85'),
#   'In stock',
#   3,
#   9),
#  (240,
#   'Still Life with Bread Crumbs',
#   'http://books.toscrape.com/catalogue/still-life-with-bread-crumbs_738/index.html',
#   Decimal('26.41'),
#   'In stock',
#   3,
#   9),
#  (243,
#   'My Mrs. Brown',
#   'http://books.toscrape.com/catalogue/my-mrs-brown_719/index.html',
#   Decimal('24.48'),
#   'In stock',
#   3,
#   9),
#  (245,
#   'I Am Pilgrim (Pilgrim #1)',
#   'http://books.toscrape.com/catalogue/i-am-pilgrim-pilgrim-1_703/index.html',
#   Decimal('10.60'),
#   'In stock',
#   3,
#   9),
#  (246,
#   'Eligible (The Austen Project #4)',
#   'http://books.toscrape.com/catalogue/eligible-the-austen-project-4_692/index.html',
#   Decimal('27.09'),
#   'In stock',
#   3,
#   9),
#  (247,
#   'Eight Hundred Grapes',
#   'http://books.toscrape.com/catalogue/eight-hundred-grapes_690/index.html',
#   Decimal('14.39'),
#   'In stock',
#   3,
#   9),
#  (248,
#   'Dear Mr. Knightley',
#   'http://books.toscrape.com/catalogue/dear-mr-knightley_684/index.html',
#   Decimal('11.21'),
#   'In stock',
#   3,
#   9),
#  (249,
#   'Cometh the Hour (The Clifton Chronicles #6)',
#   'http://books.toscrape.com/catalogue/cometh-the-hour-the-clifton-chronicles-6_681/index.html',
#   Decimal('25.01'),
#   'In stock',
#   3,
#   9),
#  (250,
#   'Balloon Animals',
#   'http://books.toscrape.com/catalogue/balloon-animals_665/index.html',
#   Decimal('17.03'),
#   'In stock',
#   3,
#   9),
#  (255,
#   'Mothering Sunday',
#   'http://books.toscrape.com/catalogue/mothering-sunday_600/index.html',
#   Decimal('13.34'),
#   'In stock',
#   3,
#   9),
#  (257,
#   'Daredevils',
#   'http://books.toscrape.com/catalogue/daredevils_590/index.html',
#   Decimal('16.34'),
#   'In stock',
#   3,
#   9),
#  (262,
#   'Hystopia: A Novel',
#   'http://books.toscrape.com/catalogue/hystopia-a-novel_523/index.html',
#   Decimal('21.96'),
#   'In stock',
#   4,
#   9),
#  (266,
#   'Me Before You (Me Before You #1)',
#   'http://books.toscrape.com/catalogue/me-before-you-me-before-you-1_434/index.html',
#   Decimal('19.02'),
#   'In stock',
#   3,
#   9),
#  (268,
#   'The Little Paris Bookshop',
#   'http://books.toscrape.com/catalogue/the-little-paris-bookshop_407/index.html',
#   Decimal('24.73'),
#   'In stock',
#   3,
#   9),
#  (275,
#   'Three-Martini Lunch',
#   'http://books.toscrape.com/catalogue/three-martini-lunch_290/index.html',
#   Decimal('23.21'),
#   'In stock',
#   3,
#   9),
#  (276,
#   'The Nightingale',
#   'http://books.toscrape.com/catalogue/the-nightingale_267/index.html',
#   Decimal('26.26'),
#   'In stock',
#   4,
#   9),
#  (281,
#   'Lila (Gilead #3)',
#   'http://books.toscrape.com/catalogue/lila-gilead-3_190/index.html',
#   Decimal('12.47'),
#   'In stock',
#   3,
#   9),
#  (286,
#   'The Course of Love',
#   'http://books.toscrape.com/catalogue/the-course-of-love_109/index.html',
#   Decimal('16.78'),
#   'In stock',
#   3,
#   9),
#  (288,
#   'The Silent Wife',
#   'http://books.toscrape.com/catalogue/the-silent-wife_83/index.html',
#   Decimal('12.34'),
#   'In stock',
#   3,
#   9),
#  (289,
#   'The Bette Davis Club',
#   'http://books.toscrape.com/catalogue/the-bette-davis-club_59/index.html',
#   Decimal('30.66'),
#   'In stock',
#   3,
#   9),
#  (296,
#   'Little Red',
#   'http://books.toscrape.com/catalogue/little-red_817/index.html',
#   Decimal('13.47'),
#   'In stock',
#   3,
#   10),
#  (297,
#   "Walt Disney's Alice in Wonderland",
#   'http://books.toscrape.com/catalogue/walt-disneys-alice-in-wonderland_777/index.html',
#   Decimal('12.96'),
#   'In stock',
#   3,
#   10),
#  (299,
#   'Rain Fish',
#   'http://books.toscrape.com/catalogue/rain-fish_728/index.html',
#   Decimal('23.57'),
#   'In stock',
#   3,
#   10),
#  (300,
#   'Once Was a Time',
#   'http://books.toscrape.com/catalogue/once-was-a-time_724/index.html',
#   Decimal('18.28'),
#   'In stock',
#   3,
#   10),
#  (303,
#   'The Whale',
#   'http://books.toscrape.com/catalogue/the-whale_501/index.html',
#   Decimal('35.96'),
#   'In stock',
#   4,
#   10),
#  (312,
#   'The Cat in the Hat (Beginner Books B-1)',
#   'http://books.toscrape.com/catalogue/the-cat-in-the-hat-beginner-books-b-1_235/index.html',
#   Decimal('16.26'),
#   'In stock',
#   3,
#   10),
#  (313,
#   'Red: The True Story of Red Riding Hood',
#   'http://books.toscrape.com/catalogue/red-the-true-story-of-red-riding-hood_210/index.html',
#   Decimal('28.54'),
#   'In stock',
#   3,
#   10),
#  (315,
#   'Green Eggs and Ham (Beginner Books B-16)',
#   'http://books.toscrape.com/catalogue/green-eggs-and-ham-beginner-books-b-16_165/index.html',
#   Decimal('10.79'),
#   'In stock',
#   3,
#   10),
#  (316,
#   'Counting Thyme',
#   'http://books.toscrape.com/catalogue/counting-thyme_142/index.html',
#   Decimal('10.62'),
#   'In stock',
#   3,
#   10),
#  (317,
#   'Are We There Yet?',
#   'http://books.toscrape.com/catalogue/are-we-there-yet_122/index.html',
#   Decimal('10.66'),
#   'In stock',
#   3,
#   10),
#  (320,
#   'Charlie and the Chocolate Factory (Charlie Bucket #1)',
#   'http://books.toscrape.com/catalogue/charlie-and-the-chocolate-factory-charlie-bucket-1_13/index.html',
#   Decimal('22.85'),
#   'In stock',
#   3,
#   10),
#  (322,
#   'You Are What You Love: The Spiritual Power of Habit',
#   'http://books.toscrape.com/catalogue/you-are-what-you-love-the-spiritual-power-of-habit_872/index.html',
#   Decimal('21.87'),
#   'In stock',
#   4,
#   11),
#  (324,
#   'The Book of Mormon',
#   'http://books.toscrape.com/catalogue/the-book-of-mormon_571/index.html',
#   Decimal('24.57'),
#   'In stock',
#   3,
#   11),
#  (327,
#   "Choosing Our Religion: The Spiritual Lives of America's Nones",
#   'http://books.toscrape.com/catalogue/choosing-our-religion-the-spiritual-lives-of-americas-nones_14/index.html',
#   Decimal('28.42'),
#   'In stock',
#   4,
#   11),
#  (329,
#   'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#   'http://books.toscrape.com/catalogue/the-five-love-languages-how-to-express-heartfelt-commitment-to-your-mate_969/index.html',
#   Decimal('31.05'),
#   'In stock',
#   3,
#   12),
#  (333,
#   'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#   'http://books.toscrape.com/catalogue/throwing-rocks-at-the-google-bus-how-growth-became-the-enemy-of-prosperity_948/index.html',
#   Decimal('31.12'),
#   'In stock',
#   3,
#   12),
#  (334,
#   'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   'http://books.toscrape.com/catalogue/the-life-changing-magic-of-tidying-up-the-japanese-art-of-decluttering-and-organizing_936/index.html',
#   Decimal('16.77'),
#   'In stock',
#   3,
#   12),
#  (338,
#   'Reskilling America: Learning to Labor in the Twenty-First Century',
#   'http://books.toscrape.com/catalogue/reskilling-america-learning-to-labor-in-the-twenty-first-century_922/index.html',
#   Decimal('19.83'),
#   'In stock',
#   3,
#   12),
#  (339,
#   'In the Country We Love: My Family Divided',
#   'http://books.toscrape.com/catalogue/in-the-country-we-love-my-family-divided_901/index.html',
#   Decimal('22.00'),
#   'In stock',
#   4,
#   12),
#  (345,
#   'The Genius of Birds',
#   'http://books.toscrape.com/catalogue/the-genius-of-birds_843/index.html',
#   Decimal('17.24'),
#   'In stock',
#   3,
#   12),
#  (347,
#   "So You've Been Publicly Shamed",
#   'http://books.toscrape.com/catalogue/so-youve-been-publicly-shamed_832/index.html',
#   Decimal('12.23'),
#   'In stock',
#   3,
#   12),
#  (348,
#   'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   'http://books.toscrape.com/catalogue/daring-greatly-how-the-courage-to-be-vulnerable-transforms-the-way-we-live-love-parent-and-lead_799/index.html',
#   Decimal('19.43'),
#   'In stock',
#   3,
#   12),
#  (349,
#   'Big Magic: Creative Living Beyond Fear',
#   'http://books.toscrape.com/catalogue/big-magic-creative-living-beyond-fear_796/index.html',
#   Decimal('30.80'),
#   'In stock',
#   3,
#   12),
#  (351,
#   'Agnostic: A Spirited Manifesto',
#   'http://books.toscrape.com/catalogue/agnostic-a-spirited-manifesto_786/index.html',
#   Decimal('12.51'),
#   'In stock',
#   3,
#   12),
#  (352,
#   'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   'http://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html',
#   Decimal('38.20'),
#   'In stock',
#   4,
#   12),
#  (353,
#   "What's It Like in Space?: Stories from Astronauts Who've Been There",
#   'http://books.toscrape.com/catalogue/whats-it-like-in-space-stories-from-astronauts-whove-been-there_779/index.html',
#   Decimal('19.60'),
#   'In stock',
#   3,
#   12),
#  (355,
#   'The Literature Book (Big Ideas Simply Explained)',
#   'http://books.toscrape.com/catalogue/the-literature-book-big-ideas-simply-explained_755/index.html',
#   Decimal('17.43'),
#   'In stock',
#   3,
#   12),
#  (356,
#   'The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World’s Most Precious Manuscripts',
#   'http://books.toscrape.com/catalogue/the-bad-ass-librarians-of-timbuktu-and-their-race-to-save-the-worlds-most-precious-manuscripts_745/index.html',
#   Decimal('15.77'),
#   'In stock',
#   3,
#   12),
#  (362,
#   'Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   'http://books.toscrape.com/catalogue/far-away-places-on-the-brink-of-change-seven-continents-twenty-five-years_694/index.html',
#   Decimal('15.06'),
#   'In stock',
#   3,
#   12),
#  (364,
#   'Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#   'http://books.toscrape.com/catalogue/buying-in-the-secret-dialogue-between-what-we-buy-and-who-we-are_670/index.html',
#   Decimal('37.80'),
#   'In stock',
#   4,
#   12),
#  (370,
#   'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#   'http://books.toscrape.com/catalogue/snatched-how-a-drug-queen-went-undercover-for-the-dea-and-was-kidnapped-by-colombian-guerillas_631/index.html',
#   Decimal('21.21'),
#   'In stock',
#   3,
#   12),
#  (372,
#   'The Sleep Revolution: Transforming Your Life, One Night at a Time',
#   'http://books.toscrape.com/catalogue/the-sleep-revolution-transforming-your-life-one-night-at-a-time_608/index.html',
#   Decimal('11.68'),
#   'In stock',
#   3,
#   12),
#  (373,
#   'Mother, Can You Not?',
#   'http://books.toscrape.com/catalogue/mother-can-you-not_599/index.html',
#   Decimal('16.89'),
#   'In stock',
#   3,
#   12),
#  (374,
#   "A Mother's Reckoning: Living in the Aftermath of Tragedy",
#   'http://books.toscrape.com/catalogue/a-mothers-reckoning-living-in-the-aftermath-of-tragedy_585/index.html',
#   Decimal('19.53'),
#   'In stock',
#   3,
#   12),
#  (377,
#   'Zero to One: Notes on Startups, or How to Build the Future',
#   'http://books.toscrape.com/catalogue/zero-to-one-notes-on-startups-or-how-to-build-the-future_555/index.html',
#   Decimal('34.06'),
#   'In stock',
#   3,
#   12),
#  (378,
#   'Why Not Me?',
#   'http://books.toscrape.com/catalogue/why-not-me_554/index.html',
#   Decimal('17.76'),
#   'In stock',
#   3,
#   12),
#  (380,
#   "The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#   'http://books.toscrape.com/catalogue/the-midnight-assassin-panic-scandal-and-the-hunt-for-americas-first-serial-killer_549/index.html',
#   Decimal('28.45'),
#   'In stock',
#   4,
#   12),
#  (382,
#   'Rising Strong',
#   'http://books.toscrape.com/catalogue/rising-strong_539/index.html',
#   Decimal('21.82'),
#   'In stock',
#   3,
#   12),
#  (383,
#   "Man's Search for Meaning",
#   'http://books.toscrape.com/catalogue/mans-search-for-meaning_533/index.html',
#   Decimal('29.48'),
#   'In stock',
#   3,
#   12),
#  (385,
#   'Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want',
#   'http://books.toscrape.com/catalogue/living-forward-a-proven-plan-to-stop-drifting-and-get-the-life-you-want_531/index.html',
#   Decimal('12.55'),
#   'In stock',
#   3,
#   12),
#  (387,
#   "Brazen: The Courage to Find the You That's Been Hiding",
#   'http://books.toscrape.com/catalogue/brazen-the-courage-to-find-the-you-thats-been-hiding_514/index.html',
#   Decimal('19.22'),
#   'In stock',
#   3,
#   12),
#  (390,
#   'A Murder Over a Girl: Justice, Gender, Junior High',
#   'http://books.toscrape.com/catalogue/a-murder-over-a-girl-justice-gender-junior-high_511/index.html',
#   Decimal('13.20'),
#   'In stock',
#   3,
#   12),
#  (397,
#   "Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut",
#   'http://books.toscrape.com/catalogue/talking-to-girls-about-duran-duran-one-young-mans-quest-for-true-love-and-a-cooler-haircut_394/index.html',
#   Decimal('25.15'),
#   'In stock',
#   4,
#   12),
#  (398,
#   'My Mother Was Nuts',
#   'http://books.toscrape.com/catalogue/my-mother-was-nuts_388/index.html',
#   Decimal('31.63'),
#   'In stock',
#   4,
#   12),
#  (399,
#   'Data, A Love Story: How I Gamed Online Dating to Meet My Match',
#   'http://books.toscrape.com/catalogue/data-a-love-story-how-i-gamed-online-dating-to-meet-my-match_367/index.html',
#   Decimal('32.35'),
#   'In stock',
#   3,
#   12),
#  (400,
#   'The Jazz of Physics: The Secret Link Between Music and the Structure of the Universe',
#   'http://books.toscrape.com/catalogue/the-jazz-of-physics-the-secret-link-between-music-and-the-structure-of-the-universe_350/index.html',
#   Decimal('38.71'),
#   'In stock',
#   3,
#   12),
#  (401,
#   'The Gunning of America: Business and the Making of American Gun Culture',
#   'http://books.toscrape.com/catalogue/the-gunning-of-america-business-and-the-making-of-american-gun-culture_347/index.html',
#   Decimal('16.81'),
#   'In stock',
#   3,
#   12),
#  (404,
#   "We the People: The Modern-Day Figures Who Have Reshaped and Affirmed the Founding Fathers' Vision of America",
#   'http://books.toscrape.com/catalogue/we-the-people-the-modern-day-figures-who-have-reshaped-and-affirmed-the-founding-fathers-vision-of-america_302/index.html',
#   Decimal('31.95'),
#   'In stock',
#   3,
#   12),
#  (410,
#   'Stiff: The Curious Lives of Human Cadavers',
#   'http://books.toscrape.com/catalogue/stiff-the-curious-lives-of-human-cadavers_226/index.html',
#   Decimal('36.74'),
#   'In stock',
#   3,
#   12),
#  (413,
#   'Outliers: The Story of Success',
#   'http://books.toscrape.com/catalogue/outliers-the-story-of-success_204/index.html',
#   Decimal('14.16'),
#   'In stock',
#   3,
#   12),
#  (415,
#   'Night (The Night Trilogy #1)',
#   'http://books.toscrape.com/catalogue/night-the-night-trilogy-1_199/index.html',
#   Decimal('13.51'),
#   'In stock',
#   3,
#   12),
#  (421,
#   "In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin",
#   'http://books.toscrape.com/catalogue/in-the-garden-of-beasts-love-terror-and-an-american-family-in-hitlers-berlin_175/index.html',
#   Decimal('28.85'),
#   'In stock',
#   3,
#   12),
#  (424,
#   'Disrupted: My Misadventure in the Start-Up Bubble',
#   'http://books.toscrape.com/catalogue/disrupted-my-misadventure-in-the-start-up-bubble_148/index.html',
#   Decimal('15.28'),
#   'In stock',
#   3,
#   12),
#  (430,
#   'A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#   'http://books.toscrape.com/catalogue/a-walk-in-the-woods-rediscovering-america-on-the-appalachian-trail_118/index.html',
#   Decimal('30.48'),
#   'In stock',
#   4,
#   12),
#  (431,
#   'The Suffragettes (Little Black Classics, #96)',
#   'http://books.toscrape.com/catalogue/the-suffragettes-little-black-classics-96_112/index.html',
#   Decimal('11.89'),
#   'In stock',
#   3,
#   12),
#  (432,
#   "Kindle Paperwhite User's Guide",
#   'http://books.toscrape.com/catalogue/kindle-paperwhite-users-guide_103/index.html',
#   Decimal('34.00'),
#   'In stock',
#   3,
#   12),
#  (436,
#   'The End of the Jesus Era (An Investigation #1)',
#   'http://books.toscrape.com/catalogue/the-end-of-the-jesus-era-an-investigation-1_64/index.html',
#   Decimal('14.40'),
#   'In stock',
#   3,
#   12),
#  (441,
#   'Love Is a Mix Tape (Music #1)',
#   'http://books.toscrape.com/catalogue/love-is-a-mix-tape-music-1_711/index.html',
#   Decimal('18.03'),
#   'In stock',
#   3,
#   13),
#  (442,
#   'Please Kill Me: The Uncensored Oral History of Punk',
#   'http://books.toscrape.com/catalogue/please-kill-me-the-uncensored-oral-history-of-punk_537/index.html',
#   Decimal('31.19'),
#   'In stock',
#   4,
#   13),
#  (446,
#   'Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',
#   'http://books.toscrape.com/catalogue/orchestra-of-exiles-the-story-of-bronislaw-huberman-the-israel-philharmonic-and-the-one-thousand-jews-he-saved-from-nazi-horrors_337/index.html',
#   Decimal('12.36'),
#   'In stock',
#   3,
#   13),
#  (450,
#   'Forever Rockers (The Rocker #12)',
#   'http://books.toscrape.com/catalogue/forever-rockers-the-rocker-12_19/index.html',
#   Decimal('28.80'),
#   'In stock',
#   3,
#   13),
#  (451,
#   'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'http://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#   Decimal('17.93'),
#   'In stock',
#   3,
#   14),
#  (452,
#   'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'http://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#   Decimal('22.60'),
#   'In stock',
#   4,
#   14),
#  (453,
#   'Starving Hearts (Triangular Trade Trilogy, #1)',
#   'http://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html',
#   Decimal('13.99'),
#   'In stock',
#   3,
#   14),
#  (454,
#   "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#   'http://books.toscrape.com/catalogue/americas-cradle-of-quarterbacks-western-pennsylvanias-football-factory-from-johnny-unitas-to-joe-montana_974/index.html',
#   Decimal('22.50'),
#   'In stock',
#   3,
#   14),
#  (456,
#   'Penny Maybe',
#   'http://books.toscrape.com/catalogue/penny-maybe_965/index.html',
#   Decimal('33.29'),
#   'In stock',
#   3,
#   14),
#  (457,
#   'Maude (1883-1993):She Grew Up with the country',
#   'http://books.toscrape.com/catalogue/maude-1883-1993she-grew-up-with-the-country_964/index.html',
#   Decimal('18.02'),
#   'In stock',
#   3,
#   14),
#  (465,
#   'The Secret (The Secret #1)',
#   'http://books.toscrape.com/catalogue/the-secret-the-secret-1_859/index.html',
#   Decimal('27.37'),
#   'In stock',
#   4,
#   14),
#  (470,
#   "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#   'http://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html',
#   Decimal('32.00'),
#   'In stock',
#   3,
#   14),
#  (475,
#   'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)',
#   'http://books.toscrape.com/catalogue/miss-peregrines-home-for-peculiar-children-miss-peregrines-peculiar-children-1_819/index.html',
#   Decimal('10.76'),
#   'In stock',
#   3,
#   14),
#  (476,
#   'Large Print Heart of the Pride',
#   'http://books.toscrape.com/catalogue/large-print-heart-of-the-pride_815/index.html',
#   Decimal('19.15'),
#   'In stock',
#   3,
#   14),
#  (480,
#   'Drive: The Surprising Truth About What Motivates Us',
#   'http://books.toscrape.com/catalogue/drive-the-surprising-truth-about-what-motivates-us_804/index.html',
#   Decimal('34.95'),
#   'In stock',
#   4,
#   14),
#  (482,
#   'Beauty Restored (Riley Family Legacy Novellas #3)',
#   'http://books.toscrape.com/catalogue/beauty-restored-riley-family-legacy-novellas-3_794/index.html',
#   Decimal('11.11'),
#   'In stock',
#   3,
#   14),
#  (483,
#   "Ayumi's Violin",
#   'http://books.toscrape.com/catalogue/ayumis-violin_791/index.html',
#   Decimal('15.48'),
#   'In stock',
#   3,
#   14),
#  (485,
#   'Amy Meets the Saints and Sages',
#   'http://books.toscrape.com/catalogue/amy-meets-the-saints-and-sages_789/index.html',
#   Decimal('18.46'),
#   'In stock',
#   3,
#   14),
#  (487,
#   'V for Vendetta (V for Vendetta Complete)',
#   'http://books.toscrape.com/catalogue/v-for-vendetta-v-for-vendetta-complete_776/index.html',
#   Decimal('37.10'),
#   'In stock',
#   4,
#   14),
#  (492,
#   'The Power of Habit: Why We Do What We Do in Life and Business',
#   'http://books.toscrape.com/catalogue/the-power-of-habit-why-we-do-what-we-do-in-life-and-business_760/index.html',
#   Decimal('16.88'),
#   'In stock',
#   3,
#   14),
#  (496,
#   'Lady Midnight (The Dark Artifices #1)',
#   'http://books.toscrape.com/catalogue/lady-midnight-the-dark-artifices-1_707/index.html',
#   Decimal('16.28'),
#   'In stock',
#   3,
#   14),
#  (498,
#   'Greek Mythic History',
#   'http://books.toscrape.com/catalogue/greek-mythic-history_698/index.html',
#   Decimal('10.23'),
#   'In stock',
#   3,
#   14),
#  (502,
#   'City of Fallen Angels (The Mortal Instruments #4)',
#   'http://books.toscrape.com/catalogue/city-of-fallen-angels-the-mortal-instruments-4_677/index.html',
#   Decimal('11.23'),
#   'In stock',
#   3,
#   14),
#  (505,
#   'Carry On, Warrior: Thoughts on Life Unarmed',
#   'http://books.toscrape.com/catalogue/carry-on-warrior-thoughts-on-life-unarmed_672/index.html',
#   Decimal('31.85'),
#   'In stock',
#   3,
#   14),
#  (508,
#   'The Three Searches, Meaning, and the Story',
#   'http://books.toscrape.com/catalogue/the-three-searches-meaning-and-the-story_649/index.html',
#   Decimal('13.33'),
#   'In stock',
#   3,
#   14),
#  (515,
#   'Underlying Notes',
#   'http://books.toscrape.com/catalogue/underlying-notes_577/index.html',
#   Decimal('11.82'),
#   'In stock',
#   3,
#   14),
#  (517,
#   'The Flowers Lied',
#   'http://books.toscrape.com/catalogue/the-flowers-lied_573/index.html',
#   Decimal('16.68'),
#   'In stock',
#   3,
#   14),
#  (518,
#   'NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   'http://books.toscrape.com/catalogue/nano-what-now-finding-your-editing-process-revising-your-nanowrimo-book-and-building-a-writing-career-through-publishing-and-beyond_566/index.html',
#   Decimal('10.41'),
#   'In stock',
#   3,
#   14),
#  (523,
#   'John Vassos: Industrial Design for Modern Life',
#   'http://books.toscrape.com/catalogue/john-vassos-industrial-design-for-modern-life_526/index.html',
#   Decimal('20.22'),
#   'In stock',
#   4,
#   14),
#  (527,
#   'Death by Leisure: A Cautionary Tale',
#   'http://books.toscrape.com/catalogue/death-by-leisure-a-cautionary-tale_516/index.html',
#   Decimal('37.51'),
#   'In stock',
#   4,
#   14),
#  (530,
#   'The Great Gatsby',
#   'http://books.toscrape.com/catalogue/the-great-gatsby_498/index.html',
#   Decimal('36.05'),
#   'In stock',
#   4,
#   14),
#  (532,
#   'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',
#   'http://books.toscrape.com/catalogue/the-7-habits-of-highly-effective-people-powerful-lessons-in-personal-change_489/index.html',
#   Decimal('33.17'),
#   'In stock',
#   4,
#   14),
#  (534,
#   'Life of Pi',
#   'http://books.toscrape.com/catalogue/life-of-pi_475/index.html',
#   Decimal('13.22'),
#   'In stock',
#   3,
#   14),
#  (538,
#   'The Hobbit (Middle-Earth Universe)',
#   'http://books.toscrape.com/catalogue/the-hobbit-middle-earth-universe_447/index.html',
#   Decimal('17.80'),
#   'In stock',
#   3,
#   14),
#  (539,
#   'The Fellowship of the Ring (The Lord of the Rings #1)',
#   'http://books.toscrape.com/catalogue/the-fellowship-of-the-ring-the-lord-of-the-rings-1_442/index.html',
#   Decimal('10.27'),
#   'In stock',
#   3,
#   14),
#  (540,
#   'Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman',
#   'http://books.toscrape.com/catalogue/ship-leaves-harbor-essays-on-travel-by-a-recovering-journeyman_438/index.html',
#   Decimal('30.60'),
#   'In stock',
#   3,
#   14),
#  (545,
#   'The 5th Wave (The 5th Wave #1)',
#   'http://books.toscrape.com/catalogue/the-5th-wave-the-5th-wave-1_397/index.html',
#   Decimal('11.83'),
#   'In stock',
#   3,
#   14),
#  (546,
#   'Shiver (The Wolves of Mercy Falls #1)',
#   'http://books.toscrape.com/catalogue/shiver-the-wolves-of-mercy-falls-1_392/index.html',
#   Decimal('16.23'),
#   'In stock',
#   3,
#   14),
#  (547,
#   'Remember Me?',
#   'http://books.toscrape.com/catalogue/remember-me_391/index.html',
#   Decimal('11.48'),
#   'In stock',
#   3,
#   14),
#  (551,
#   'Fool Me Once',
#   'http://books.toscrape.com/catalogue/fool-me-once_374/index.html',
#   Decimal('16.96'),
#   'In stock',
#   3,
#   14),
#  (556,
#   'The Shining (The Shining #1)',
#   'http://books.toscrape.com/catalogue/the-shining-the-shining-1_354/index.html',
#   Decimal('27.88'),
#   'In stock',
#   3,
#   14),
#  (558,
#   'Outlander (Outlander #1)',
#   'http://books.toscrape.com/catalogue/outlander-outlander-1_338/index.html',
#   Decimal('19.67'),
#   'In stock',
#   3,
#   14),
#  (559,
#   'Mockingjay (The Hunger Games #3)',
#   'http://books.toscrape.com/catalogue/mockingjay-the-hunger-games-3_333/index.html',
#   Decimal('20.44'),
#   'In stock',
#   4,
#   14),
#  (560,
#   "Harry Potter and the Sorcerer's Stone (Harry Potter #1)",
#   'http://books.toscrape.com/catalogue/harry-potter-and-the-sorcerers-stone-harry-potter-1_329/index.html',
#   Decimal('13.90'),
#   'In stock',
#   3,
#   14),
#  (565,
#   "Where'd You Go, Bernadette",
#   'http://books.toscrape.com/catalogue/whered-you-go-bernadette_304/index.html',
#   Decimal('18.13'),
#   'In stock',
#   3,
#   14),
#  (567,
#   'The Paris Wife',
#   'http://books.toscrape.com/catalogue/the-paris-wife_269/index.html',
#   Decimal('36.80'),
#   'In stock',
#   3,
#   14),
#  (571,
#   'The Giver (The Giver Quartet #1)',
#   'http://books.toscrape.com/catalogue/the-giver-the-giver-quartet-1_251/index.html',
#   Decimal('12.30'),
#   'In stock',
#   3,
#   14),
#  (584,
#   'Is Everyone Hanging Out Without Me? (And Other Concerns)',
#   'http://books.toscrape.com/catalogue/is-everyone-hanging-out-without-me-and-other-concerns_178/index.html',
#   Decimal('20.11'),
#   'In stock',
#   3,
#   14),
#  (587,
#   'Eclipse (Twilight #3)',
#   'http://books.toscrape.com/catalogue/eclipse-twilight-3_152/index.html',
#   Decimal('18.74'),
#   'In stock',
#   3,
#   14),
#  (590,
#   'David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',
#   'http://books.toscrape.com/catalogue/david-and-goliath-underdogs-misfits-and-the-art-of-battling-giants_146/index.html',
#   Decimal('17.81'),
#   'In stock',
#   3,
#   14),
#  (594,
#   'A Visit from the Goon Squad',
#   'http://books.toscrape.com/catalogue/a-visit-from-the-goon-squad_117/index.html',
#   Decimal('14.08'),
#   'In stock',
#   3,
#   14),
#  (595,
#   'The Zombie Room',
#   'http://books.toscrape.com/catalogue/the-zombie-room_87/index.html',
#   Decimal('19.69'),
#   'In stock',
#   3,
#   14),
#  (597,
#   'Taking Shots (Assassins #1)',
#   'http://books.toscrape.com/catalogue/taking-shots-assassins-1_57/index.html',
#   Decimal('18.88'),
#   'In stock',
#   3,
#   14),
#  (600,
#   'On the Road (Duluoz Legend)',
#   'http://books.toscrape.com/catalogue/on-the-road-duluoz-legend_40/index.html',
#   Decimal('32.36'),
#   'In stock',
#   3,
#   14),
#  (606,
#   'The Project',
#   'http://books.toscrape.com/catalogue/the-project_856/index.html',
#   Decimal('10.65'),
#   'In stock',
#   3,
#   15),
#  (609,
#   'Arena',
#   'http://books.toscrape.com/catalogue/arena_587/index.html',
#   Decimal('21.36'),
#   'In stock',
#   4,
#   15),
#  (611,
#   "The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2)",
#   'http://books.toscrape.com/catalogue/the-restaurant-at-the-end-of-the-universe-hitchhikers-guide-to-the-galaxy-2_275/index.html',
#   Decimal('10.92'),
#   'In stock',
#   3,
#   15),
#  (612,
#   'Ready Player One',
#   'http://books.toscrape.com/catalogue/ready-player-one_209/index.html',
#   Decimal('19.07'),
#   'In stock',
#   3,
#   15),
#  (618,
#   "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",
#   'http://books.toscrape.com/catalogue/having-the-barbarians-baby-ice-planet-barbarians-75_23/index.html',
#   Decimal('34.96'),
#   'In stock',
#   4,
#   15),
#  (624,
#   'The Torch Is Passed: A Harding Family Story',
#   'http://books.toscrape.com/catalogue/the-torch-is-passed-a-harding-family-story_945/index.html',
#   Decimal('19.09'),
#   'In stock',
#   3,
#   17),
#  (625,
#   'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   'http://books.toscrape.com/catalogue/the-mindfulness-and-acceptance-workbook-for-anxiety-a-guide-to-breaking-free-from-anxiety-phobias-and-worry-using-acceptance-and-commitment-therapy_937/index.html',
#   Decimal('23.89'),
#   'In stock',
#   4,
#   17),
#  (627,
#   'On a Midnight Clear',
#   'http://books.toscrape.com/catalogue/on-a-midnight-clear_912/index.html',
#   Decimal('14.07'),
#   'In stock',
#   3,
#   17),
#  (629,
#   'Shobu Samurai, Project Aryoku (#3)',
#   'http://books.toscrape.com/catalogue/shobu-samurai-project-aryoku-3_830/index.html',
#   Decimal('29.06'),
#   'In stock',
#   3,
#   17),
#  (636,
#   'Code Name Verity (Code Name Verity #1)',
#   'http://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html',
#   Decimal('22.13'),
#   'In stock',
#   4,
#   17),
#  (637,
#   'Cell',
#   'http://books.toscrape.com/catalogue/cell_674/index.html',
#   Decimal('20.29'),
#   'In stock',
#   4,
#   17),
#  (642,
#   'Rook',
#   'http://books.toscrape.com/catalogue/rook_647/index.html',
#   Decimal('37.86'),
#   'In stock',
#   4,
#   17),
#  (645,
#   'The Children',
#   'http://books.toscrape.com/catalogue/the-children_633/index.html',
#   Decimal('11.88'),
#   'In stock',
#   3,
#   17),
#  (646,
#   'One with You (Crossfire #5)',
#   'http://books.toscrape.com/catalogue/one-with-you-crossfire-5_626/index.html',
#   Decimal('15.71'),
#   'In stock',
#   3,
#   17),
#  (651,
#   'The Glass Castle',
#   'http://books.toscrape.com/catalogue/the-glass-castle_496/index.html',
#   Decimal('16.24'),
#   'In stock',
#   3,
#   17),
#  (652,
#   'The Drowning Girls',
#   'http://books.toscrape.com/catalogue/the-drowning-girls_494/index.html',
#   Decimal('35.67'),
#   'In stock',
#   3,
#   17),
#  (657,
#   'The Golden Compass (His Dark Materials #1)',
#   'http://books.toscrape.com/catalogue/the-golden-compass-his-dark-materials-1_445/index.html',
#   Decimal('18.77'),
#   'In stock',
#   3,
#   17),
#  (659,
#   'Pride and Prejudice',
#   'http://books.toscrape.com/catalogue/pride-and-prejudice_437/index.html',
#   Decimal('19.27'),
#   'In stock',
#   3,
#   17),
#  (666,
#   'A Clash of Kings (A Song of Ice and Fire #2)',
#   'http://books.toscrape.com/catalogue/a-clash-of-kings-a-song-of-ice-and-fire-2_356/index.html',
#   Decimal('10.79'),
#   'In stock',
#   3,
#   17),
#  (667,
#   'The Tipping Point: How Little Things Can Make a Big Difference',
#   'http://books.toscrape.com/catalogue/the-tipping-point-how-little-things-can-make-a-big-difference_284/index.html',
#   Decimal('10.02'),
#   'In stock',
#   3,
#   17),
#  (669,
#   'The Purpose Driven Life: What on Earth Am I Here for?',
#   'http://books.toscrape.com/catalogue/the-purpose-driven-life-what-on-earth-am-i-here-for_272/index.html',
#   Decimal('37.19'),
#   'In stock',
#   3,
#   17),
#  (672,
#   'The End of Faith: Religion, Terror, and the Future of Reason',
#   'http://books.toscrape.com/catalogue/the-end-of-faith-religion-terror-and-the-future-of-reason_246/index.html',
#   Decimal('22.13'),
#   'In stock',
#   4,
#   17),
#  (681,
#   'Fire Bound (Sea Haven/Sisters of the Heart #5)',
#   'http://books.toscrape.com/catalogue/fire-bound-sea-havensisters-of-the-heart-5_157/index.html',
#   Decimal('21.28'),
#   'In stock',
#   4,
#   17),
#  (684,
#   'The Sense of an Ending',
#   'http://books.toscrape.com/catalogue/the-sense-of-an-ending_111/index.html',
#   Decimal('31.38'),
#   'In stock',
#   3,
#   17),
#  (685,
#   'The Republic',
#   'http://books.toscrape.com/catalogue/the-republic_78/index.html',
#   Decimal('33.78'),
#   'In stock',
#   3,
#   17),
#  (686,
#   'The Odyssey',
#   'http://books.toscrape.com/catalogue/the-odyssey_77/index.html',
#   Decimal('29.64'),
#   'In stock',
#   3,
#   17),
#  (688,
#   'The Iliad',
#   'http://books.toscrape.com/catalogue/the-iliad_69/index.html',
#   Decimal('16.16'),
#   'In stock',
#   3,
#   17),
#  (689,
#   'The Communist Manifesto',
#   'http://books.toscrape.com/catalogue/the-communist-manifesto_61/index.html',
#   Decimal('14.76'),
#   'In stock',
#   3,
#   17),
#  (690,
#   'Lord of the Flies',
#   'http://books.toscrape.com/catalogue/lord-of-the-flies_30/index.html',
#   Decimal('24.89'),
#   'In stock',
#   3,
#   17),
#  (691,
#   'Unicorn Tracks',
#   'http://books.toscrape.com/catalogue/unicorn-tracks_951/index.html',
#   Decimal('18.78'),
#   'In stock',
#   3,
#   18),
#  (692,
#   'Saga, Volume 6 (Saga (Collected Editions) #6)',
#   'http://books.toscrape.com/catalogue/saga-volume-6-saga-collected-editions-6_924/index.html',
#   Decimal('25.02'),
#   'In stock',
#   3,
#   18),
#  (693,
#   'Princess Between Worlds (Wide-Awake Princess #5)',
#   'http://books.toscrape.com/catalogue/princess-between-worlds-wide-awake-princess-5_919/index.html',
#   Decimal('13.34'),
#   'In stock',
#   3,
#   18),
#  (698,
#   'Throne of Glass (Throne of Glass #1)',
#   'http://books.toscrape.com/catalogue/throne-of-glass-throne-of-glass-1_868/index.html',
#   Decimal('35.07'),
#   'In stock',
#   3,
#   18),
#  (711,
#   'Every Heart a Doorway (Every Heart A Doorway #1)',
#   'http://books.toscrape.com/catalogue/every-heart-a-doorway-every-heart-a-doorway-1_465/index.html',
#   Decimal('12.16'),
#   'In stock',
#   3,
#   18),
#  (716,
# ...
#   Decimal('14.36'),
#   'In stock',
#   3,
#   20),
#  (763,
#   'The Epidemic (The Program 0.6)',
#   'http://books.toscrape.com/catalogue/the-epidemic-the-program-06_636/index.html',
#   Decimal('14.44'),
#   'In stock',
#   3,
#   20),
#  (776,
#   'Two Summers',
#   'http://books.toscrape.com/catalogue/two-summers_415/index.html',
#   Decimal('14.64'),
#   'In stock',
#   3,
#   20),
#  (777,
#   'The Darkest Corners',
#   'http://books.toscrape.com/catalogue/the-darkest-corners_399/index.html',
#   Decimal('11.33'),
#   'In stock',
#   3,
#   20),
#  (779,
#   'Lola and the Boy Next Door (Anna and the French Kiss #2)',
#   'http://books.toscrape.com/catalogue/lola-and-the-boy-next-door-anna-and-the-french-kiss-2_385/index.html',
#   Decimal('23.63'),
#   'In stock',
#   4,
#   20),
#  (780,
#   'Kill the Boy Band',
#   'http://books.toscrape.com/catalogue/kill-the-boy-band_381/index.html',
#   Decimal('15.52'),
#   'In stock',
#   3,
#   20),
#  (782,
#   'An Abundance of Katherines',
#   'http://books.toscrape.com/catalogue/an-abundance-of-katherines_362/index.html',
#   Decimal('10.00'),
#   'In stock',
#   3,
#   20),
#  (783,
#   'Harry Potter and the Prisoner of Azkaban (Harry Potter #3)',
#   'http://books.toscrape.com/catalogue/harry-potter-and-the-prisoner-of-azkaban-harry-potter-3_328/index.html',
#   Decimal('24.17'),
#   'In stock',
#   4,
#   20),
#  (784,
#   'Walk the Edge (Thunder Road #2)',
#   'http://books.toscrape.com/catalogue/walk-the-edge-thunder-road-2_300/index.html',
#   Decimal('32.36'),
#   'In stock',
#   3,
#   20),
#  (787,
#   'The Land of 10,000 Madonnas',
#   'http://books.toscrape.com/catalogue/the-land-of-10000-madonnas_258/index.html',
#   Decimal('29.64'),
#   'In stock',
#   4,
#   20),
#  (788,
#   'Scarlet (The Lunar Chronicles #2)',
#   'http://books.toscrape.com/catalogue/scarlet-the-lunar-chronicles-2_218/index.html',
#   Decimal('14.57'),
#   'In stock',
#   3,
#   20),
#  (793,
#   'Boy Meets Boy',
#   'http://books.toscrape.com/catalogue/boy-meets-boy_134/index.html',
#   Decimal('21.12'),
#   'In stock',
#   3,
#   20),
#  (795,
#   'New Moon (Twilight #2)',
#   'http://books.toscrape.com/catalogue/new-moon-twilight-2_105/index.html',
#   Decimal('12.86'),
#   'In stock',
#   3,
#   20),
#  (805,
#   'The Origin of Species',
#   'http://books.toscrape.com/catalogue/the-origin-of-species_499/index.html',
#   Decimal('10.01'),
#   'In stock',
#   3,
#   21),
#  (806,
#   'The Grand Design',
#   'http://books.toscrape.com/catalogue/the-grand-design_405/index.html',
#   Decimal('13.76'),
#   'In stock',
#   3,
#   21),
#  (807,
#   'Peak: Secrets from the New Science of Expertise',
#   'http://books.toscrape.com/catalogue/peak-secrets-from-the-new-science-of-expertise_389/index.html',
#   Decimal('16.28'),
#   'In stock',
#   3,
#   21),
#  (808,
#   'The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory',
#   'http://books.toscrape.com/catalogue/the-elegant-universe-superstrings-hidden-dimensions-and-the-quest-for-the-ultimate-theory_245/index.html',
#   Decimal('13.03'),
#   'In stock',
#   3,
#   21),
#  (811,
#   'Seven Brief Lessons on Physics',
#   'http://books.toscrape.com/catalogue/seven-brief-lessons-on-physics_219/index.html',
#   Decimal('30.60'),
#   'In stock',
#   4,
#   21),
#  (815,
#   "Shakespeare's Sonnets",
#   'http://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html',
#   Decimal('20.66'),
#   'In stock',
#   4,
#   22),
#  (819,
#   'Untitled Collection: Sabbath Poems 2014',
#   'http://books.toscrape.com/catalogue/untitled-collection-sabbath-poems-2014_953/index.html',
#   Decimal('14.27'),
#   'In stock',
#   3,
#   22),
#  (820,
#   'Poems That Make Grown Women Cry',
#   'http://books.toscrape.com/catalogue/poems-that-make-grown-women-cry_824/index.html',
#   Decimal('14.19'),
#   'In stock',
#   3,
#   22),
#  (828,
#   'The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#   'http://books.toscrape.com/catalogue/the-collected-poems-of-wb-yeats-the-collected-works-of-wb-yeats-1_441/index.html',
#   Decimal('15.42'),
#   'In stock',
#   3,
#   22),
#  (829,
#   'The Crossover',
#   'http://books.toscrape.com/catalogue/the-crossover_398/index.html',
#   Decimal('38.77'),
#   'In stock',
#   4,
#   22),
#  (830,
#   'Booked',
#   'http://books.toscrape.com/catalogue/booked_365/index.html',
#   Decimal('17.49'),
#   'In stock',
#   3,
#   22),
#  (831,
#   'Twenty Love Poems and a Song of Despair',
#   'http://books.toscrape.com/catalogue/twenty-love-poems-and-a-song-of-despair_91/index.html',
#   Decimal('30.95'),
#   'In stock',
#   4,
#   22),
#  (832,
#   'Vampire Knight, Vol. 1 (Vampire Knight #1)',
#   'http://books.toscrape.com/catalogue/vampire-knight-vol-1-vampire-knight-1_93/index.html',
#   Decimal('15.40'),
#   'In stock',
#   3,
#   23),
#  (837,
#   'History of Beauty',
#   'http://books.toscrape.com/catalogue/history-of-beauty_521/index.html',
#   Decimal('10.29'),
#   'In stock',
#   3,
#   24),
#  (841,
#   'The Lucifer Effect: Understanding How Good People Turn Evil',
#   'http://books.toscrape.com/catalogue/the-lucifer-effect-understanding-how-good-people-turn-evil_758/index.html',
#   Decimal('10.40'),
#   'In stock',
#   3,
#   25),
#  (844,
#   'An Unquiet Mind: A Memoir of Moods and Madness',
#   'http://books.toscrape.com/catalogue/an-unquiet-mind-a-memoir-of-moods-and-madness_422/index.html',
#   Decimal('21.30'),
#   'In stock',
#   3,
#   25),
#  (848,
#   'The Argonauts',
#   'http://books.toscrape.com/catalogue/the-argonauts_837/index.html',
#   Decimal('10.93'),
#   'In stock',
#   3,
#   26),
#  (852,
#   'Running with Scissors',
#   'http://books.toscrape.com/catalogue/running-with-scissors_215/index.html',
#   Decimal('12.91'),
#   'In stock',
#   3,
#   26),
#  (854,
#   'Lust & Wonder',
#   'http://books.toscrape.com/catalogue/lust-wonder_191/index.html',
#   Decimal('11.87'),
#   'In stock',
#   3,
#   26),
#  (858,
#   'Fifty Shades Freed (Fifty Shades #3)',
#   'http://books.toscrape.com/catalogue/fifty-shades-freed-fifty-shades-3_156/index.html',
#   Decimal('15.36'),
#   'In stock',
#   3,
#   28),
#  (860,
#   'Old School (Diary of a Wimpy Kid #10)',
#   'http://books.toscrape.com/catalogue/old-school-diary-of-a-wimpy-kid-10_723/index.html',
#   Decimal('11.83'),
#   'In stock',
#   3,
#   29),
#  (861,
#   "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#   'http://books.toscrape.com/catalogue/i-know-what-im-doing-and-other-lies-i-tell-myself-dispatches-from-a-life-under-construction_704/index.html',
#   Decimal('25.98'),
#   'In stock',
#   4,
#   29),
#  (862,
#   'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   'http://books.toscrape.com/catalogue/hyperbole-and-a-half-unfortunate-situations-flawed-coping-mechanisms-mayhem-and-other-things-that-happened_702/index.html',
#   Decimal('14.75'),
#   'In stock',
#   3,
#   29),
#  (866,
#   'Naked',
#   'http://books.toscrape.com/catalogue/naked_197/index.html',
#   Decimal('31.69'),
#   'In stock',
#   3,
#   29),
#  (872,
#   'Pet Sematary',
#   'http://books.toscrape.com/catalogue/pet-sematary_726/index.html',
#   Decimal('10.56'),
#   'In stock',
#   3,
#   30),
#  (876,
#   'Red Dragon (Hannibal Lecter #1)',
#   'http://books.toscrape.com/catalogue/red-dragon-hannibal-lecter-1_390/index.html',
#   Decimal('23.37'),
#   'In stock',
#   3,
#   30),
#  (878,
#   'Night Shift (Night Shift #1-20)',
#   'http://books.toscrape.com/catalogue/night-shift-night-shift-1-20_335/index.html',
#   Decimal('12.75'),
#   'In stock',
#   3,
#   30),
#  (881,
#   'It',
#   'http://books.toscrape.com/catalogue/it_330/index.html',
#   Decimal('25.01'),
#   'In stock',
#   3,
#   30),
#  (888,
#   'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   'http://books.toscrape.com/catalogue/the-age-of-genius-the-seventeenth-century-and-the-birth-of-the-modern-mind_929/index.html',
#   Decimal('19.73'),
#   'In stock',
#   3,
#   31),
#  (891,
#   'Zealot: The Life and Times of Jesus of Nazareth',
#   'http://books.toscrape.com/catalogue/zealot-the-life-and-times-of-jesus-of-nazareth_785/index.html',
#   Decimal('24.70'),
#   'In stock',
#   3,
#   31),
#  (892,
#   'A Distant Mirror: The Calamitous 14th Century',
#   'http://books.toscrape.com/catalogue/a-distant-mirror-the-calamitous-14th-century_652/index.html',
#   Decimal('14.58'),
#   'In stock',
#   3,
#   31),
#  (893,
#   '1491: New Revelations of the Americas Before Columbus',
#   'http://books.toscrape.com/catalogue/1491-new-revelations-of-the-americas-before-columbus_650/index.html',
#   Decimal('21.80'),
#   'In stock',
#   3,
#   31),
#  (894,
#   'Brilliant Beacons: A History of the American Lighthouse',
#   'http://books.toscrape.com/catalogue/brilliant-beacons-a-history-of-the-american-lighthouse_515/index.html',
#   Decimal('11.45'),
#   'In stock',
#   3,
#   31),
#  (902,
#   'The Guns of August',
#   'http://books.toscrape.com/catalogue/the-guns-of-august_254/index.html',
#   Decimal('14.54'),
#   'In stock',
#   3,
#   31),
#  (904,
#   'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#   'http://books.toscrape.com/catalogue/foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html',
#   Decimal('30.52'),
#   'In stock',
#   3,
#   32),
#  (907,
#   'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   'http://books.toscrape.com/catalogue/mama-tried-traditional-italian-cooking-for-the-screwed-crude-vegan-and-tattooed_908/index.html',
#   Decimal('14.02'),
#   'In stock',
#   3,
#   32),
#  (913,
#   'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',
#   'http://books.toscrape.com/catalogue/the-help-yourself-cookbook-for-kids-60-easy-plant-based-recipes-kids-can-make-to-stay-healthy-and-save-the-earth_751/index.html',
#   Decimal('28.77'),
#   'In stock',
#   3,
#   32),
#  (914,
#   "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",
#   'http://books.toscrape.com/catalogue/its-all-easy-healthy-delicious-weeknight-meals-in-under-30-minutes_706/index.html',
#   Decimal('19.55'),
#   'In stock',
#   3,
#   32),
#  (917,
#   'My Kitchen Year: 136 Recipes That Saved My Life',
#   'http://books.toscrape.com/catalogue/my-kitchen-year-136-recipes-that-saved-my-life_646/index.html',
#   Decimal('11.53'),
#   'In stock',
#   3,
#   32),
#  (920,
#   'Cravings: Recipes for What You Want to Eat',
#   'http://books.toscrape.com/catalogue/cravings-recipes-for-what-you-want-to-eat_589/index.html',
#   Decimal('20.50'),
#   'In stock',
#   3,
#   32),
#  (921,
#   'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   'http://books.toscrape.com/catalogue/the-moosewood-cookbook-recipes-from-moosewood-restaurant-ithaca-new-york_574/index.html',
#   Decimal('12.34'),
#   'In stock',
#   3,
#   32),
#  (923,
#   'Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   'http://books.toscrape.com/catalogue/naturally-lean-125-nourishing-gluten-free-plant-based-recipes-all-under-300-calories_479/index.html',
#   Decimal('11.38'),
#   'In stock',
#   3,
#   32),
#  (927,
#   'Better Homes and Gardens New Cook Book',
#   'http://books.toscrape.com/catalogue/better-homes-and-gardens-new-cook-book_423/index.html',
#   Decimal('39.61'),
#   'In stock',
#   3,
#   32),
#  (928,
#   'The Power Greens Cookbook: 140 Delicious Superfood Recipes',
#   'http://books.toscrape.com/catalogue/the-power-greens-cookbook-140-delicious-superfood-recipes_410/index.html',
#   Decimal('11.05'),
#   'In stock',
#   3,
#   32),
#  (930,
#   'Vegan Vegetarian Omnivore: Dinner for Everyone at the Table',
#   'http://books.toscrape.com/catalogue/vegan-vegetarian-omnivore-dinner-for-everyone-at-the-table_297/index.html',
#   Decimal('13.66'),
#   'In stock',
#   3,
#   32),
#  (932,
#   'The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution',
#   'http://books.toscrape.com/catalogue/the-art-of-simple-food-notes-lessons-and-recipes-from-a-delicious-revolution_229/index.html',
#   Decimal('34.32'),
#   'In stock',
#   3,
#   32),
#  (933,
#   'Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',
#   'http://books.toscrape.com/catalogue/hungry-girl-clean-hungry-easy-all-natural-recipes-for-healthy-eating-in-the-real-world_171/index.html',
#   Decimal('33.14'),
#   'In stock',
#   3,
#   32),
#  (938,
#   'Counted With the Stars (Out from Egypt #1)',
#   'http://books.toscrape.com/catalogue/counted-with-the-stars-out-from-egypt-1_463/index.html',
#   Decimal('17.97'),
#   'In stock',
#   3,
#   33),
#  (940,
#   'The Dirty Little Secrets of Getting Your Dream Job',
#   'http://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#   Decimal('33.34'),
#   'In stock',
#   4,
#   34),
#  (941,
#   'The Third Wave: An Entrepreneur’s Vision of the Future',
#   'http://books.toscrape.com/catalogue/the-third-wave-an-entrepreneurs-vision-of-the-future_862/index.html',
#   Decimal('12.61'),
#   'In stock',
#   3,
#   34),
#  (942,
#   'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#   'http://books.toscrape.com/catalogue/the-10-entrepreneur-live-your-startup-dream-without-quitting-your-day-job_836/index.html',
#   Decimal('27.55'),
#   'In stock',
#   3,
#   34),
#  (946,
#   'The Art of Startup Fundraising',
#   'http://books.toscrape.com/catalogue/the-art-of-startup-fundraising_606/index.html',
#   Decimal('21.00'),
#   'In stock',
#   3,
#   34),
#  (950,
#   "The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses",
#   'http://books.toscrape.com/catalogue/the-lean-startup-how-todays-entrepreneurs-use-continuous-innovation-to-create-radically-successful-businesses_260/index.html',
#   Decimal('33.92'),
#   'In stock',
#   3,
#   34),
#  (952,
#   'Louisa: The Extraordinary Life of Mrs. Adams',
#   'http://books.toscrape.com/catalogue/louisa-the-extraordinary-life-of-mrs-adams_818/index.html',
#   Decimal('16.85'),
#   'In stock',
#   3,
#   35),
#  (957,
#   'In Her Wake',
#   'http://books.toscrape.com/catalogue/in-her-wake_980/index.html',
#   Decimal('12.84'),
#   'In stock',
#   3,
#   36),
#  (961,
#   'The Guilty (Will Robie #4)',
#   'http://books.toscrape.com/catalogue/the-guilty-will-robie-4_750/index.html',
#   Decimal('13.82'),
#   'In stock',
#   3,
#   36),
#  (963,
#   'Give It Back',
#   'http://books.toscrape.com/catalogue/give-it-back_430/index.html',
#   Decimal('18.32'),
#   'In stock',
#   3,
#   36),
#  (964,
#   'Killing Floor (Jack Reacher #1)',
#   'http://books.toscrape.com/catalogue/killing-floor-jack-reacher-1_382/index.html',
#   Decimal('31.49'),
#   'In stock',
#   4,
#   36),
#  (967,
#   'The Travelers',
#   'http://books.toscrape.com/catalogue/the-travelers_285/index.html',
#   Decimal('15.77'),
#   'In stock',
#   3,
#   36),
#  (971,
#   'The Four Agreements: A Practical Guide to Personal Freedom',
#   'http://books.toscrape.com/catalogue/the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html',
#   Decimal('17.66'),
#   'In stock',
#   3,
#   38),
#  (977,
#   'Logan Kade (Fallen Crest High #5.5)',
#   'http://books.toscrape.com/catalogue/logan-kade-fallen-crest-high-55_384/index.html',
#   Decimal('13.12'),
#   'In stock',
#   3,
#   39),
#  (981,
#   'You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#   'http://books.toscrape.com/catalogue/you-are-a-badass-how-to-stop-doubting-your-greatness-and-start-living-an-awesome-life_508/index.html',
#   Decimal('12.08'),
#   'In stock',
#   3,
#   40),
#  (984,
#   'The Girl You Left Behind (The Girl You Left Behind #1)',
#   'http://books.toscrape.com/catalogue/the-girl-you-left-behind-the-girl-you-left-behind-1_443/index.html',
#   Decimal('15.79'),
#   'In stock',
#   3,
#   41),
#  (999,
#   'Dark Notes',
#   'http://books.toscrape.com/catalogue/dark-notes_800/index.html',
#   Decimal('19.19'),
#   'In stock',
#   3,
#   49),
#  (1000,
#   'The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   'http://books.toscrape.com/catalogue/the-long-shadow-of-small-ghosts-murder-and-memory-in-an-american-city_848/index.html',
#   Decimal('10.97'),
#   'In stock',
#   3,
#   50),
#  (1002, 'Guns, Germs, and Steel', '#', Decimal('39.50'), 'In stock', 4, 54),
#  (1003, 'The Silk Roads', '#', Decimal('35.00'), 'In stock', 4, 54),
#  (1004, 'The Wright Brothers', '#', Decimal('28.90'), 'In stock', 3, 54)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#      book_id                                              title  \
# 0          5                               Under the Tuscan Sun
# 1         10          Neither Here nor There: Travels in Europe
# 2         13                               In a Dark, Dark Wood
# 3         15                                   A Murder in Time
# 4         18             That Darkness (Gardiner and Renner #1)
# ..       ...                                                ...
# 338      999                                         Dark Notes
# 339     1000  The Long Shadow of Small Ghosts: Murder and Me...
# 340     1002                             Guns, Germs, and Steel
# 341     1003                                     The Silk Roads
# 342     1004                                The Wright Brothers
#
#                                                    url  price availability  \
# 0    http://books.toscrape.com/catalogue/under-the-...  37.33     In stock
# 1    http://books.toscrape.com/catalogue/neither-he...  38.95     In stock
# 2    http://books.toscrape.com/catalogue/in-a-dark-...  19.63     In stock
# 3    http://books.toscrape.com/catalogue/a-murder-i...  16.64     In stock
# 4    http://books.toscrape.com/catalogue/that-darkn...  13.92     In stock
# ..                                                 ...    ...          ...
# 338  http://books.toscrape.com/catalogue/dark-notes...  19.19     In stock
# 339  http://books.toscrape.com/catalogue/the-long-s...  10.97     In stock
# 340                                                  #  39.50     In stock
# 341                                                  #  35.00     In stock
# 342                                                  #  28.90     In stock
#
#      rating  category_id
# 0         3            1
# 1         3            1
# 2         3            2
# 3         3            2
# 4         3            2
# ..      ...          ...
# 338       3           49
# 339       3           50
# 340       4           54
# 341       4           54
# 342       3           54
#
# [343 rows x 7 columns]

# %% [markdown]
# #### 05) Write a sql query to get the top 5 most expensive books (order books desc with price column and then limit the result to the first 5).

# %%
qry = '''
SELECT * FROM books_catalog 
order By price DESC
LIMIT 5;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(192,
#   'The Perfect Play (Play by Play #1)',
#   'http://books.toscrape.com/catalogue/the-perfect-play-play-by-play-1_352/index.html',
#   Decimal('59.99'),
#   'In stock',
#   3,
#   7),
#  (272,
#   'Last One Home (New Beginnings #1)',
#   'http://books.toscrape.com/catalogue/last-one-home-new-beginnings-1_383/index.html',
#   Decimal('59.98'),
#   'In stock',
#   3,
#   9),
#  (926,
#   'The Barefoot Contessa Cookbook',
#   'http://books.toscrape.com/catalogue/the-barefoot-contessa-cookbook_440/index.html',
#   Decimal('59.92'),
#   'In stock',
#   5,
#   32),
#  (369,
#   'The Diary of a Young Girl',
#   'http://books.toscrape.com/catalogue/the-diary-of-a-young-girl_634/index.html',
#   Decimal('59.90'),
#   'In stock',
#   3,
#   12),
#  (965,
#   'The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)',
#   'http://books.toscrape.com/catalogue/the-bone-hunters-lexy-vaughan-steven-macaulay-2_343/index.html',
#   Decimal('59.71'),
#   'In stock',
#   3,
#   36)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    book_id                                              title  \
# 0      192                 The Perfect Play (Play by Play #1)
# 1      272                  Last One Home (New Beginnings #1)
# 2      926                     The Barefoot Contessa Cookbook
# 3      369                          The Diary of a Young Girl
# 4      965  The Bone Hunters (Lexy Vaughan & Steven Macaul...
#
#                                                  url  price availability  \
# 0  http://books.toscrape.com/catalogue/the-perfec...  59.99     In stock
# 1  http://books.toscrape.com/catalogue/last-one-h...  59.98     In stock
# 2  http://books.toscrape.com/catalogue/the-barefo...  59.92     In stock
# 3  http://books.toscrape.com/catalogue/the-diary-...  59.90     In stock
# 4  http://books.toscrape.com/catalogue/the-bone-h...  59.71     In stock
#
#    rating  category_id
# 0       3            7
# 1       3            9
# 2       5           32
# 3       3           12
# 4       3           36

# %% [markdown]
# #### 06) Write a sql query to get the 3rd 10 books in the books table order first by rate desc and then by price asc.

# %%
qry = '''
SELECT * FROM books_catalog 
order By rating DESC  ,price 
LIMIT 10 OFFSET 20;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(11,
#   '1,000 Places to See Before You Die',
#   'http://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html',
#   Decimal('26.08'),
#   'In stock',
#   5,
#   1),
#  (311,
#   'The Day the Crayons Came Home (Crayons)',
#   'http://books.toscrape.com/catalogue/the-day-the-crayons-came-home-crayons_241/index.html',
#   Decimal('26.33'),
#   'In stock',
#   5,
#   10),
#  (274,
#   'Atlas Shrugged',
#   'http://books.toscrape.com/catalogue/atlas-shrugged_314/index.html',
#   Decimal('26.58'),
#   'In stock',
#   5,
#   9),
#  (423,
#   'Gratitude',
#   'http://books.toscrape.com/catalogue/gratitude_163/index.html',
#   Decimal('26.66'),
#   'In stock',
#   5,
#   12),
#  (360,
#   'Let It Out: A Journey Through Journaling',
#   'http://books.toscrape.com/catalogue/let-it-out-a-journey-through-journaling_708/index.html',
#   Decimal('26.79'),
#   'In stock',
#   5,
#   12),
#  (236,
#   'The Time Keeper',
#   'http://books.toscrape.com/catalogue/the-time-keeper_766/index.html',
#   Decimal('27.88'),
#   'In stock',
#   5,
#   9),
#  (797,
#   'The Haters',
#   'http://books.toscrape.com/catalogue/the-haters_67/index.html',
#   Decimal('27.89'),
#   'In stock',
#   5,
#   20),
#  (630,
#   'Modern Romance',
#   'http://books.toscrape.com/catalogue/modern-romance_820/index.html',
#   Decimal('28.26'),
#   'In stock',
#   5,
#   17),
#  (57,
#   'The Passion of Dolssa',
#   'http://books.toscrape.com/catalogue/the-passion-of-dolssa_351/index.html',
#   Decimal('28.32'),
#   'In stock',
#   5,
#   3),
#  (825,
#   'Les Fleurs du Mal',
#   'http://books.toscrape.com/catalogue/les-fleurs-du-mal_530/index.html',
#   Decimal('29.04'),
#   'In stock',
#   5,
#   22)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    book_id                                     title  \
# 0       11        1,000 Places to See Before You Die
# 1      311   The Day the Crayons Came Home (Crayons)
# 2      274                            Atlas Shrugged
# 3      423                                 Gratitude
# 4      360  Let It Out: A Journey Through Journaling
# 5      236                           The Time Keeper
# 6      797                                The Haters
# 7      630                            Modern Romance
# 8       57                     The Passion of Dolssa
# 9      825                         Les Fleurs du Mal
#
#                                                  url  price availability  \
# 0  http://books.toscrape.com/catalogue/1000-place...  26.08     In stock
# 1  http://books.toscrape.com/catalogue/the-day-th...  26.33     In stock
# 2  http://books.toscrape.com/catalogue/atlas-shru...  26.58     In stock
# 3  http://books.toscrape.com/catalogue/gratitude_...  26.66     In stock
# 4  http://books.toscrape.com/catalogue/let-it-out...  26.79     In stock
# 5  http://books.toscrape.com/catalogue/the-time-k...  27.88     In stock
# 6  http://books.toscrape.com/catalogue/the-haters...  27.89     In stock
# 7  http://books.toscrape.com/catalogue/modern-rom...  28.26     In stock
# 8  http://books.toscrape.com/catalogue/the-passio...  28.32     In stock
# 9  http://books.toscrape.com/catalogue/les-fleurs...  29.04     In stock
#
#    rating  category_id
# 0       5            1
# 1       5           10
# 2       5            9
# 3       5           12
# 4       5           12
# 5       5            9
# 6       5           20
# 7       5           17
# 8       5            3
# 9       5           22

# %% [markdown]
# #### 07) Write a sql query to add a new category in categories table and add 5 books to this category in books table with title, rate and price.

# %%
qry = '''
INSERT INTO categories (category_name)
values(%s);
'''
cur.execute(qry , ('Art & Design',))

# %%
# Get the category_id of "Art & Design" First
qry = '''
SELECT category_id FROM categories WHERE category_name = 'Art & Design';
'''
cur.execute(qry)
category_id = cur.fetchone()[0]
category_id
# Out:
# 54

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    category_id
# 0           54

# %%
# Insert 5 books linked to this category
books = [
    ('Sapiens: A Brief History of Humankind', 5, 49.99),
    ('Guns, Germs, and Steel', 4, 39.50),
    ('The Silk Roads', 4, 35.00),
    ('The Wright Brothers', 3, 28.90),
    ('The History of the Ancient World', 5, 41.75)
]

qry = '''
INSERT INTO books_catalog (title, url, price, availability, rating, category_id)
VALUES (%s, %s, %s, %s, %s, %s);
'''

for title , rating , price in books:
    cur.execute(qry , (title , '#', price, 'In stock', rating, category_id))

con.commit()

# %%
qry = '''
SELECT * FROM books_catalog
WHERE category_id = '54';
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(1001,
#   'Sapiens: A Brief History of Humankind',
#   '#',
#   Decimal('49.99'),
#   'In stock',
#   5,
#   54),
#  (1002, 'Guns, Germs, and Steel', '#', Decimal('39.50'), 'In stock', 4, 54),
#  (1003, 'The Silk Roads', '#', Decimal('35.00'), 'In stock', 4, 54),
#  (1004, 'The Wright Brothers', '#', Decimal('28.90'), 'In stock', 3, 54),
#  (1005,
#   'The History of the Ancient World',
#   '#',
#   Decimal('41.75'),
#   'In stock',
#   5,
#   54)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    book_id                                  title url  price availability  \
# 0     1001  Sapiens: A Brief History of Humankind   #  49.99     In stock
# 1     1002                 Guns, Germs, and Steel   #  39.50     In stock
# 2     1003                         The Silk Roads   #  35.00     In stock
# 3     1004                    The Wright Brothers   #  28.90     In stock
# 4     1005       The History of the Ancient World   #  41.75     In stock
#
#    rating  category_id
# 0       5           54
# 1       4           54
# 2       4           54
# 3       3           54
# 4       5           54

# %% [markdown]
# #### 08) Write a sql query to update book's rate to 3 that thier price < 20£.

# %%
qry = '''
UPDATE books_catalog
SET rating = 3
WHERE price < 20;
'''
cur.execute(qry)

# %% [markdown]
# #### 09) Write a sql query to delete all books that have price > 50£ and has rate <= 2.

# %%
qry = '''
DELETE FROM books_catalog
WHERE price > 50 AND rating <=2;
'''
cur.execute(qry)
con.commit()

# %% [markdown]
# #### 10) Write a sql query to count the number of books that have 'Secret' in thier names and price between 10£ and 25£.

# %%
qry = '''
SELECT COUNT(*) AS secret_book_count
FROM books_catalog
WHERE Title LIKE "%Secret%" AND price BETWEEN 10 AND 25;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(5,)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    secret_book_count
# 0                  5

# %% [markdown]
# #### 11) Write a sql query to get the minimum & maximum price for all the books that have rate 5.

# %%
qry = '''
SELECT MIN(price) AS min_price, MAX(price) AS max_price
FROM books_catalog
WHERE rating = 5;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(Decimal('20.02'), Decimal('59.92'))]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    min_price  max_price
# 0      20.02      59.92

# %% [markdown]
# #### 12) Write a sql query to calculate the avg price for all the books that have rate 5.

# %%
qry = '''
SELECT AVG(price) AS Avg_price
FROM books_catalog
WHERE rating = 5;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(Decimal('41.111795'),)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    Avg_price
# 0  41.111795

# %% [markdown]
# #### 13) Write a sql query to sum all book's price that have rate 2 and price between 10 and 40

# %%
qry = '''
SELECT SUM(price) AS Sum_price
FROM books_catalog
WHERE rating = 2 AND price BETWEEN 10 AND 40;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(Decimal('2772.75'),)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    Sum_price
# 0    2772.75

# %% [markdown]
# #### 14) Write a sql query to join both books & categories table into one new table containing book_name & category_name & book_rate and book_price.

# %%
qry = '''
SELECT b.title AS book_name , c.category_name , b.rating AS book_rate , b.price AS book_price
FROM books_catalog AS b INNER JOIN categories AS c
ON b.category_id = c.category_id;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [('Logan Kade (Fallen Crest High #5.5)', 'Academic', 3, Decimal('13.12')),
#  ('The Torch Is Passed: A Harding Family Story',
#   'Add a comment',
#   3,
#   Decimal('19.09')),
#  ('The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   'Add a comment',
#   4,
#   Decimal('23.89')),
#  ('The Art Forger', 'Add a comment', 3, Decimal('40.76')),
#  ('On a Midnight Clear', 'Add a comment', 3, Decimal('14.07')),
#  ('Shobu Samurai, Project Aryoku (#3)', 'Add a comment', 3, Decimal('29.06')),
#  ('Modern Romance', 'Add a comment', 5, Decimal('28.26')),
#  ("The White Queen (The Cousins' War #1)",
#   'Add a comment',
#   5,
#   Decimal('25.91')),
#  ('The Song of Achilles', 'Add a comment', 5, Decimal('37.40')),
#  ('The Immortal Life of Henrietta Lacks',
#   'Add a comment',
#   2,
#   Decimal('40.67')),
#  ('The Dovekeepers', 'Add a comment', 1, Decimal('48.78')),
#  ('More Than Music (Chasing the Dream #1)',
#   'Add a comment',
#   2,
#   Decimal('37.61')),
#  ('Code Name Verity (Code Name Verity #1)',
#   'Add a comment',
#   4,
#   Decimal('22.13')),
#  ('Cell', 'Add a comment', 4, Decimal('20.29')),
#  ('Angels Walking (Angels Walking #1)', 'Add a comment', 2, Decimal('34.20')),
#  ("A People's History of the United States",
#   'Add a comment',
#   2,
#   Decimal('40.79')),
#  ('Rook', 'Add a comment', 4, Decimal('37.86')),
#  ('The Midnight Watch: A Novel of the Titanic and the Californian',
#   'Add a comment',
#   1,
#   Decimal('26.20')),
#  ('The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#   'Add a comment',
#   4,
#   Decimal('59.15')),
#  ('The Children', 'Add a comment', 3, Decimal('11.88')),
#  ('One with You (Crossfire #5)', 'Add a comment', 3, Decimal('15.71')),
#  ('Without Shame', 'Add a comment', 5, Decimal('48.27')),
#  ('Watchmen', 'Add a comment', 4, Decimal('58.05')),
#  ("A Hero's Curse (The Unseen Chronicles #1)",
#   'Add a comment',
#   3,
#   Decimal('50.49')),
#  ('23 Degrees South: A Tropical Tale of Changing Whether...',
#   'Add a comment',
#   2,
#   Decimal('35.79')),
#  ('The Glass Castle', 'Add a comment', 3, Decimal('16.24')),
#  ('The Drowning Girls', 'Add a comment', 3, Decimal('35.67')),
#  ('Team of Rivals: The Political Genius of Abraham Lincoln',
#   'Add a comment',
#   5,
#   Decimal('20.12')),
#  ('John Adams', 'Add a comment', 4, Decimal('57.43')),
#  ('Good in Bed (Cannie Shapiro #1)', 'Add a comment', 5, Decimal('37.05')),
#  ('The Joy of Cooking', 'Add a comment', 4, Decimal('43.27')),
#  ('The Golden Compass (His Dark Materials #1)',
#   'Add a comment',
#   3,
#   Decimal('18.77')),
#  ('The God Delusion', 'Add a comment', 3, Decimal('46.85')),
#  ('Pride and Prejudice', 'Add a comment', 3, Decimal('19.27')),
#  ('Mere Christianity', 'Add a comment', 3, Decimal('48.51')),
#  ('Fun Home: A Family Tragicomic', 'Add a comment', 4, Decimal('56.59')),
#  ('The Raven King (The Raven Cycle #4)', 'Add a comment', 2, Decimal('30.57')),
#  ('Find Her (Detective D.D. Warren #8)', 'Add a comment', 1, Decimal('22.37')),
#  ('Evicted: Poverty and Profit in the American City',
#   'Add a comment',
#   1,
#   Decimal('42.27')),
#  ('A Game of Thrones (A Song of Ice and Fire #1)',
#   'Add a comment',
#   2,
#   Decimal('46.42')),
#  ('A Clash of Kings (A Song of Ice and Fire #2)',
#   'Add a comment',
#   3,
#   Decimal('10.79')),
#  ('The Tipping Point: How Little Things Can Make a Big Difference',
#   'Add a comment',
#   3,
#   Decimal('10.02')),
#  ('The Rest Is Noise: Listening to the Twentieth Century',
#   'Add a comment',
#   1,
#   Decimal('34.77')),
#  ('The Purpose Driven Life: What on Earth Am I Here for?',
#   'Add a comment',
#   3,
#   Decimal('37.19')),
#  ("The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1)",
#   'Add a comment',
#   3,
#   Decimal('47.80')),
#  ('The End of Faith: Religion, Terror, and the Future of Reason',
#   'Add a comment',
#   4,
#   Decimal('22.13')),
#  ('The Complete Poems', 'Add a comment', 5, Decimal('41.32')),
#  ('The Catcher in the Rye', 'Add a comment', 1, Decimal('24.55')),
#  ('The Case for Christ (Cases for Christianity)',
#   'Add a comment',
#   1,
#   Decimal('47.84')),
#  ('The Blind Side: Evolution of a Game', 'Add a comment', 5, Decimal('53.71')),
#  ("Sarah's Key", 'Add a comment', 1, Decimal('46.29')),
#  ('Rogue Lawyer (Rogue Lawyer #1)', 'Add a comment', 3, Decimal('50.11')),
#  ('Manuscript Found in Accra', 'Add a comment', 2, Decimal('34.98')),
#  ('Fire Bound (Sea Haven/Sisters of the Heart #5)',
#   'Add a comment',
#   4,
#   Decimal('21.28')),
#  ('Cosmos', 'Add a comment', 2, Decimal('36.17')),
#  ('The Sense of an Ending', 'Add a comment', 3, Decimal('31.38')),
#  ('The Republic', 'Add a comment', 3, Decimal('33.78')),
#  ('The Odyssey', 'Add a comment', 3, Decimal('29.64')),
#  ('The Iliad', 'Add a comment', 3, Decimal('16.16')),
#  ('The Communist Manifesto', 'Add a comment', 3, Decimal('14.76')),
#  ('Lord of the Flies', 'Add a comment', 3, Decimal('24.89')),
#  ('Fifty Shades Freed (Fifty Shades #3)',
#   'Adult Fiction',
#   3,
#   Decimal('15.36')),
#  ('Wall and Piece', 'Art', 4, Decimal('44.18')),
#  ('Feathers: Displays of Brilliant Plumage', 'Art', 3, Decimal('49.05')),
#  ('Art and Fear: Observations on the Perils (and Rewards) of Artmaking',
#   'Art',
#   4,
#   Decimal('48.63')),
#  ('The New Drawing on the Right Side of the Brain',
#   'Art',
#   3,
#   Decimal('43.02')),
#  ('History of Beauty', 'Art', 3, Decimal('10.29')),
#  ('The Story of Art', 'Art', 4, Decimal('41.14')),
#  ('The Art Book', 'Art', 2, Decimal('32.34')),
#  ('Ways of Seeing', 'Art', 5, Decimal('39.51')),
#  ('Sapiens: A Brief History of Humankind',
#   'Art & Design',
#   5,
#   Decimal('49.99')),
#  ('Guns, Germs, and Steel', 'Art & Design', 4, Decimal('39.50')),
#  ('The Silk Roads', 'Art & Design', 4, Decimal('35.00')),
#  ('The Wright Brothers', 'Art & Design', 3, Decimal('28.90')),
#  ('The History of the Ancient World', 'Art & Design', 5, Decimal('41.75')),
#  ('The Argonauts', 'Autobiography', 3, Decimal('10.93')),
#  ('M Train', 'Autobiography', 1, Decimal('27.18')),
#  ('Lab Girl', 'Autobiography', 1, Decimal('40.85')),
#  ('Approval Junkie: Adventures in Caring Too Much',
#   'Autobiography',
#   5,
#   Decimal('58.81')),
#  ('Running with Scissors', 'Autobiography', 3, Decimal('12.91')),
#  ('Lust & Wonder', 'Autobiography', 3, Decimal('11.87')),
#  ('Life Without a Recipe', 'Autobiography', 5, Decimal('59.04')),
#  ('A Heartbreaking Work of Staggering Genius',
#   'Autobiography',
#   5,
#   Decimal('54.29')),
#  ('Louisa: The Extraordinary Life of Mrs. Adams',
#   'Biography',
#   3,
#   Decimal('16.85')),
#  ('Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   'Biography',
#   2,
#   Decimal('21.15')),
#  ("The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",
#   'Biography',
#   1,
#   Decimal('39.55')),
#  ('Benjamin Franklin: An American Life', 'Biography', 3, Decimal('48.19')),
#  ('The Rise of Theodore Roosevelt (Theodore Roosevelt #1)',
#   'Biography',
#   3,
#   Decimal('42.57')),
#  ('The Dirty Little Secrets of Getting Your Dream Job',
#   'Business',
#   4,
#   Decimal('33.34')),
#  ('The Third Wave: An Entrepreneur’s Vision of the Future',
#   'Business',
#   3,
#   Decimal('12.61')),
#  ('The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#   'Business',
#   3,
#   Decimal('27.55')),
#  ('Shoe Dog: A Memoir by the Creator of NIKE',
#   'Business',
#   2,
#   Decimal('23.99')),
#  ('Made to Stick: Why Some Ideas Survive and Others Die',
#   'Business',
#   5,
#   Decimal('38.85')),
#  ('Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#   'Business',
#   1,
#   Decimal('43.14')),
#  ('The Art of Startup Fundraising', 'Business', 3, Decimal('21.00')),
#  ('Born for This: How to Find the Work You Were Meant to Do',
#   'Business',
#   5,
#   Decimal('21.59')),
#  ("The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",
#   'Business',
#   1,
#   Decimal('36.91')),
#  ("The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses",
#   'Business',
#   3,
#   Decimal('33.92')),
#  ('Rework', 'Business', 2, Decimal('44.88')),
#  ('Birdsong: A Story in Pictures', 'Childrens', 3, Decimal('54.64')),
#  ('The Bear and the Piano', 'Childrens', 1, Decimal('36.89')),
#  ('The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”',
#   'Childrens',
#   4,
#   Decimal('58.08')),
#  ('Little Red', 'Childrens', 3, Decimal('13.47')),
#  ("Walt Disney's Alice in Wonderland", 'Childrens', 3, Decimal('12.96')),
#  ('Twenty Yawns', 'Childrens', 2, Decimal('22.08')),
#  ('Rain Fish', 'Childrens', 3, Decimal('23.57')),
#  ('Once Was a Time', 'Childrens', 3, Decimal('18.28')),
#  ('Luis Paints the World', 'Childrens', 3, Decimal('53.95')),
#  ('Nap-a-Roo', 'Childrens', 1, Decimal('25.08')),
#  ('The Whale', 'Childrens', 4, Decimal('35.96')),
#  ('Shrunken Treasures: Literary Classics, Short, Sweet, and Silly',
#   'Childrens',
#   3,
#   Decimal('52.87')),
#  ('Raymie Nightingale', 'Childrens', 2, Decimal('34.41')),
#  ('Playing from the Heart', 'Childrens', 1, Decimal('32.38')),
#  ('Maybe Something Beautiful: How Art Transformed a Neighborhood',
#   'Childrens',
#   1,
#   Decimal('22.54')),
#  ('The Wild Robot', 'Childrens', 3, Decimal('56.07')),
#  ('The Thing About Jellyfish', 'Childrens', 1, Decimal('48.77')),
#  ('The Lonely Ones', 'Childrens', 5, Decimal('43.59')),
#  ('The Day the Crayons Came Home (Crayons)', 'Childrens', 5, Decimal('26.33')),
#  ('The Cat in the Hat (Beginner Books B-1)', 'Childrens', 3, Decimal('16.26')),
#  ('Red: The True Story of Red Riding Hood', 'Childrens', 3, Decimal('28.54')),
#  ('Horrible Bear!', 'Childrens', 2, Decimal('37.52')),
#  ('Green Eggs and Ham (Beginner Books B-16)',
#   'Childrens',
#   3,
#   Decimal('10.79')),
#  ('Counting Thyme', 'Childrens', 3, Decimal('10.62')),
#  ('Are We There Yet?', 'Childrens', 3, Decimal('10.66')),
#  ('Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#   'Childrens',
#   4,
#   Decimal('52.88')),
#  ('Matilda', 'Childrens', 1, Decimal('28.34')),
#  ('Charlie and the Chocolate Factory (Charlie Bucket #1)',
#   'Childrens',
#   3,
#   Decimal('22.85')),
#  ('(Un)Qualified: How God Uses Broken People to Do Big Things',
#   'Christian',
#   5,
#   Decimal('54.00')),
#  ('Crazy Love: Overwhelmed by a Relentless God',
#   'Christian',
#   2,
#   Decimal('47.72')),
#  ('Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',
#   'Christian',
#   1,
#   Decimal('25.77')),
#  ('Redeeming Love', 'Christian Fiction', 5, Decimal('20.47')),
#  ('Close to You', 'Christian Fiction', 4, Decimal('49.46')),
#  ('Shadows of the Past (Logan Point #1)',
#   'Christian Fiction',
#   5,
#   Decimal('39.67')),
#  ('Like Never Before (Walker Family #2)',
#   'Christian Fiction',
#   2,
#   Decimal('28.77')),
#  ('Counted With the Stars (Out from Egypt #1)',
#   'Christian Fiction',
#   3,
#   Decimal('17.97')),
#  ('If I Run (If I Run #1)', 'Christian Fiction', 4, Decimal('49.97')),
#  ('The Secret Garden', 'Classics', 3, Decimal('15.08')),
#  ('The Metamorphosis', 'Classics', 1, Decimal('28.58')),
#  ('The Hound of the Baskervilles (Sherlock Holmes #5)',
#   'Classics',
#   3,
#   Decimal('14.82')),
#  ('Little Women (Little Women #1)', 'Classics', 4, Decimal('28.07')),
#  ('Gone with the Wind', 'Classics', 3, Decimal('32.49')),
#  ('Candide', 'Classics', 3, Decimal('58.63')),
#  ('Animal Farm', 'Classics', 3, Decimal('57.22')),
#  ('Wuthering Heights', 'Classics', 3, Decimal('17.73')),
#  ('The Picture of Dorian Gray', 'Classics', 2, Decimal('29.70')),
#  ('The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',
#   'Classics',
#   4,
#   Decimal('26.78')),
#  ('Beowulf', 'Classics', 2, Decimal('38.35')),
#  ('And Then There Were None', 'Classics', 2, Decimal('35.01')),
#  ('The Story of Hong Gildong', 'Classics', 4, Decimal('43.19')),
#  ('The Little Prince', 'Classics', 2, Decimal('45.42')),
#  ('Sense and Sensibility', 'Classics', 1, Decimal('37.46')),
#  ('Of Mice and Men', 'Classics', 2, Decimal('47.11')),
#  ('Emma', 'Classics', 2, Decimal('32.93')),
#  ('When We Collided', 'Contemporary', 1, Decimal('31.77')),
#  ('Someone Like You (The Harrisons #2)', 'Contemporary', 5, Decimal('52.79')),
#  ('We Are All Completely Beside Ourselves',
#   'Contemporary',
#   1,
#   Decimal('24.04')),
#  ('The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   'Crime',
#   3,
#   Decimal('10.97')),
#  ('Amid the Chaos', 'Cultural', 1, Decimal('36.58')),
#  ('The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'Default',
#   3,
#   Decimal('17.93')),
#  ('The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'Default',
#   4,
#   Decimal('22.60')),
#  ('Starving Hearts (Triangular Trade Trilogy, #1)',
#   'Default',
#   3,
#   Decimal('13.99')),
#  ("America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#   'Default',
#   3,
#   Decimal('22.50')),
#  ('Aladdin and His Wonderful Lamp', 'Default', 3, Decimal('53.13')),
#  ('Penny Maybe', 'Default', 3, Decimal('33.29')),
#  ('Maude (1883-1993):She Grew Up with the country',
#   'Default',
#   3,
#   Decimal('18.02')),
#  ('The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   'Default',
#   5,
#   Decimal('20.59')),
#  ('Soul Reader', 'Default', 2, Decimal('39.58')),
#  ('Bossypants', 'Default', 2, Decimal('49.46')),
#  ('A World of Flavor: Your Gluten Free Passport',
#   'Default',
#   1,
#   Decimal('42.95')),
#  ('A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#   'Default',
#   5,
#   Decimal('56.76')),
#  ('Tracing Numbers on a Train', 'Default', 3, Decimal('41.60')),
#  ('The Secret (The Secret #1)', 'Default', 4, Decimal('27.37')),
#  ('The Psychopath Test: A Journey Through the Madness Industry',
#   'Default',
#   2,
#   Decimal('36.00')),
#  ('The Kite Runner', 'Default', 4, Decimal('41.82')),
#  ('The Emerald Mystery', 'Default', 2, Decimal('23.15')),
#  ("The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#   'Default',
#   3,
#   Decimal('32.00')),
#  ('The Art of War', 'Default', 5, Decimal('33.34')),
#  ('Secrets and Lace (Fatal Hearts #1)', 'Default', 1, Decimal('20.27')),
#  ('Romero and Juliet: A Tragic Tale of Love and Zombies',
#   'Default',
#   1,
#   Decimal('36.94')),
#  ('Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#   'Default',
#   1,
#   Decimal('41.06')),
#  ('Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)',
#   'Default',
#   3,
#   Decimal('10.76')),
#  ('Large Print Heart of the Pride', 'Default', 3, Decimal('19.15')),
#  ('Grumbles', 'Default', 2, Decimal('22.16')),
#  ('First Steps for New Christians (Print Edition)',
#   'Default',
#   1,
#   Decimal('29.00')),
#  ('Eureka Trivia 6.0', 'Default', 4, Decimal('54.59')),
#  ('Drive: The Surprising Truth About What Motivates Us',
#   'Default',
#   4,
#   Decimal('34.95')),
#  ('Done Rubbed Out (Reightman & Bailey #1)', 'Default', 5, Decimal('37.72')),
#  ('Beauty Restored (Riley Family Legacy Novellas #3)',
#   'Default',
#   3,
#   Decimal('11.11')),
#  ("Ayumi's Violin", 'Default', 3, Decimal('15.48')),
#  ('Anonymous', 'Default', 4, Decimal('46.82')),
#  ('Amy Meets the Saints and Sages', 'Default', 3, Decimal('18.46')),
#  ('Amatus', 'Default', 5, Decimal('50.54')),
#  ('V for Vendetta (V for Vendetta Complete)', 'Default', 4, Decimal('37.10')),
#  ('Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#   'Default',
#   2,
#   Decimal('45.95')),
#  ('The Wright Brothers', 'Default', 4, Decimal('56.80')),
#  ('The Songs of the Gods', 'Default', 5, Decimal('44.48')),
#  ('The Power of Habit: Why We Do What We Do in Life and Business',
#   'Default',
#   3,
#   Decimal('16.88')),
#  ('Steve Jobs', 'Default', 5, Decimal('39.50')),
#  ('Luckiest Girl Alive', 'Default', 3, Decimal('49.83')),
#  ('Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',
#   'Default',
#   4,
#   Decimal('46.91')),
#  ('Lady Midnight (The Dark Artifices #1)', 'Default', 3, Decimal('16.28')),
#  ('Hush, Hush (Hush, Hush #1)', 'Default', 3, Decimal('47.02')),
#  ('Greek Mythic History', 'Default', 3, Decimal('10.23')),
#  ('Every Last Word', 'Default', 3, Decimal('46.47')),
#  ('Daily Fantasy Sports', 'Default', 1, Decimal('36.58')),
#  ('Clockwork Angel (The Infernal Devices #1)', 'Default', 1, Decimal('44.14')),
#  ('City of Fallen Angels (The Mortal Instruments #4)',
#   'Default',
#   3,
#   Decimal('11.23')),
#  ('City of Bones (The Mortal Instruments #1)', 'Default', 1, Decimal('43.28')),
#  ('City of Ashes (The Mortal Instruments #2)', 'Default', 1, Decimal('47.27')),
#  ('Carry On, Warrior: Thoughts on Life Unarmed',
#   'Default',
#   3,
#   Decimal('31.85')),
#  ('Carrie', 'Default', 2, Decimal('46.23')),
#  ('Angels & Demons (Robert Langdon #1)', 'Default', 3, Decimal('51.48')),
#  ('The Three Searches, Meaning, and the Story',
#   'Default',
#   3,
#   Decimal('13.33')),
#  ('Raspberry Pi Electronics Projects for the Evil Genius',
#   'Default',
#   4,
#   Decimal('49.67')),
#  ('How to Speak Golf: An Illustrated Guide to Links Lingo',
#   'Default',
#   5,
#   Decimal('58.32')),
#  ('Eleanor & Park', 'Default', 5, Decimal('56.51')),
#  ('Troublemaker: Surviving Hollywood and Scientology',
#   'Default',
#   2,
#   Decimal('48.39')),
#  ('Adultery', 'Default', 5, Decimal('20.88')),
#  ('Unlimited Intuition Now', 'Default', 4, Decimal('58.87')),
#  ('Underlying Notes', 'Default', 3, Decimal('11.82')),
#  ('The New Brand You: Your New Image Makes the Sale for You',
#   'Default',
#   5,
#   Decimal('44.05')),
#  ('The Flowers Lied', 'Default', 3, Decimal('16.68')),
#  ('NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   'Default',
#   3,
#   Decimal('10.41')),
#  ('Modern Day Fables', 'Default', 2, Decimal('47.44')),
#  ('The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)',
#   'Default',
#   5,
#   Decimal('43.62')),
#  ('The Martian (The Martian #1)', 'Default', 2, Decimal('41.39')),
#  ('Left Behind (Left Behind #1)', 'Default', 2, Decimal('40.72')),
#  ('John Vassos: Industrial Design for Modern Life',
#   'Default',
#   4,
#   Decimal('20.22')),
#  ("Ender's Game (The Ender Quintet #1)", 'Default', 1, Decimal('43.64')),
#  ('Death by Leisure: A Cautionary Tale', 'Default', 4, Decimal('37.51')),
#  ('Wildlife of New York: A Five-Borough Coloring Book',
#   'Default',
#   2,
#   Decimal('22.14')),
#  ("The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible",
#   'Default',
#   1,
#   Decimal('34.72')),
#  ('The Great Gatsby', 'Default', 4, Decimal('36.05')),
#  ('The Good Girl', 'Default', 3, Decimal('49.03')),
#  ('The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',
#   'Default',
#   4,
#   Decimal('33.17')),
#  ('Steal Like an Artist: 10 Things Nobody Told You About Being Creative',
#   'Default',
#   2,
#   Decimal('20.90')),
#  ('Life of Pi', 'Default', 3, Decimal('13.22')),
#  ('The Sound Of Love', 'Default', 5, Decimal('57.84')),
#  ('The Perks of Being a Wallflower', 'Default', 3, Decimal('55.02')),
#  ('The Makings of a Fatherless Child', 'Default', 2, Decimal('31.58')),
#  ('The Hobbit (Middle-Earth Universe)', 'Default', 3, Decimal('17.80')),
#  ('The Fellowship of the Ring (The Lord of the Rings #1)',
#   'Default',
#   3,
#   Decimal('10.27')),
#  ('Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman',
#   'Default',
#   3,
#   Decimal('30.60')),
#  ('Musicophilia: Tales of Music and the Brain',
#   'Default',
#   1,
#   Decimal('46.58')),
#  ('What If?: Serious Scientific Answers to Absurd Hypothetical Questions',
#   'Default',
#   4,
#   Decimal('53.68')),
#  ('The Fault in Our Stars', 'Default', 1, Decimal('47.22')),
#  ('The Dream Thieves (The Raven Cycle #2)', 'Default', 1, Decimal('34.50')),
#  ('The 5th Wave (The 5th Wave #1)', 'Default', 3, Decimal('11.83')),
#  ('Shiver (The Wolves of Mercy Falls #1)', 'Default', 3, Decimal('16.23')),
#  ('Remember Me?', 'Default', 3, Decimal('11.48')),
#  ('If I Stay (If I Stay #1)', 'Default', 5, Decimal('38.13')),
#  ("I Know Why the Caged Bird Sings (Maya Angelou's Autobiography #1)",
#   'Default',
#   2,
#   Decimal('36.55')),
#  ('Harry Potter and the Deathly Hallows (Harry Potter #7)',
#   'Default',
#   1,
#   Decimal('23.32')),
#  ('Fool Me Once', 'Default', 3, Decimal('16.96')),
#  ('Drama', 'Default', 2, Decimal('38.70')),
#  ('Blue Lily, Lily Blue (The Raven Cycle #3)', 'Default', 5, Decimal('34.13')),
#  ('Alight (The Generations Trilogy #2)', 'Default', 4, Decimal('58.59')),
#  ('Vogue Colors A to Z: A Fashion Coloring Book',
#   'Default',
#   4,
#   Decimal('52.35')),
#  ('The Shining (The Shining #1)', 'Default', 3, Decimal('27.88')),
#  ('The Hunger Games (The Hunger Games #1)', 'Default', 5, Decimal('29.85')),
#  ('Outlander (Outlander #1)', 'Default', 3, Decimal('19.67')),
#  ('Mockingjay (The Hunger Games #3)', 'Default', 4, Decimal('20.44')),
#  ("Harry Potter and the Sorcerer's Stone (Harry Potter #1)",
#   'Default',
#   3,
#   Decimal('13.90')),
#  ('Confessions of a Shopaholic (Shopaholic #1)',
#   'Default',
#   2,
#   Decimal('48.94')),
#  ('Zero History (Blue Ant #3)', 'Default', 1, Decimal('34.77')),
#  ('World War Z: An Oral History of the Zombie War',
#   'Default',
#   1,
#   Decimal('21.80')),
#  ('Wild: From Lost to Found on the Pacific Crest Trail',
#   'Default',
#   3,
#   Decimal('46.02')),
#  ("Where'd You Go, Bernadette", 'Default', 3, Decimal('18.13')),
#  ('Twilight (Twilight #1)', 'Default', 2, Decimal('41.93')),
#  ('The Paris Wife', 'Default', 3, Decimal('36.80')),
#  ('The Maze Runner (The Maze Runner #1)', 'Default', 1, Decimal('20.93')),
#  ('The Goldfinch', 'Default', 3, Decimal('43.58')),
#  ('The Giver (The Giver Quartet #1)', 'Default', 3, Decimal('12.30')),
#  ('The Girl Who Played with Fire (Millennium Trilogy #2)',
#   'Default',
#   2,
#   Decimal('22.14')),
#  ('The Demon-Haunted World: Science as a Candle in the Dark',
#   'Default',
#   4,
#   Decimal('52.25')),
#  ('The Autobiography of Malcolm X', 'Default', 2, Decimal('23.43')),
#  ('Shopaholic & Baby (Shopaholic #5)', 'Default', 2, Decimal('46.45')),
#  ("Quiet: The Power of Introverts in a World That Can't Stop Talking",
#   'Default',
#   1,
#   Decimal('43.55')),
#  ('Orange Is the New Black', 'Default', 2, Decimal('24.61')),
#  ('One for the Money (Stephanie Plum #1)', 'Default', 2, Decimal('32.87')),
#  ('Morning Star (Red Rising #3)', 'Default', 1, Decimal('29.40')),
#  ('Life After Life', 'Default', 2, Decimal('26.13')),
#  ('Lean In: Women, Work, and the Will to Lead',
#   'Default',
#   1,
#   Decimal('25.02')),
#  ('Is Everyone Hanging Out Without Me? (And Other Concerns)',
#   'Default',
#   3,
#   Decimal('20.11')),
#  ('Gone Girl', 'Default', 5, Decimal('37.60')),
#  ('Fellside', 'Default', 1, Decimal('38.62')),
#  ('Eclipse (Twilight #3)', 'Default', 3, Decimal('18.74')),
#  ('Dracula', 'Default', 3, Decimal('52.62')),
#  ('Dead Wake: The Last Crossing of the Lusitania',
#   'Default',
#   5,
#   Decimal('39.24')),
#  ('David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',
#   'Default',
#   3,
#   Decimal('17.81')),
#  ('Dark Places', 'Default', 5, Decimal('23.90')),
#  ('Breaking Dawn (Twilight #4)', 'Default', 5, Decimal('35.28')),
#  ('Beautiful Creatures (Caster Chronicles #1)',
#   'Default',
#   5,
#   Decimal('21.55')),
#  ('A Visit from the Goon Squad', 'Default', 3, Decimal('14.08')),
#  ('The Zombie Room', 'Default', 3, Decimal('19.69')),
#  ('The Name of the Wind (The Kingkiller Chronicle #1)',
#   'Default',
#   3,
#   Decimal('50.59')),
#  ('Taking Shots (Assassins #1)', 'Default', 3, Decimal('18.88')),
#  ('Shatter Me (Shatter Me #1)', 'Default', 1, Decimal('42.40')),
#  ('Paradise Lost (Paradise #1)', 'Default', 1, Decimal('24.96')),
#  ('On the Road (Duluoz Legend)', 'Default', 3, Decimal('32.36')),
#  ('Jane Eyre', 'Default', 5, Decimal('38.43')),
#  ('Frankenstein', 'Default', 2, Decimal('38.00')),
#  ('Dark Notes', 'Erotica', 3, Decimal('19.19')),
#  ('Unicorn Tracks', 'Fantasy', 3, Decimal('18.78')),
#  ('Saga, Volume 6 (Saga (Collected Editions) #6)',
#   'Fantasy',
#   3,
#   Decimal('25.02')),
#  ('Princess Between Worlds (Wide-Awake Princess #5)',
#   'Fantasy',
#   3,
#   Decimal('13.34')),
#  ('Crown of Midnight (Throne of Glass #2)', 'Fantasy', 3, Decimal('43.29')),
#  ('Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#   'Fantasy',
#   2,
#   Decimal('28.09')),
#  ('Throne of Glass (Throne of Glass #1)', 'Fantasy', 3, Decimal('35.07')),
#  ('The Glittering Court (The Glittering Court #1)',
#   'Fantasy',
#   1,
#   Decimal('44.28')),
#  ('Hollow City (Miss Peregrine’s Peculiar Children #2)',
#   'Fantasy',
#   1,
#   Decimal('42.98')),
#  ('The Star-Touched Queen', 'Fantasy', 5, Decimal('46.02')),
#  ('The Bane Chronicles (The Bane Chronicles #1-11)',
#   'Fantasy',
#   4,
#   Decimal('44.73')),
#  ('Island of Dragons (Unwanteds #7)', 'Fantasy', 1, Decimal('29.65')),
#  ('Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',
#   'Fantasy',
#   5,
#   Decimal('37.51')),
#  ('City of Glass (The Mortal Instruments #3)', 'Fantasy', 4, Decimal('56.02')),
#  ('Searching for Meaning in Gailana', 'Fantasy', 1, Decimal('38.73')),
#  ('The Star-Touched Queen', 'Fantasy', 5, Decimal('32.30')),
#  ('A Shard of Ice (The Black Symphony Saga #1)',
#   'Fantasy',
#   3,
#   Decimal('56.63')),
#  ("King's Folly (The Kinsman Chronicles #1)", 'Fantasy', 5, Decimal('39.61')),
#  ('Every Heart a Doorway (Every Heart A Doorway #1)',
#   'Fantasy',
#   3,
#   Decimal('12.16')),
#  ('A Gathering of Shadows (Shades of Magic #2)',
#   'Fantasy',
#   4,
#   Decimal('44.81')),
#  ('The Raven Boys (The Raven Cycle #1)', 'Fantasy', 4, Decimal('57.74')),
#  ('The False Prince (The Ascendance Trilogy #1)',
#   'Fantasy',
#   5,
#   Decimal('56.00')),
#  ('Tell the Wind and Fire', 'Fantasy', 3, Decimal('45.51')),
#  ('A Feast for Crows (A Song of Ice and Fire #4)',
#   'Fantasy',
#   3,
#   Decimal('17.21')),
#  ('The Beast (Black Dagger Brotherhood #14)', 'Fantasy', 5, Decimal('46.08')),
#  ('Paper and Fire (The Great Library #2)', 'Fantasy', 5, Decimal('49.45')),
#  ('Harry Potter and the Order of the Phoenix (Harry Potter #5)',
#   'Fantasy',
#   4,
#   Decimal('31.63')),
#  ('Harry Potter and the Half-Blood Prince (Harry Potter #6)',
#   'Fantasy',
#   5,
#   Decimal('48.75')),
#  ('Harry Potter and the Chamber of Secrets (Harry Potter #2)',
#   'Fantasy',
#   3,
#   Decimal('14.74')),
#  ('The Rose & the Dagger (The Wrath and the Dawn #2)',
#   'Fantasy',
#   4,
#   Decimal('58.64')),
#  ('Soldier (Talon #3)', 'Fantasy', 2, Decimal('24.72')),
#  ('Heir to the Sky', 'Fantasy', 4, Decimal('44.07')),
#  ('Eragon (The Inheritance Cycle #1)', 'Fantasy', 3, Decimal('43.87')),
#  ('Ash', 'Fantasy', 4, Decimal('22.06')),
#  ('A Storm of Swords (A Song of Ice and Fire #3)',
#   'Fantasy',
#   2,
#   Decimal('31.22')),
#  ('The Silent Twin (Detective Jennifer Knight #3)',
#   'Fantasy',
#   3,
#   Decimal('36.25')),
#  ('The Mirror & the Maze (The Wrath and the Dawn #1.5)',
#   'Fantasy',
#   1,
#   Decimal('29.38')),
#  ('Sister Sable (The Mad Queen #1)', 'Fantasy', 3, Decimal('13.33')),
#  ('Shadow Rites (Jane Yellowrock #10)', 'Fantasy', 4, Decimal('21.72')),
#  ('Origins (Alphas 0.5)', 'Fantasy', 1, Decimal('28.99')),
#  ('Myriad (Prentor #1)', 'Fantasy', 4, Decimal('58.75')),
#  ('Private Paris (Private #10)', 'Fiction', 5, Decimal('47.61')),
#  ('We Love You, Charlie Freeman', 'Fiction', 5, Decimal('50.27')),
#  ('Thirst', 'Fiction', 3, Decimal('17.27')),
#  ('The Murder That Never Was (Forensic Instincts #5)',
#   'Fiction',
#   3,
#   Decimal('54.11')),
#  ('Tuesday Nights in 1980', 'Fiction', 2, Decimal('21.04')),
#  ('The Vacationers', 'Fiction', 4, Decimal('42.15')),
#  ('The Regional Office Is Under Attack!', 'Fiction', 5, Decimal('51.36')),
#  ('Finders Keepers (Bill Hodges Trilogy #2)', 'Fiction', 5, Decimal('53.53')),
#  ('The Time Keeper', 'Fiction', 5, Decimal('27.88')),
#  ('The Testament of Mary', 'Fiction', 4, Decimal('52.67')),
#  ('The First Hostage (J.B. Collins #2)', 'Fiction', 3, Decimal('25.85')),
#  ('Take Me with You', 'Fiction', 3, Decimal('45.21')),
#  ('Still Life with Bread Crumbs', 'Fiction', 3, Decimal('26.41')),
#  ('Shtum', 'Fiction', 4, Decimal('55.84')),
#  ('My Name Is Lucy Barton', 'Fiction', 1, Decimal('41.56')),
#  ('My Mrs. Brown', 'Fiction', 3, Decimal('24.48')),
#  ('Mr. Mercedes (Bill Hodges Trilogy #1)', 'Fiction', 1, Decimal('28.90')),
#  ('I Am Pilgrim (Pilgrim #1)', 'Fiction', 3, Decimal('10.60')),
#  ('Eligible (The Austen Project #4)', 'Fiction', 3, Decimal('27.09')),
#  ('Eight Hundred Grapes', 'Fiction', 3, Decimal('14.39')),
#  ('Dear Mr. Knightley', 'Fiction', 3, Decimal('11.21')),
#  ('Cometh the Hour (The Clifton Chronicles #6)',
#   'Fiction',
#   3,
#   Decimal('25.01')),
#  ('Balloon Animals', 'Fiction', 3, Decimal('17.03')),
#  ('A Man Called Ove', 'Fiction', 1, Decimal('39.72')),
#  ('The Silent Sister (Riley MacPherson #1)', 'Fiction', 5, Decimal('46.29')),
#  ('Mothering Sunday', 'Fiction', 3, Decimal('13.34')),
#  ('Lies and Other Acts of Love', 'Fiction', 1, Decimal('45.14')),
#  ('Daredevils', 'Fiction', 3, Decimal('16.34')),
#  ('11/22/63', 'Fiction', 3, Decimal('48.48')),
#  ('The Shack', 'Fiction', 1, Decimal('28.03')),
#  ('Hystopia: A Novel', 'Fiction', 4, Decimal('21.96')),
#  ('The Bourne Identity (Jason Bourne #1)', 'Fiction', 4, Decimal('42.78')),
#  ('Sister Dear', 'Fiction', 4, Decimal('40.20')),
#  ('Memoirs of a Geisha', 'Fiction', 3, Decimal('49.67')),
#  ('Me Before You (Me Before You #1)', 'Fiction', 3, Decimal('19.02')),
#  ('Deception Point', 'Fiction', 4, Decimal('40.32')),
#  ('The Little Paris Bookshop', 'Fiction', 3, Decimal('24.73')),
#  ('The Firm', 'Fiction', 3, Decimal('45.56')),
#  ('The Expatriates', 'Fiction', 2, Decimal('44.58')),
#  ('Siddhartha', 'Fiction', 5, Decimal('34.22')),
#  ('Last One Home (New Beginnings #1)', 'Fiction', 3, Decimal('59.98')),
#  ('Digital Fortress', 'Fiction', 5, Decimal('58.00')),
#  ('Atlas Shrugged', 'Fiction', 5, Decimal('26.58')),
#  ('Three-Martini Lunch', 'Fiction', 3, Decimal('23.21')),
#  ('The Nightingale', 'Fiction', 4, Decimal('26.26')),
#  ('The Infinities', 'Fiction', 1, Decimal('27.41')),
#  ("The Husband's Secret", 'Fiction', 5, Decimal('52.51')),
#  ('The Da Vinci Code (Robert Langdon #2)', 'Fiction', 2, Decimal('22.96')),
#  ('The Art of Fielding', 'Fiction', 1, Decimal('22.10')),
#  ('Lila (Gilead #3)', 'Fiction', 3, Decimal('12.47')),
#  ('Jurassic Park (Jurassic Park #1)', 'Fiction', 1, Decimal('44.97')),
#  ('Inferno (Robert Langdon #4)', 'Fiction', 5, Decimal('41.00')),
#  ('Crazy Rich Asians (Crazy Rich Asians #1)', 'Fiction', 5, Decimal('49.13')),
#  ('Big Little Lies', 'Fiction', 1, Decimal('22.11')),
#  ('The Course of Love', 'Fiction', 3, Decimal('16.78')),
#  ("When I'm Gone", 'Fiction', 3, Decimal('51.96')),
#  ('The Silent Wife', 'Fiction', 3, Decimal('12.34')),
#  ('The Bette Davis Club', 'Fiction', 3, Decimal('30.66')),
#  ('Kitchens of the Great Midwest', 'Fiction', 5, Decimal('57.20')),
#  ('Bright Lines', 'Fiction', 5, Decimal('39.07')),
#  ('Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#   'Food and Drink',
#   3,
#   Decimal('30.52')),
#  ('My Paris Kitchen: Recipes and Stories',
#   'Food and Drink',
#   2,
#   Decimal('33.37')),
#  ('Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   'Food and Drink',
#   3,
#   Decimal('14.02')),
#  ('Layered: Baking, Building, and Styling Spectacular Cakes',
#   'Food and Drink',
#   1,
#   Decimal('40.11')),
#  ('The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#   'Food and Drink',
#   5,
#   Decimal('37.34')),
#  ('The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#   'Food and Drink',
#   2,
#   Decimal('37.60')),
#  ('The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#   'Food and Drink',
#   1,
#   Decimal('41.25')),
#  ('Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#   'Food and Drink',
#   3,
#   Decimal('42.16')),
#  ('The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',
#   'Food and Drink',
#   3,
#   Decimal('28.77')),
#  ("It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",
#   'Food and Drink',
#   3,
#   Decimal('19.55')),
#  ('Barefoot Contessa Back to Basics', 'Food and Drink', 1, Decimal('28.01')),
#  ("Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   'Food and Drink',
#   5,
#   Decimal('50.62')),
#  ('My Kitchen Year: 136 Recipes That Saved My Life',
#   'Food and Drink',
#   3,
#   Decimal('11.53')),
#  ('Everyday Italian: 125 Simple and Delicious Recipes',
#   'Food and Drink',
#   5,
#   Decimal('20.10')),
#  ('A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#   'Food and Drink',
#   1,
#   Decimal('38.77')),
#  ('Cravings: Recipes for What You Want to Eat',
#   'Food and Drink',
#   3,
#   Decimal('20.50')),
#  ('The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   'Food and Drink',
#   3,
#   Decimal('12.34')),
#  ('Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   'Food and Drink',
#   3,
#   Decimal('11.38')),
#  ('How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#   'Food and Drink',
#   4,
#   Decimal('46.01')),
#  ('How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#   'Food and Drink',
#   2,
#   Decimal('28.25')),
#  ('The Barefoot Contessa Cookbook', 'Food and Drink', 5, Decimal('59.92')),
#  ('Better Homes and Gardens New Cook Book',
#   'Food and Drink',
#   3,
#   Decimal('39.61')),
#  ('The Power Greens Cookbook: 140 Delicious Superfood Recipes',
#   'Food and Drink',
#   3,
#   Decimal('11.05')),
#  ('Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens',
#   'Food and Drink',
#   5,
#   Decimal('24.91')),
#  ('Vegan Vegetarian Omnivore: Dinner for Everyone at the Table',
#   'Food and Drink',
#   3,
#   Decimal('13.66')),
#  ('The Smitten Kitchen Cookbook', 'Food and Drink', 1, Decimal('23.59')),
#  ('The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution',
#   'Food and Drink',
#   3,
#   Decimal('34.32')),
#  ('Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',
#   'Food and Drink',
#   3,
#   Decimal('33.14')),
#  ('The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#   'Health',
#   3,
#   Decimal('49.05')),
#  ('10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#   'Health',
#   5,
#   Decimal('49.71')),
#  ('The Art and Science of Low Carbohydrate Living',
#   'Health',
#   5,
#   Decimal('52.98')),
#  ('All the Light We Cannot See', 'Historical', 5, Decimal('29.87')),
#  ('The Girl You Left Behind (The Girl You Left Behind #1)',
#   'Historical',
#   3,
#   Decimal('15.79')),
#  ('Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#   'Historical Fiction',
#   3,
#   Decimal('29.69')),
#  ('A Flight of Arrows (The Pathfinders #2)',
#   'Historical Fiction',
#   5,
#   Decimal('55.53')),
#  ('The House by the Lake', 'Historical Fiction', 1, Decimal('36.95')),
#  ('Mrs. Houdini', 'Historical Fiction', 5, Decimal('30.25')),
#  ('The Marriage of Opposites', 'Historical Fiction', 4, Decimal('28.08')),
#  ('Glory over Everything: Beyond The Kitchen House',
#   'Historical Fiction',
#   3,
#   Decimal('45.84')),
#  ('Love, Lies and Spies', 'Historical Fiction', 2, Decimal('20.55')),
#  ('A Paris Apartment', 'Historical Fiction', 4, Decimal('39.01')),
#  ('Lilac Girls', 'Historical Fiction', 3, Decimal('17.28')),
#  ('The Constant Princess (The Tudor Court #1)',
#   'Historical Fiction',
#   3,
#   Decimal('16.62')),
#  ('The Invention of Wings', 'Historical Fiction', 1, Decimal('37.34')),
#  ('World Without End (The Pillars of the Earth #2)',
#   'Historical Fiction',
#   4,
#   Decimal('32.97')),
#  ('The Passion of Dolssa', 'Historical Fiction', 5, Decimal('28.32')),
#  ('Girl With a Pearl Earring', 'Historical Fiction', 1, Decimal('26.77')),
#  ('Voyager (Outlander #3)', 'Historical Fiction', 5, Decimal('21.07')),
#  ('The Red Tent', 'Historical Fiction', 5, Decimal('35.66')),
#  ('The Guernsey Literary and Potato Peel Pie Society',
#   'Historical Fiction',
#   1,
#   Decimal('49.53')),
#  ('Girl in the Blue Coat', 'Historical Fiction', 2, Decimal('46.83')),
#  ('Between Shades of Gray', 'Historical Fiction', 5, Decimal('20.79')),
#  ('While You Were Mine', 'Historical Fiction', 5, Decimal('41.32')),
#  ('The Secret Healer', 'Historical Fiction', 3, Decimal('34.56')),
#  ('Starlark', 'Historical Fiction', 3, Decimal('25.83')),
#  ('Lost Among the Living', 'Historical Fiction', 4, Decimal('27.70')),
#  ("A Spy's Devotion (The Regency Spies of London #1)",
#   'Historical Fiction',
#   3,
#   Decimal('16.97')),
#  ('Sapiens: A Brief History of Humankind', 'History', 5, Decimal('54.23')),
#  ('Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#   'History',
#   1,
#   Decimal('25.52')),
#  ('The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   'History',
#   3,
#   Decimal('19.73')),
#  ('Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   'History',
#   2,
#   Decimal('36.28')),
#  ('Zealot: The Life and Times of Jesus of Nazareth',
#   'History',
#   3,
#   Decimal('24.70')),
#  ('A Distant Mirror: The Calamitous 14th Century',
#   'History',
#   3,
#   Decimal('14.58')),
#  ('1491: New Revelations of the Americas Before Columbus',
#   'History',
#   3,
#   Decimal('21.80')),
#  ('Brilliant Beacons: A History of the American Lighthouse',
#   'History',
#   3,
#   Decimal('11.45')),
#  ('"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',
#   'History',
#   5,
#   Decimal('44.48')),
#  ('A Short History of Nearly Everything', 'History', 5, Decimal('52.40')),
#  ('The Rise and Fall of the Third Reich: A History of Nazi Germany',
#   'History',
#   2,
#   Decimal('39.67')),
#  ('Catherine the Great: Portrait of a Woman', 'History', 4, Decimal('58.55')),
#  ("The Mathews Men: Seven Brothers and the War Against Hitler's U-boats",
#   'History',
#   5,
#   Decimal('42.91')),
#  ('The Hiding Place', 'History', 4, Decimal('55.91')),
#  ('The Guns of August', 'History', 3, Decimal('14.54')),
#  ('House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth',
#   'History',
#   2,
#   Decimal('43.70')),
#  ('Security', 'Horror', 2, Decimal('39.25')),
#  ('Follow You Home', 'Horror', 1, Decimal('21.36')),
#  ('The Loney', 'Horror', 1, Decimal('23.40')),
#  ('Pet Sematary', 'Horror', 3, Decimal('10.56')),
#  ('Doctor Sleep (The Shining #2)', 'Horror', 2, Decimal('40.12')),
#  ('Psycho: Sanitarium (Psycho #1.5)', 'Horror', 5, Decimal('36.97')),
#  ('Can You Keep a Secret? (Fear Street Relaunch #4)',
#   'Horror',
#   1,
#   Decimal('48.64')),
#  ('Red Dragon (Hannibal Lecter #1)', 'Horror', 3, Decimal('23.37')),
#  ('Dracula the Un-Dead', 'Horror', 5, Decimal('35.63')),
#  ('Night Shift (Night Shift #1-20)', 'Horror', 3, Decimal('12.75')),
#  ('Needful Things', 'Horror', 4, Decimal('47.51')),
#  ('Misery', 'Horror', 2, Decimal('34.79')),
#  ('It', 'Horror', 3, Decimal('25.01')),
#  ("'Salem's Lot", 'Horror', 4, Decimal('49.56')),
#  ('The Girl with All the Gifts', 'Horror', 3, Decimal('49.47')),
#  ('The Long Haul (Diary of a Wimpy Kid #9)', 'Humor', 1, Decimal('44.07')),
#  ('Old School (Diary of a Wimpy Kid #10)', 'Humor', 3, Decimal('11.83')),
#  ("I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#   'Humor',
#   4,
#   Decimal('25.98')),
#  ('Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   'Humor',
#   3,
#   Decimal('14.75')),
#  ('Dress Your Family in Corduroy and Denim', 'Humor', 3, Decimal('43.68')),
#  ("Toddlers Are A**holes: It's Not Your Fault", 'Humor', 1, Decimal('25.55')),
#  ('When You Are Engulfed in Flames', 'Humor', 5, Decimal('30.89')),
#  ('Naked', 'Humor', 3, Decimal('31.69')),
#  ("Lamb: The Gospel According to Biff, Christ's Childhood Pal",
#   'Humor',
#   5,
#   Decimal('55.50')),
#  ('Rip it Up and Start Again', 'Music', 5, Decimal('35.02')),
#  ('Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   'Music',
#   3,
#   Decimal('57.25')),
#  ('How Music Works', 'Music', 2, Decimal('37.32')),
#  ('Love Is a Mix Tape (Music #1)', 'Music', 3, Decimal('18.03')),
#  ('Please Kill Me: The Uncensored Oral History of Punk',
#   'Music',
#   4,
#   Decimal('31.19')),
#  ("Kill 'Em and Leave: Searching for James Brown and the American Soul",
#   'Music',
#   5,
#   Decimal('45.05')),
#  ('This Is Your Brain on Music: The Science of a Human Obsession',
#   'Music',
#   1,
#   Decimal('38.40')),
#  ('Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',
#   'Music',
#   3,
#   Decimal('12.36')),
#  ('No One Here Gets Out Alive', 'Music', 5, Decimal('20.02')),
#  ('Life', 'Music', 5, Decimal('31.58')),
#  ('Forever Rockers (The Rocker #12)', 'Music', 3, Decimal('28.80')),
#  ('Sharp Objects', 'Mystery', 4, Decimal('47.82')),
#  ('In a Dark, Dark Wood', 'Mystery', 3, Decimal('19.63')),
#  ('The Past Never Ends', 'Mystery', 4, Decimal('56.50')),
#  ('A Murder in Time', 'Mystery', 3, Decimal('16.64')),
#  ('The Murder of Roger Ackroyd (Hercule Poirot #4)',
#   'Mystery',
#   4,
#   Decimal('44.10')),
#  ('That Darkness (Gardiner and Renner #1)', 'Mystery', 3, Decimal('13.92')),
#  ('Tastes Like Fear (DI Marnie Rome #3)', 'Mystery', 3, Decimal('10.69')),
#  ('A Time of Torment (Charlie Parker #14)', 'Mystery', 5, Decimal('48.35')),
#  ('A Study in Scarlet (Sherlock Holmes #1)', 'Mystery', 3, Decimal('16.73')),
#  ('Poisonous (Max Revere Novels #3)', 'Mystery', 3, Decimal('26.80')),
#  ('Murder at the 42nd Street Library (Raymond Ambler #1)',
#   'Mystery',
#   4,
#   Decimal('54.36')),
#  ('Most Wanted', 'Mystery', 3, Decimal('35.28')),
#  ('Hide Away (Eve Duncan #20)', 'Mystery', 3, Decimal('11.84')),
#  ('Boar Island (Anna Pigeon #19)', 'Mystery', 3, Decimal('59.48')),
#  ('The Widow', 'Mystery', 2, Decimal('27.26')),
#  ('Playing with Fire', 'Mystery', 3, Decimal('13.71')),
#  ('What Happened on Beale Street (Secrets of the South Mysteries #2)',
#   'Mystery',
#   5,
#   Decimal('25.37')),
#  ("The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#   'Mystery',
#   5,
#   Decimal('52.30')),
#  ('Delivering the Truth (Quaker Midwife Mystery #1)',
#   'Mystery',
#   4,
#   Decimal('20.89')),
#  ('The Mysterious Affair at Styles (Hercule Poirot #1)',
#   'Mystery',
#   4,
#   Decimal('24.80')),
#  ('In the Woods (Dublin Murder Squad #1)', 'Mystery', 2, Decimal('38.38')),
#  ('The Silkworm (Cormoran Strike #2)', 'Mystery', 5, Decimal('23.05')),
#  ('The Exiled', 'Mystery', 3, Decimal('43.45')),
#  ("The Cuckoo's Calling (Cormoran Strike #1)", 'Mystery', 3, Decimal('19.21')),
#  ('Extreme Prey (Lucas Davenport #26)', 'Mystery', 3, Decimal('25.40')),
#  ('Career of Evil (Cormoran Strike #3)', 'Mystery', 2, Decimal('24.72')),
#  ("The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#   'Mystery',
#   4,
#   Decimal('57.70')),
#  ('The Girl You Lost', 'Mystery', 3, Decimal('12.29')),
#  ('The Girl In The Ice (DCI Erika Foster #1)', 'Mystery', 3, Decimal('15.85')),
#  ('Blood Defense (Samantha Brinkman #1)', 'Mystery', 3, Decimal('20.30')),
#  ('Without Borders (Wanderlove #1)', 'New Adult', 2, Decimal('45.07')),
#  ('The Mistake (Off-Campus #2)', 'New Adult', 3, Decimal('43.29')),
#  ('The Hook Up (Game On #1)', 'New Adult', 5, Decimal('36.29')),
#  ('Shameless', 'New Adult', 3, Decimal('58.35')),
#  ('Off Sides (Off #1)', 'New Adult', 5, Decimal('39.45')),
#  ('Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#   'Nonfiction',
#   5,
#   Decimal('40.30')),
#  ('The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#   'Nonfiction',
#   3,
#   Decimal('31.05')),
#  ('Reasons to Stay Alive', 'Nonfiction', 2, Decimal('26.41')),
#  ('#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   'Nonfiction',
#   5,
#   Decimal('23.11')),
#  ('Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   'Nonfiction',
#   4,
#   Decimal('44.18')),
#  ('Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#   'Nonfiction',
#   3,
#   Decimal('31.12')),
#  ('The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   'Nonfiction',
#   3,
#   Decimal('16.77')),
#  ('The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#   'Nonfiction',
#   1,
#   Decimal('37.13')),
#  ('Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   'Nonfiction',
#   4,
#   Decimal('41.83')),
#  ('Reskilling America: Learning to Labor in the Twenty-First Century',
#   'Nonfiction',
#   3,
#   Decimal('19.83')),
#  ('In the Country We Love: My Family Divided',
#   'Nonfiction',
#   4,
#   Decimal('22.00')),
#  ('Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#   'Nonfiction',
#   5,
#   Decimal('29.14')),
#  ('Algorithms to Live By: The Computer Science of Human Decisions',
#   'Nonfiction',
#   1,
#   Decimal('30.81')),
#  ('The Power of Now: A Guide to Spiritual Enlightenment',
#   'Nonfiction',
#   2,
#   Decimal('43.54')),
#  ("The Omnivore's Dilemma: A Natural History of Four Meals",
#   'Nonfiction',
#   2,
#   Decimal('38.21')),
#  ('The Genius of Birds', 'Nonfiction', 3, Decimal('17.24')),
#  ("The Artist's Way: A Spiritual Path to Higher Creativity",
#   'Nonfiction',
#   5,
#   Decimal('38.49')),
#  ("So You've Been Publicly Shamed", 'Nonfiction', 3, Decimal('12.23')),
#  ('Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   'Nonfiction',
#   3,
#   Decimal('19.43')),
#  ('Big Magic: Creative Living Beyond Fear', 'Nonfiction', 3, Decimal('30.80')),
#  ('Becoming Wise: An Inquiry into the Mystery and Art of Living',
#   'Nonfiction',
#   2,
#   Decimal('27.43')),
#  ('Agnostic: A Spirited Manifesto', 'Nonfiction', 3, Decimal('12.51')),
#  ('Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   'Nonfiction',
#   4,
#   Decimal('38.20')),
#  ("What's It Like in Space?: Stories from Astronauts Who've Been There",
#   'Nonfiction',
#   3,
#   Decimal('19.60')),
#  ('The Year of Magical Thinking', 'Nonfiction', 2, Decimal('43.04')),
#  ('The Literature Book (Big Ideas Simply Explained)',
#   'Nonfiction',
#   3,
#   Decimal('17.43')),
#  ('The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World’s Most Precious Manuscripts',
#   'Nonfiction',
#   3,
#   Decimal('15.77')),
#  ('Swell: A Year of Waves', 'Nonfiction', 1, Decimal('45.58')),
#  ('No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon',
#   'Nonfiction',
#   2,
#   Decimal('21.95')),
#  ('Looking for Lovely: Collecting the Moments that Matter',
#   'Nonfiction',
#   5,
#   Decimal('29.14')),
#  ('Let It Out: A Journey Through Journaling',
#   'Nonfiction',
#   5,
#   Decimal('26.79')),
#  ('Hamilton: The Revolution', 'Nonfiction', 3, Decimal('58.79')),
#  ('Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   'Nonfiction',
#   3,
#   Decimal('15.06')),
#  ('Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#   'Nonfiction',
#   5,
#   Decimal('51.75')),
#  ('Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#   'Nonfiction',
#   4,
#   Decimal('37.80')),
#  ('Brain on Fire: My Month of Madness', 'Nonfiction', 5, Decimal('49.32')),
#  ('Abstract City', 'Nonfiction', 5, Decimal('56.37')),
#  ('13 Hours: The Inside Account of What Really Happened In Benghazi',
#   'Nonfiction',
#   1,
#   Decimal('27.06')),
#  ('The Lonely City: Adventures in the Art of Being Alone',
#   'Nonfiction',
#   2,
#   Decimal('33.26')),
#  ('The Diary of a Young Girl', 'Nonfiction', 3, Decimal('59.90')),
#  ('Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#   'Nonfiction',
#   3,
#   Decimal('21.21')),
#  ('Furiously Happy: A Funny Book About Horrible Things',
#   'Nonfiction',
#   4,
#   Decimal('41.46')),
#  ('The Sleep Revolution: Transforming Your Life, One Night at a Time',
#   'Nonfiction',
#   3,
#   Decimal('11.68')),
#  ('Mother, Can You Not?', 'Nonfiction', 3, Decimal('16.89')),
#  ("A Mother's Reckoning: Living in the Aftermath of Tragedy",
#   'Nonfiction',
#   3,
#   Decimal('19.53')),
#  ('10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works',
# ...
#  ('Soft Apocalypse', 'Science Fiction', 2, Decimal('26.12')),
#  ('Sleeping Giants (Themis Files #1)', 'Science Fiction', 1, Decimal('48.74')),
#  ('Arena', 'Science Fiction', 4, Decimal('21.36')),
#  ('Foundation (Foundation (Publication Order) #1)',
#   'Science Fiction',
#   1,
#   Decimal('32.42')),
#  ("The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2)",
#   'Science Fiction',
#   3,
#   Decimal('10.92')),
#  ('Ready Player One', 'Science Fiction', 3, Decimal('19.07')),
#  ("Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)",
#   'Science Fiction',
#   2,
#   Decimal('33.26')),
#  ('Three Wishes (River of Time: California #1)',
#   'Science Fiction',
#   2,
#   Decimal('44.18')),
#  ('The Last Girl (The Dominion Trilogy #1)',
#   'Science Fiction',
#   2,
#   Decimal('36.26')),
#  ("Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",
#   'Science Fiction',
#   4,
#   Decimal('34.96')),
#  ('Online Marketing for Busy Authors: A Step-By-Step Guide',
#   'Self Help',
#   1,
#   Decimal('46.35')),
#  ('How to Be Miserable: 40 Strategies You Already Use',
#   'Self Help',
#   1,
#   Decimal('46.03')),
#  ('Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress',
#   'Self Help',
#   3,
#   Decimal('52.15')),
#  ('You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#   'Self Help',
#   3,
#   Decimal('12.08')),
#  ('How to Stop Worrying and Start Living', 'Self Help', 5, Decimal('46.49')),
#  ("Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   'Sequential Art',
#   5,
#   Decimal('52.29')),
#  ('Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   'Sequential Art',
#   3,
#   Decimal('16.28')),
#  ('This One Summer', 'Sequential Art', 3, Decimal('19.49')),
#  ('The Nameless City (The Nameless City #1)',
#   'Sequential Art',
#   4,
#   Decimal('38.16')),
#  ('Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#   'Sequential Art',
#   3,
#   Decimal('50.40')),
#  ('Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   'Sequential Art',
#   3,
#   Decimal('13.61')),
#  ('Pop Gun War, Volume 1: Gift', 'Sequential Art', 3, Decimal('18.97')),
#  ('Patience', 'Sequential Art', 3, Decimal('10.16')),
#  ('Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   'Sequential Art',
#   3,
#   Decimal('15.44')),
#  ('orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   'Sequential Art',
#   1,
#   Decimal('48.41')),
#  ('Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   'Sequential Art',
#   2,
#   Decimal('46.91')),
#  ('Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#   'Sequential Art',
#   3,
#   Decimal('45.61')),
#  ('Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   'Sequential Art',
#   3,
#   Decimal('19.92')),
#  ('I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   'Sequential Art',
#   2,
#   Decimal('29.17')),
#  ('I am a Hero Omnibus Volume 1', 'Sequential Art', 3, Decimal('54.63')),
#  ('Giant Days, Vol. 2 (Giant Days #5-8)',
#   'Sequential Art',
#   2,
#   Decimal('22.11')),
#  ('Danganronpa Volume 1', 'Sequential Art', 4, Decimal('51.99')),
#  ('Codename Baboushka, Volume 1: The Conclave of Death',
#   'Sequential Art',
#   4,
#   Decimal('36.72')),
#  ('Camp Midnight', 'Sequential Art', 3, Decimal('17.08')),
#  ('Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   'Sequential Art',
#   2,
#   Decimal('37.92')),
#  ('The Shadow Hero (The Shadow Hero)', 'Sequential Art', 1, Decimal('33.14')),
#  ('Fables, Vol. 1: Legends in Exile (Fables #1)',
#   'Sequential Art',
#   4,
#   Decimal('41.62')),
#  ('Batman: The Long Halloween (Batman)',
#   'Sequential Art',
#   2,
#   Decimal('36.50')),
#  ('Batman: The Dark Knight Returns (Batman)',
#   'Sequential Art',
#   3,
#   Decimal('15.38')),
#  ('Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   'Sequential Art',
#   4,
#   Decimal('37.34')),
#  ('Through the Woods', 'Sequential Art', 2, Decimal('25.38')),
#  ('Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#   'Sequential Art',
#   3,
#   Decimal('11.89')),
#  ('So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#   'Sequential Art',
#   4,
#   Decimal('35.43')),
#  ('Robin War', 'Sequential Art', 3, Decimal('47.82')),
#  ('Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#   'Sequential Art',
#   2,
#   Decimal('25.48')),
#  ('Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#   'Sequential Art',
#   2,
#   Decimal('38.39')),
#  ('El Deafo', 'Sequential Art', 5, Decimal('57.62')),
#  ('Batman: Europa', 'Sequential Art', 2, Decimal('32.01')),
#  ('Art Ops Vol. 1', 'Sequential Art', 3, Decimal('48.80')),
#  ('Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#   'Sequential Art',
#   3,
#   Decimal('10.90')),
#  ('Fruits Basket, Vol. 9 (Fruits Basket #9)',
#   'Sequential Art',
#   4,
#   Decimal('33.95')),
#  ('Roller Girl', 'Sequential Art', 3, Decimal('14.10')),
#  ('Fruits Basket, Vol. 7 (Fruits Basket #7)',
#   'Sequential Art',
#   3,
#   Decimal('19.57')),
#  ('Fruits Basket, Vol. 6 (Fruits Basket #6)',
#   'Sequential Art',
#   4,
#   Decimal('20.96')),
#  ('Death Note, Vol. 6: Give-and-Take (Death Note #6)',
#   'Sequential Art',
#   3,
#   Decimal('36.39')),
#  ('Fruits Basket, Vol. 5 (Fruits Basket #5)',
#   'Sequential Art',
#   3,
#   Decimal('16.33')),
#  ('The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of Momochi House #4)',
#   'Sequential Art',
#   2,
#   Decimal('27.88')),
#  ('Fruits Basket, Vol. 4 (Fruits Basket #4)',
#   'Sequential Art',
#   4,
#   Decimal('50.44')),
#  ('The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine)',
#   'Sequential Art',
#   3,
#   Decimal('14.41')),
#  ('The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)',
#   'Sequential Art',
#   5,
#   Decimal('55.55')),
#  ('Saga, Volume 3 (Saga (Collected Editions) #3)',
#   'Sequential Art',
#   5,
#   Decimal('21.57')),
#  ('Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)',
#   'Sequential Art',
#   3,
#   Decimal('43.63')),
#  ('Persepolis: The Story of a Childhood (Persepolis #1-2)',
#   'Sequential Art',
#   1,
#   Decimal('39.13')),
#  ('Original Fake', 'Sequential Art', 3, Decimal('31.45')),
#  ('Grayson, Vol 3: Nemesis (Grayson #3)',
#   'Sequential Art',
#   1,
#   Decimal('42.72')),
#  ('Fruits Basket, Vol. 3 (Fruits Basket #3)',
#   'Sequential Art',
#   2,
#   Decimal('45.17')),
#  ('Black Butler, Vol. 1 (Black Butler #1)',
#   'Sequential Art',
#   1,
#   Decimal('49.31')),
#  ('Awkward', 'Sequential Art', 2, Decimal('38.02')),
#  ('Saga, Volume 2 (Saga (Collected Editions) #2)',
#   'Sequential Art',
#   3,
#   Decimal('11.75')),
#  ('Fruits Basket, Vol. 2 (Fruits Basket #2)',
#   'Sequential Art',
#   3,
#   Decimal('11.64')),
#  ('Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#   'Sequential Art',
#   3,
#   Decimal('18.51')),
#  ('The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#   'Sequential Art',
#   2,
#   Decimal('36.52')),
#  ('The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)',
#   'Sequential Art',
#   3,
#   Decimal('54.12')),
#  ('The Complete Maus (Maus #1-2)', 'Sequential Art', 3, Decimal('10.64')),
#  ('Skip Beat!, Vol. 01 (Skip Beat! #1)',
#   'Sequential Art',
#   3,
#   Decimal('42.12')),
#  ('Saga, Volume 1 (Saga (Collected Editions) #1)',
#   'Sequential Art',
#   1,
#   Decimal('28.48')),
#  ('Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#   'Sequential Art',
#   5,
#   Decimal('46.96')),
#  ('Paper Girls, Vol. 1 (Paper Girls #1-5)',
#   'Sequential Art',
#   4,
#   Decimal('21.71')),
#  ('Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',
#   'Sequential Art',
#   3,
#   Decimal('29.87')),
#  ('Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#   'Sequential Art',
#   4,
#   Decimal('39.39')),
#  ('Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',
#   'Sequential Art',
#   3,
#   Decimal('45.24')),
#  ('Giant Days, Vol. 1 (Giant Days #1-4)',
#   'Sequential Art',
#   4,
#   Decimal('56.76')),
#  ('Fruits Basket, Vol. 1 (Fruits Basket #1)',
#   'Sequential Art',
#   5,
#   Decimal('40.28')),
#  ('Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#   'Sequential Art',
#   5,
#   Decimal('34.65')),
#  ('Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#   'Sequential Art',
#   4,
#   Decimal('57.06')),
#  ('The Grownup', 'Short Stories', 1, Decimal('35.88')),
#  ('The Four Agreements: A Practical Guide to Personal Freedom',
#   'Spirituality',
#   3,
#   Decimal('17.66')),
#  ("The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   'Spirituality',
#   5,
#   Decimal('32.24')),
#  ('Chasing Heaven: What Dying Taught Me About Living',
#   'Spirituality',
#   2,
#   Decimal('37.80')),
#  ("If I Gave You God's Phone Number....: Searching for Spirituality in America",
#   'Spirituality',
#   1,
#   Decimal('20.91')),
#  ('Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain',
#   'Spirituality',
#   2,
#   Decimal('46.33')),
#  ("A New Earth: Awakening to Your Life's Purpose",
#   'Spirituality',
#   5,
#   Decimal('55.65')),
#  ('The Book of Basketball: The NBA According to The Sports Guy',
#   'Sports and Games',
#   5,
#   Decimal('44.84')),
#  ('Friday Night Lights: A Town, a Team, and a Dream',
#   'Sports and Games',
#   3,
#   Decimal('51.22')),
#  ('Sugar Rush (Offensive Line #2)', 'Sports and Games', 1, Decimal('24.42')),
#  ('Settling the Score (The Summer Games #1)',
#   'Sports and Games',
#   2,
#   Decimal('44.91')),
#  ('Icing (Aces Hockey #2)', 'Sports and Games', 4, Decimal('40.44')),
#  ('Silence in the Dark (Logan Point #4)', 'Suspense', 3, Decimal('58.33')),
#  ('In Her Wake', 'Thriller', 3, Decimal('12.84')),
#  ('The Elephant Tree', 'Thriller', 5, Decimal('23.82')),
#  ('Behind Closed Doors', 'Thriller', 4, Decimal('52.22')),
#  ('You (You #1)', 'Thriller', 5, Decimal('43.61')),
#  ('The Guilty (Will Robie #4)', 'Thriller', 3, Decimal('13.82')),
#  ('The 14th Colony (Cotton Malone #11)', 'Thriller', 1, Decimal('39.24')),
#  ('Give It Back', 'Thriller', 3, Decimal('18.32')),
#  ('Killing Floor (Jack Reacher #1)', 'Thriller', 4, Decimal('31.49')),
#  ('The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)',
#   'Thriller',
#   3,
#   Decimal('59.71')),
#  ('Far From True (Promise Falls Trilogy #2)', 'Thriller', 2, Decimal('34.93')),
#  ('The Travelers', 'Thriller', 3, Decimal('15.77')),
#  ("It's Only the Himalayas", 'Travel', 2, Decimal('45.17')),
#  ('Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#   'Travel',
#   4,
#   Decimal('49.43')),
#  ('See America: A Celebration of Our National Parks & Treasured Sites',
#   'Travel',
#   3,
#   Decimal('48.87')),
#  ('Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   'Travel',
#   2,
#   Decimal('36.94')),
#  ('Under the Tuscan Sun', 'Travel', 3, Decimal('37.33')),
#  ('A Summer In Europe', 'Travel', 2, Decimal('44.34')),
#  ('The Great Railway Bazaar', 'Travel', 1, Decimal('30.54')),
#  ('A Year in Provence (Provence #1)', 'Travel', 4, Decimal('56.88')),
#  ('The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#   'Travel',
#   1,
#   Decimal('23.21')),
#  ('Neither Here nor There: Travels in Europe', 'Travel', 3, Decimal('38.95')),
#  ('1,000 Places to See Before You Die', 'Travel', 5, Decimal('26.08')),
#  ('I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   'Womens Fiction',
#   4,
#   Decimal('57.36')),
#  ("Will You Won't You Want Me?", 'Womens Fiction', 3, Decimal('13.86')),
#  ('Keep Me Posted', 'Womens Fiction', 4, Decimal('20.46')),
#  ('Grey (Fifty Shades #4)', 'Womens Fiction', 4, Decimal('48.49')),
#  ('Meternity', 'Womens Fiction', 3, Decimal('43.58')),
#  ('Some Women', 'Womens Fiction', 3, Decimal('13.73')),
#  ('Shopaholic Ties the Knot (Shopaholic #3)',
#   'Womens Fiction',
#   5,
#   Decimal('48.39')),
#  ('Can You Keep a Secret?', 'Womens Fiction', 1, Decimal('21.94')),
#  ('Twenties Girl', 'Womens Fiction', 2, Decimal('42.80')),
#  ('The Undomestic Goddess', 'Womens Fiction', 4, Decimal('45.75')),
#  ('The Nanny Diaries (Nanny #1)', 'Womens Fiction', 5, Decimal('52.53')),
#  ('The Devil Wears Prada (The Devil Wears Prada #1)',
#   'Womens Fiction',
#   1,
#   Decimal('44.29')),
#  ('Something Borrowed (Darcy & Rachel #1)',
#   'Womens Fiction',
#   5,
#   Decimal('48.96')),
#  ("I've Got Your Number", 'Womens Fiction', 3, Decimal('19.69')),
#  ('The Edge of Reason (Bridget Jones #2)',
#   'Womens Fiction',
#   3,
#   Decimal('19.18')),
#  ("Bridget Jones's Diary (Bridget Jones #1)",
#   'Womens Fiction',
#   1,
#   Decimal('29.82')),
#  ('The Requiem Red', 'Young Adult', 1, Decimal('22.65')),
#  ('Set Me Free', 'Young Adult', 3, Decimal('17.46')),
#  ('The Natural History of Us (The Fine Art of Pretending #2)',
#   'Young Adult',
#   3,
#   Decimal('45.22')),
#  ('Obsidian (Lux #1)', 'Young Adult', 3, Decimal('14.86')),
#  ('Burning', 'Young Adult', 3, Decimal('28.81')),
#  ('A Fierce and Subtle Poison', 'Young Adult', 4, Decimal('28.13')),
#  ('Scarlett Epstein Hates It Here', 'Young Adult', 5, Decimal('43.55')),
#  ('Nightingale, Sing', 'Young Adult', 1, Decimal('38.28')),
#  ('Library of Souls (Miss Peregrine’s Peculiar Children #3)',
#   'Young Adult',
#   5,
#   Decimal('48.56')),
#  ('Frostbite (Vampire Academy #2)', 'Young Adult', 5, Decimal('29.99')),
#  ('Wild Swans', 'Young Adult', 3, Decimal('14.36')),
#  ('Until Friday Night (The Field Party #1)',
#   'Young Adult',
#   2,
#   Decimal('46.31')),
#  ('This Is Where It Ends', 'Young Adult', 2, Decimal('27.12')),
#  ('The Darkest Lie', 'Young Adult', 5, Decimal('35.35')),
#  ('My Kind of Crazy', 'Young Adult', 1, Decimal('40.36')),
#  ('Catching Jordan (Hundred Oaks)', 'Young Adult', 3, Decimal('50.83')),
#  ('Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#   'Young Adult',
#   4,
#   Decimal('58.14')),
#  ('The Epidemic (The Program 0.6)', 'Young Adult', 3, Decimal('14.44')),
#  ('Stars Above (The Lunar Chronicles #4.5)',
#   'Young Adult',
#   2,
#   Decimal('48.05')),
#  ('No Love Allowed (Dodge Cove #1)', 'Young Adult', 4, Decimal('54.65')),
#  ('Exit, Pursued by a Bear', 'Young Adult', 4, Decimal('51.34')),
#  ("Don't Forget Steven", 'Young Adult', 1, Decimal('33.23')),
#  ('South of Sunshine', 'Young Adult', 1, Decimal('28.93')),
#  ('My Life Next Door (My Life Next Door )',
#   'Young Adult',
#   5,
#   Decimal('36.39')),
#  ('Future Shock (Future Shock #1)', 'Young Adult', 5, Decimal('55.65')),
#  ('Nightstruck: A Novel', 'Young Adult', 4, Decimal('50.35')),
#  ('Will Grayson, Will Grayson (Will Grayson, Will Grayson)',
#   'Young Adult',
#   4,
#   Decimal('47.31')),
#  ('Where She Went (If I Stay #2)', 'Young Adult', 4, Decimal('41.73')),
#  ('Two Summers', 'Young Adult', 3, Decimal('14.64')),
#  ('The Darkest Corners', 'Young Adult', 3, Decimal('11.33')),
#  ('Tell Me Three Things', 'Young Adult', 1, Decimal('41.81')),
#  ('Lola and the Boy Next Door (Anna and the French Kiss #2)',
#   'Young Adult',
#   4,
#   Decimal('23.63')),
#  ('Kill the Boy Band', 'Young Adult', 3, Decimal('15.52')),
#  ('Isla and the Happily Ever After (Anna and the French Kiss #3)',
#   'Young Adult',
#   5,
#   Decimal('48.13')),
#  ('An Abundance of Katherines', 'Young Adult', 3, Decimal('10.00')),
#  ('Harry Potter and the Prisoner of Azkaban (Harry Potter #3)',
#   'Young Adult',
#   4,
#   Decimal('24.17')),
#  ('Walk the Edge (Thunder Road #2)', 'Young Adult', 3, Decimal('32.36')),
#  ('Two Boys Kissing', 'Young Adult', 2, Decimal('32.74')),
#  ('The New Guy (and Other Senior Year Distractions)',
#   'Young Adult',
#   3,
#   Decimal('44.92')),
#  ('The Land of 10,000 Madonnas', 'Young Adult', 4, Decimal('29.64')),
#  ('Scarlet (The Lunar Chronicles #2)', 'Young Adult', 3, Decimal('14.57')),
#  ('Legend (Legend #1)', 'Young Adult', 4, Decimal('43.69')),
#  ('Lady Renegades (Rebel Belle #3)', 'Young Adult', 5, Decimal('53.04')),
#  ('Golden (Heart of Dread #3)', 'Young Adult', 4, Decimal('42.21')),
#  ('Cinder (The Lunar Chronicles #1)', 'Young Adult', 1, Decimal('26.09')),
#  ('Boy Meets Boy', 'Young Adult', 3, Decimal('21.12')),
#  ('Annie on My Mind', 'Young Adult', 5, Decimal('36.83')),
#  ('New Moon (Twilight #2)', 'Young Adult', 3, Decimal('12.86')),
#  ('The Haters', 'Young Adult', 5, Decimal('27.89')),
#  ('The Art of Not Breathing', 'Young Adult', 4, Decimal('40.83'))]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#                                              book_name  category_name  \
# 0                  Logan Kade (Fallen Crest High #5.5)       Academic
# 1          The Torch Is Passed: A Harding Family Story  Add a comment
# 2    The Mindfulness and Acceptance Workbook for An...  Add a comment
# 3                                       The Art Forger  Add a comment
# 4                                  On a Midnight Clear  Add a comment
# ..                                                 ...            ...
# 926                                      Boy Meets Boy    Young Adult
# 927                                   Annie on My Mind    Young Adult
# 928                             New Moon (Twilight #2)    Young Adult
# 929                                         The Haters    Young Adult
# 930                           The Art of Not Breathing    Young Adult
#
#      book_rate  book_price
# 0            3       13.12
# 1            3       19.09
# 2            4       23.89
# 3            3       40.76
# 4            3       14.07
# ..         ...         ...
# 926          3       21.12
# 927          5       36.83
# 928          3       12.86
# 929          5       27.89
# 930          4       40.83
#
# [931 rows x 4 columns]

# %% [markdown]
# #### 15) Write a sql query to calculate how many books each rate has and have price between 20£ and 30£.

# %%
qry = '''
SELECT COUNT(*) AS book_count , rating 
FROM books_catalog
WHERE price BETWEEN 20 AND 30
GROUP BY rating
;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(56, 1), (36, 5), (42, 3), (40, 2), (34, 4)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#    book_count  rating
# 0          56       1
# 1          36       5
# 2          42       3
# 3          40       2
# 4          34       4

# %% [markdown]
# #### 16) Write a sql query to calculate how many books each category has having count > 10.

# %%
qry = '''
SELECT c.category_name, COUNT(b.book_id) AS book_count
FROM categories AS c
INNER JOIN books_catalog AS b
ON c.category_id = b.category_id
GROUP BY c.category_name
HAVING COUNT(b.book_id) > 10;
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [('Add a comment', 60),
#  ('Business', 11),
#  ('Childrens', 28),
#  ('Classics', 17),
#  ('Default', 144),
#  ('Fantasy', 40),
#  ('Fiction', 60),
#  ('Food and Drink', 28),
#  ('Historical Fiction', 24),
#  ('History', 16),
#  ('Horror', 15),
#  ('Music', 11),
#  ('Mystery', 30),
#  ('Nonfiction', 104),
#  ('Poetry', 18),
#  ('Romance', 33),
#  ('Science', 13),
#  ('Science Fiction', 14),
#  ('Sequential Art', 70),
#  ('Thriller', 11),
#  ('Travel', 11),
#  ('Womens Fiction', 16),
#  ('Young Adult', 50)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#          category_name  book_count
# 0        Add a comment          60
# 1             Business          11
# 2            Childrens          28
# 3             Classics          17
# 4              Default         144
# 5              Fantasy          40
# 6              Fiction          60
# 7       Food and Drink          28
# 8   Historical Fiction          24
# 9              History          16
# 10              Horror          15
# 11               Music          11
# 12             Mystery          30
# 13          Nonfiction         104
# 14              Poetry          18
# 15             Romance          33
# 16             Science          13
# 17     Science Fiction          14
# 18      Sequential Art          70
# 19            Thriller          11
# 20              Travel          11
# 21      Womens Fiction          16
# 22         Young Adult          50

# %% [markdown]
# #### 17) Write a sql query to get all books with category_name='Music' using subquery.

# %%
qry = '''
SELECT * 
FROM books_catalog
WHERE category_id IN(
SELECT category_id
FROM categories
WHERE category_name = 'Music'
);
'''
cur.execute(qry)
cur.fetchall()
# Out:
# [(438,
#   'Rip it Up and Start Again',
#   'http://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html',
#   Decimal('35.02'),
#   'In stock',
#   5,
#   13),
#  (439,
#   'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   'http://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html',
#   Decimal('57.25'),
#   'In stock',
#   3,
#   13),
#  (440,
#   'How Music Works',
#   'http://books.toscrape.com/catalogue/how-music-works_979/index.html',
#   Decimal('37.32'),
#   'In stock',
#   2,
#   13),
#  (441,
#   'Love Is a Mix Tape (Music #1)',
#   'http://books.toscrape.com/catalogue/love-is-a-mix-tape-music-1_711/index.html',
#   Decimal('18.03'),
#   'In stock',
#   3,
#   13),
#  (442,
#   'Please Kill Me: The Uncensored Oral History of Punk',
#   'http://books.toscrape.com/catalogue/please-kill-me-the-uncensored-oral-history-of-punk_537/index.html',
#   Decimal('31.19'),
#   'In stock',
#   4,
#   13),
#  (443,
#   "Kill 'Em and Leave: Searching for James Brown and the American Soul",
#   'http://books.toscrape.com/catalogue/kill-em-and-leave-searching-for-james-brown-and-the-american-soul_528/index.html',
#   Decimal('45.05'),
#   'In stock',
#   5,
#   13),
#  (445,
#   'This Is Your Brain on Music: The Science of a Human Obsession',
#   'http://books.toscrape.com/catalogue/this-is-your-brain-on-music-the-science-of-a-human-obsession_414/index.html',
#   Decimal('38.40'),
#   'In stock',
#   1,
#   13),
#  (446,
#   'Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',
#   'http://books.toscrape.com/catalogue/orchestra-of-exiles-the-story-of-bronislaw-huberman-the-israel-philharmonic-and-the-one-thousand-jews-he-saved-from-nazi-horrors_337/index.html',
#   Decimal('12.36'),
#   'In stock',
#   3,
#   13),
#  (447,
#   'No One Here Gets Out Alive',
#   'http://books.toscrape.com/catalogue/no-one-here-gets-out-alive_336/index.html',
#   Decimal('20.02'),
#   'In stock',
#   5,
#   13),
#  (448,
#   'Life',
#   'http://books.toscrape.com/catalogue/life_104/index.html',
#   Decimal('31.58'),
#   'In stock',
#   5,
#   13),
#  (450,
#   'Forever Rockers (The Rocker #12)',
#   'http://books.toscrape.com/catalogue/forever-rockers-the-rocker-12_19/index.html',
#   Decimal('28.80'),
#   'In stock',
#   3,
#   13)]

# %%
df = pd.read_sql(qry , con)
df
# Out:
# C:\Users\Alaa\AppData\Local\Temp\ipykernel_48364\4063385464.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(qry , con)
#     book_id                                              title  \
# 0       438                          Rip it Up and Start Again
# 1       439  Our Band Could Be Your Life: Scenes from the A...
# 2       440                                    How Music Works
# 3       441                      Love Is a Mix Tape (Music #1)
# 4       442  Please Kill Me: The Uncensored Oral History of...
# 5       443  Kill 'Em and Leave: Searching for James Brown ...
# 6       445  This Is Your Brain on Music: The Science of a ...
# 7       446  Orchestra of Exiles: The Story of Bronislaw Hu...
# 8       447                         No One Here Gets Out Alive
# 9       448                                               Life
# 10      450                   Forever Rockers (The Rocker #12)
#
#                                                   url  price availability  \
# 0   http://books.toscrape.com/catalogue/rip-it-up-...  35.02     In stock
# 1   http://books.toscrape.com/catalogue/our-band-c...  57.25     In stock
# 2   http://books.toscrape.com/catalogue/how-music-...  37.32     In stock
# 3   http://books.toscrape.com/catalogue/love-is-a-...  18.03     In stock
# 4   http://books.toscrape.com/catalogue/please-kil...  31.19     In stock
# 5   http://books.toscrape.com/catalogue/kill-em-an...  45.05     In stock
# 6   http://books.toscrape.com/catalogue/this-is-yo...  38.40     In stock
# 7   http://books.toscrape.com/catalogue/orchestra-...  12.36     In stock
# 8   http://books.toscrape.com/catalogue/no-one-her...  20.02     In stock
# 9   http://books.toscrape.com/catalogue/life_104/i...  31.58     In stock
# 10  http://books.toscrape.com/catalogue/forever-ro...  28.80     In stock
#
#     rating  category_id
# 0        5           13
# 1        3           13
# 2        2           13
# 3        3           13
# 4        4           13
# 5        5           13
# 6        1           13
# 7        3           13
# 8        5           13
# 9        5           13
# 10       3           13
